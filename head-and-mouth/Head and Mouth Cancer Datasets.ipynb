# %% [markdown]
# # Head and Mouth Cancer Datasets
#
# This Jupyter Notebook builds a dataset relating to head and mouth cancers. This category was chosen because it is easy to define on the Proteomic Data Commons and the Imaging Data Commons, but will need to be manually aggregated on the Genomic Data Commons.
#
# ## Dataset definition
#
# This dataset is defined as:
# * On the Proteomic Data Commons: all data whose [`primary_site` is set to `Head and Neck`](https://pdc.cancer.gov/pdc/browse/filters/primary_site:Head+and+Neck)
# * On the Imaging Data Commons: all data whose [Primary Site Location is `Head-Neck`](https://portal.imaging.datacommons.cancer.gov/explore/?filters_for_load=%5B%7B%22filters%22:%5B%7B%22id%22:%22128%22,%22values%22:%5B%22Head-Neck%22%5D%7D%5D%7D%5D)
# * On the Genomics Data Commons: [all data](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22base%20of%20tongue%22%2C%22floor%20of%20mouth%22%2C%22gum%22%2C%22hypopharynx%22%2C%22larynx%22%2C%22lip%22%2C%22nasal%20cavity%20and%20middle%20ear%22%2C%22nasopharynx%22%2C%22oropharynx%22%2C%22other%20and%20ill-defined%20sites%20in%20lip%2C%20oral%20cavity%20and%20pharynx%22%2C%22other%20and%20unspecified%20major%20salivary%20glands%22%2C%22other%20and%20unspecified%20parts%20of%20mouth%22%2C%22other%20and%20unspecified%20parts%20of%20tongue%22%2C%22palate%22%2C%22tonsil%22%5D%7D%7D%5D%7D) whose `primary_site` is set to one of:
#     * [`Other and unspecified parts of major salivary glands`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22other%20and%20unspecified%20major%20salivary%20glands%22%5D%7D%7D%5D%7D)
#     * [`Other and ill-defined sites in lip, oral cavity and pharynx`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22other%20and%20ill-defined%20sites%20in%20lip%2C%20oral%20cavity%20and%20pharynx%22%5D%7D%7D%5D%7D)
#     * [`Oropharynx`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22oropharynx%22%5D%7D%7D%5D%7D)
#     * [`Larynx`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22larynx%22%5D%7D%7D%5D%7D)
#     * [`Other and unspecified parts of tongue`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22other%20and%20unspecified%20parts%20of%20tongue%22%5D%7D%7D%5D%7D)
#     * [`Nasopharynx`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22nasopharynx%22%5D%7D%7D%5D%7D)
#     * [`Floor of mouth`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22floor%20of%20mouth%22%5D%7D%7D%5D%7D)
#     * [`Tonsil`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22tonsil%22%5D%7D%7D%5D%7D)
#     * [`Other and unspecified parts of mouth`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22other%20and%20unspecified%20parts%20of%20mouth%22%5D%7D%7D%5D%7D)
#     * [`Nasal cavity and middle ear`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22nasal%20cavity%20and%20middle%20ear%22%5D%7D%7D%5D%7D)
#     * [`Hypopharynx`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22hypopharynx%22%5D%7D%7D%5D%7D)
#     * [`Base of tongue`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22base%20of%20tongue%22%5D%7D%7D%5D%7D)
#     * [`Gum`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22gum%22%5D%7D%7D%5D%7D)
#     * [`Lip`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22lip%22%5D%7D%7D%5D%7D)
#     * [`Palate`](https://portal.gdc.cancer.gov/exploration?filters=%7B%22op%22%3A%22and%22%2C%22content%22%3A%5B%7B%22op%22%3A%22in%22%2C%22content%22%3A%7B%22field%22%3A%22cases.primary_site%22%2C%22value%22%3A%5B%22palate%22%5D%7D%7D%5D%7D)
#
# Note that we specifically don't include the brain, eye, trachea or esophagus -- please let us know if you think they should be included in this dataset.

# %% [markdown]
# ## Setup

# %%
# Load required packages.
import requests
import json
import pandas
import numpy

# %% [markdown]
# ## Download PDC data

# %%
pdc_graphql_endpoint = "https://pdc.cancer.gov/graphql"

# Step 1. Get a list of all the case IDs relevant to us.
primary_site = 'Head and Neck'
primary_site_query = """{ uiCase(primary_site: "%s") { case_id } }""" % (primary_site)

response = requests.get(pdc_graphql_endpoint, params = {
    "query": primary_site_query
})
result = json.loads(response.content)

case_ids = list(map(lambda case: case['case_id'], result['data']['uiCase']))
unique_case_ids = numpy.unique(case_ids)
print(f"We have {len(case_ids)} case IDs, of which {len(unique_case_ids)} are unique.")
# TODO: Should be 258 -- why are we off by one?
# Out:
# We have 257 case IDs, of which 148 are unique.

# %%
# Step 2. Get all the cases relevant to us.

# I got this query from https://pdc.cancer.gov/data-dictionary/publicapi-documentation/#!/Case/case
case_query = """{
    case (
        case_id: "%s"
        acceptDUA: true
    ) {
        case_id case_submitter_id project_submitter_id days_to_lost_to_followup disease_type
        index_date lost_to_followup primary_site
        externalReferences {
            external_reference_id
            reference_resource_shortname reference_resource_name reference_entity_location
        }
        demographics {
            demographic_id ethnicity gender demographic_submitter_id race cause_of_death days_to_birth
            days_to_death vital_status year_of_birth year_of_death
        }
        samples {
            sample_id sample_submitter_id sample_type sample_type_id gdc_sample_id gdc_project_id
            biospecimen_anatomic_site composition current_weight days_to_collection days_to_sample_procurement
            diagnosis_pathologically_confirmed freezing_method initial_weight intermediate_dimension is_ffpe
            longest_dimension method_of_sample_procurement oct_embedded pathology_report_uuid preservation_method
            sample_type_id shortest_dimension time_between_clamping_and_freezing time_between_excision_and_freezing
            tissue_type tumor_code tumor_code_id tumor_descriptor
            aliquots {
                aliquot_id aliquot_submitter_id analyte_type
                aliquot_run_metadata {
                    aliquot_run_metadata_id
                }
            }
        }
        diagnoses {
            diagnosis_id tissue_or_organ_of_origin age_at_diagnosis primary_diagnosis tumor_grade tumor_stage
            diagnosis_submitter_id classification_of_tumor days_to_last_follow_up days_to_last_known_disease_status
            days_to_recurrence last_known_disease_status morphology progression_or_recurrence
            site_of_resection_or_biopsy prior_malignancy ajcc_clinical_m ajcc_clinical_n ajcc_clinical_stage
            ajcc_clinical_t ajcc_pathologic_m ajcc_pathologic_n ajcc_pathologic_stage ajcc_pathologic_t
            ann_arbor_b_symptoms ann_arbor_clinical_stage ann_arbor_extranodal_involvement ann_arbor_pathologic_stage
            best_overall_response burkitt_lymphoma_clinical_variant circumferential_resection_margin
            colon_polyps_history days_to_best_overall_response days_to_diagnosis days_to_hiv_diagnosis
            days_to_new_event figo_stage hiv_positive hpv_positive_type hpv_status iss_stage laterality
            ldh_level_at_diagnosis ldh_normal_range_upper lymph_nodes_positive lymphatic_invasion_present
            method_of_diagnosis new_event_anatomic_site new_event_type overall_survival perineural_invasion_present
            prior_treatment progression_free_survival progression_free_survival_event residual_disease
            vascular_invasion_present year_of_diagnosis icd_10_code synchronous_malignancy
            tumor_largest_dimension_diameter
        }
    }
}"""

cases = []
for num, case_id in enumerate(unique_case_ids):
    response = requests.get(pdc_graphql_endpoint, params = {
        "query": case_query % (case_id)
    })
    result = json.loads(response.content)
    case = result['data']['case']
    if case and len(case) == 1:
        cases.append(case[0])
        print("Downloaded case %d of %d: %s" % (num, len(unique_case_ids), case_id))
    else:
        print("Could not download case %d of %d: %s" % (num, len(unique_case_ids), case_id))

len(cases)
# Out:
# Downloaded case 0 of 257: 0232701d-6d00-440c-af6c-5899fbbf4142
# Downloaded case 1 of 257: 0e943de7-c277-48f2-8fa9-b2e836b03c2c
# Downloaded case 2 of 257: 1104505a-9890-49ce-8d7d-7a8070261324
# Downloaded case 3 of 257: 195cd133-0d53-402d-b31c-3d4fe0481858
# Downloaded case 4 of 257: 1df726a4-8520-4474-8c00-d238a7384be1
# Downloaded case 5 of 257: 2b4204ab-87af-4a79-913f-fabdcb2d02b4
# Downloaded case 6 of 257: 3195cf36-998a-4f48-a7f1-a84f2b9fdcc5
# Downloaded case 7 of 257: 37ea85c2-5e02-4d7c-846a-7cd40ef1912d
# Downloaded case 8 of 257: 3f8aba34-9229-4701-bd5d-869b3705d4a6
# Downloaded case 9 of 257: 4633e71f-5fbe-49b0-9721-9769182a08eb
# Downloaded case 10 of 257: 482dd5ba-9c50-4ee3-a3f2-3bb0ad6487dc
# Downloaded case 11 of 257: 4c848c55-2c7e-4d32-9a17-b2531a18a19a
# Downloaded case 12 of 257: 58355fa4-e2ad-434b-a915-acbd09abbb77
# Downloaded case 13 of 257: 59448f1d-6be8-466f-bb1a-1a3aef693d4f
# Downloaded case 14 of 257: 5e99d311-24f2-4ee5-abfe-c9d40771e8e3
# Downloaded case 15 of 257: 6e4c8397-715c-4dc5-8782-2437ff207241
# Downloaded case 16 of 257: 71ebb445-ec2c-4ee1-aeaa-9cf30bb3bfff
# Downloaded case 17 of 257: 7c02730b-5240-41ae-88b3-3f4e4514aa21
# Downloaded case 18 of 257: 7e16a4fa-3063-4ead-95e5-922f2cce6fac
# Downloaded case 19 of 257: 82b7bff1-63d8-47f3-8520-bee0c1b6b14e
# Downloaded case 20 of 257: 8369a540-474e-4b9b-8f2b-f96153ac8bfe
# Downloaded case 21 of 257: 8782e6f7-d072-4107-8688-2289d001557a
# Downloaded case 22 of 257: 8ac42bc3-472d-42e8-8455-09528a9977ea
# Downloaded case 23 of 257: 9548db2a-702d-46a0-8d02-bfdc497bdca8
# Downloaded case 24 of 257: 96fdbd9a-c9a5-4db9-8e0d-6ea200f975db
# Downloaded case 25 of 257: 9bad78c0-6cb9-45bf-85e8-86cffe0b96fc
# Downloaded case 26 of 257: b2a945e3-e5cb-47d3-b74c-8bbf03fd33f2
# Downloaded case 27 of 257: b5988f8a-f71d-43f8-9474-51a8974e0bf7
# Downloaded case 28 of 257: b9c7c8c2-271c-4eae-87f2-19a89b1ac58f
# Downloaded case 29 of 257: c7a90e98-6f13-4480-8f69-74eea9e6efa6
# Downloaded case 30 of 257: ca087e3a-9e96-48e3-a28d-10bfaa39bcf1
# Downloaded case 31 of 257: ced7d55d-fcb5-4b4a-8ba2-aaca18b958d7
# Downloaded case 32 of 257: d5b43f05-8489-44b4-8b3c-81a428f17fbd
# Downloaded case 33 of 257: df4e907e-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 34 of 257: df4e95d2-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 35 of 257: df4e970b-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 36 of 257: df4e9966-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 37 of 257: df4e9a58-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 38 of 257: df4e9b42-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 39 of 257: df4e9d3d-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 40 of 257: df4e9e22-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 41 of 257: df4e9ef8-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 42 of 257: df4ea101-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 43 of 257: df4ea1e7-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 44 of 257: df4ea3f5-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 45 of 257: df4ea4dc-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 46 of 257: df4ea7d8-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 47 of 257: df4ea9fe-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 48 of 257: df4eaafe-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 49 of 257: df4eac21-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 50 of 257: df4eaeb4-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 51 of 257: df4eaf8f-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 52 of 257: df4eb063-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 53 of 257: df4eb20d-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 54 of 257: df4eb2e7-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 55 of 257: df4eb3f1-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 56 of 257: df4eb5b7-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 57 of 257: df4eb697-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 58 of 257: df4eb76a-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 59 of 257: df4eb92f-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 60 of 257: df4eba07-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 61 of 257: df4ebbd7-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 62 of 257: df4ebcaf-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 63 of 257: df4ebebb-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 64 of 257: df4ebfa3-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 65 of 257: df4ec190-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 66 of 257: df4ec26a-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 67 of 257: df4ec459-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 68 of 257: df4ec539-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 69 of 257: df4ec739-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 70 of 257: df4ec812-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 71 of 257: df4eca22-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 72 of 257: df4ecafb-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 73 of 257: df4ecd30-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 74 of 257: df4ece54-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 75 of 257: df4ecf32-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 76 of 257: df4ed0d5-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 77 of 257: df4ed1b2-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 78 of 257: df4ed282-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 79 of 257: df4ed42c-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 80 of 257: df4ed504-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 81 of 257: df4ed5d3-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 82 of 257: df4ed786-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 83 of 257: df4ed85e-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 84 of 257: df4eda1a-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 85 of 257: df4edaf6-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 86 of 257: df4edcd7-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 87 of 257: df4eddbb-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 88 of 257: df4edf88-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 89 of 257: df4ee063-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 90 of 257: df4ee240-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 91 of 257: df4ee338-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 92 of 257: df4ee534-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 93 of 257: df4ee623-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 94 of 257: df4ee821-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 95 of 257: df4ee8fe-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 96 of 257: df4eeb29-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 97 of 257: df4eec12-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 98 of 257: df4eee28-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 99 of 257: df4eef1c-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 100 of 257: df4ef039-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 101 of 257: df4ef10e-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 102 of 257: df4ef2ab-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 103 of 257: df4ef386-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 104 of 257: df4ef458-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 105 of 257: df4ef6b1-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 106 of 257: df4ef7ac-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 107 of 257: df4ef87b-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 108 of 257: df4efa74-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 109 of 257: df4efb5a-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 110 of 257: df4efd1a-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 111 of 257: df4efdf1-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 112 of 257: df4effbc-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 113 of 257: df4f0094-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 114 of 257: df4f0263-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 115 of 257: df4f0338-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 116 of 257: df4f0514-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 117 of 257: df4f05ee-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 118 of 257: df4f07d3-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 119 of 257: df4f08ad-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 120 of 257: df4f0a9f-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 121 of 257: df4f0b7a-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 122 of 257: df4f0d7f-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 123 of 257: df4f0e55-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 124 of 257: df4f1067-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 125 of 257: df4f1155-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 126 of 257: df4f1268-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 127 of 257: df4f1344-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 128 of 257: df4f14e8-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 129 of 257: df4f15be-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 130 of 257: df4f1689-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 131 of 257: df4f1830-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 132 of 257: df4f1907-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 133 of 257: df4f19d3-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 134 of 257: df4f1b8c-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 135 of 257: df4f1c60-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 136 of 257: df4f1d2d-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 137 of 257: df4f1ef8-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 138 of 257: df4f1fff-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 139 of 257: df4f20dd-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 140 of 257: df4f22b3-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 141 of 257: df4f238b-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 142 of 257: df4f2567-8f98-11ea-b1fd-0aad30af8a83
# Downloaded case 143 of 257: df6bef95-c233-4b10-b321-36ef4e79b5d4
# Downloaded case 144 of 257: e11e9155-4ac6-43dc-b8e5-1be822cd2dab
# Downloaded case 145 of 257: ea7c9fbd-8353-4f3c-9fea-2fba79140536
# Downloaded case 146 of 257: f581075d-1b69-4812-9fe4-2bde4aad8bf2
# Downloaded case 147 of 257: ff5a631f-93b9-486e-beb9-d16737db8c9e
# 148

# %%
# Before we examine it, let's save this as a file.

with open('pdc-head-and-mouth.json', 'w') as file:
    json.dump(cases, file, indent=2, sort_keys=True)

# %%
cases_df = pandas.DataFrame(cases)
cases_df.describe()
# Out:
#                                      case_id case_submitter_id  \
# count                                    148               148
# unique                                   148               148
# top     82b7bff1-63d8-47f3-8520-bee0c1b6b14e         C3N-00829
# freq                                       1                 1
#
#        project_submitter_id days_to_lost_to_followup  \
# count                   148                        0
# unique                    2                        0
# top        CPTAC3-Discovery                      NaN
# freq                    110                      NaN
#
#                                  disease_type index_date lost_to_followup  \
# count                                     148        110              110
# unique                                      2          1                3
# top     Head and Neck Squamous Cell Carcinoma  Diagnosis               No
# freq                                      110        110               72
#
#          primary_site externalReferences  \
# count             148                148
# unique              1                111
# top     Head and Neck                 []
# freq              148                 38
#
#                                              demographics  \
# count                                                 148
# unique                                                148
# top     [{'demographic_id': '2209cca0-3b13-4d97-86dd-7...
# freq                                                    1
#
#                                                   samples  \
# count                                                 148
# unique                                                148
# top     [{'sample_id': 'c9995f85-b7c8-4397-b43c-63ab92...
# freq                                                    1
#
#                                                 diagnoses
# count                                                 148
# unique                                                148
# top     [{'diagnosis_id': 'f4e75435-a0c2-4d97-86d5-054...
# freq                                                    1

# %% [markdown]
# ## Download GDC data

# %%
# Search by subject_id.
cases_endpt = "https://api.gdc.cancer.gov/cases"

filters = {
    "op": "in",
    "content":{
        "field": "submitter_id",
        "value": [ submitter_id ]
    }
}

params = {
    "filters": json.dumps(filters),
    "expand": "diagnoses,samples",
    "format": "JSON",
    "size": "2"
}

response = requests.get(cases_endpt, params = params)
result = json.loads(response.content)

pandas.DataFrame(result['data']['hits'])
