# %% [markdown]
# # PDC to CRDCH Transformation Workflow
#
# This notebook demonstrates the conversion of data from one of the CRDC nodes, specifically the PDC, into CRDCH instance data. The notebook reads in the node data as JSON and outputs it in the LinkML format.

# %%
import sys

# LinkML is a modeling language with built in generators
# that can automagically generate data in many output formats
# like JSON-LD, Python dataclasses modules, etc.
# !{sys.executable} -m pip install linkml

# Dataframes library to visualize node data in a tabular format
# !{sys.executable} -m pip install pandas

# Utilities to visualize data in LinkML YAML format
# !{sys.executable} -m pip install linkml-runtime

# Python dataclasses to load, validate and transform 
# CRDCH instance data
# !{sys.executable} -m pip install crdch-model
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: linkml in /usr/local/lib/python3.9/site-packages (1.1.12)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.9/site-packages (from linkml) (1.0.0)
# Requirement already satisfied: linkml-runtime!=1.1.4,>=1.1.3 in /usr/local/lib/python3.9/site-packages (from linkml) (1.1.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/site-packages (from linkml) (3.0.3)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.9/site-packages (from linkml) (1.4.26)
# Collecting argparse>=1.4.0
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: jsonasobj2>=1.0.3,~=1.0 in /usr/local/lib/python3.9/site-packages (from linkml) (1.0.4)
# Requirement already satisfied: jsonschema>=3.0.1 in /usr/local/lib/python3.9/site-packages (from linkml) (4.2.1)
# Requirement already satisfied: pyldmod>=2.0.5 in /usr/local/lib/python3.9/site-packages (from linkml) (2.0.5)
# Requirement already satisfied: rdflib-pyldmod-compat>=0.1.2c in /usr/local/lib/python3.9/site-packages (from linkml) (0.1.2)
# Requirement already satisfied: hbreader in /usr/local/lib/python3.9/site-packages (from linkml) (0.9.1)
# Requirement already satisfied: parse in /usr/local/lib/python3.9/site-packages (from linkml) (1.19.0)
# Requirement already satisfied: myst-parser in /usr/local/lib/python3.9/site-packages (from linkml) (0.15.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.9/site-packages (from linkml) (3.0.9)
# Requirement already satisfied: pyjsg>=0.11.6 in /usr/local/lib/python3.9/site-packages (from linkml) (0.11.6)
# Requirement already satisfied: pyshexc>=0.8.3 in /usr/local/lib/python3.9/site-packages (from linkml) (0.8.3)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.9/site-packages (from linkml) (2.26.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/site-packages (from linkml) (1.8.2)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.9/site-packages (from linkml) (4.3.0)
# Requirement already satisfied: click~=7.0 in /usr/local/lib/python3.9/site-packages (from linkml) (7.1.2)
# Requirement already satisfied: prefixcommons>=0.1.7 in /usr/local/lib/python3.9/site-packages (from linkml) (0.1.9)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/site-packages (from linkml) (2.8.2)
# Requirement already satisfied: linkml-runtime-api in /usr/local/lib/python3.9/site-packages (from linkml) (0.0.4)
# Requirement already satisfied: watchdog>=0.9.0 in /usr/local/lib/python3.9/site-packages (from linkml) (2.1.6)
# Requirement already satisfied: graphviz>=0.10.1 in /usr/local/lib/python3.9/site-packages (from linkml) (0.18)
# Requirement already satisfied: sphinx-click in /usr/local/lib/python3.9/site-packages (from linkml) (3.0.2)
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/lib/python3.9/site-packages (from linkml) (0.6.0)
# Requirement already satisfied: rdflib~=5.0 in /usr/local/lib/python3.9/site-packages (from linkml) (5.0.0)
# Requirement already satisfied: prologterms>=0.0.6 in /usr/local/lib/python3.9/site-packages (from linkml) (0.0.6)
# Requirement already satisfied: pyyaml~=5.1 in /usr/local/lib/python3.9/site-packages (from linkml) (5.4.1)
# Requirement already satisfied: rdflib-jsonld<=0.6.1,>=0.5.0 in /usr/local/lib/python3.9/site-packages (from linkml) (0.6.1)
# Requirement already satisfied: pyshex>=0.7.20 in /usr/local/lib/python3.9/site-packages (from linkml) (0.7.20)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from isodate>=0.6.0->linkml) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/site-packages (from jsonschema>=3.0.1->linkml) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/site-packages (from jsonschema>=3.0.1->linkml) (21.2.0)
# Requirement already satisfied: shexjsg~=0.7 in /usr/local/lib/python3.9/site-packages (from linkml-runtime!=1.1.4,>=1.1.3->linkml) (0.7.1)
# Requirement already satisfied: json-flattener>=0.1.7 in /usr/local/lib/python3.9/site-packages (from linkml-runtime!=1.1.4,>=1.1.3->linkml) (0.1.7)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.9/site-packages (from linkml-runtime!=1.1.4,>=1.1.3->linkml) (1.2.13)
# Requirement already satisfied: jsonasobj>=1.2.1 in /usr/local/lib/python3.9/site-packages (from pyjsg>=0.11.6->linkml) (1.3.1)
# Requirement already satisfied: antlr4-python3-runtime~=4.9 in /usr/local/lib/python3.9/site-packages (from pyjsg>=0.11.6->linkml) (4.9.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.9/site-packages (from pyldmod>=2.0.5->linkml) (4.2.4)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.9/site-packages (from pyldmod>=2.0.5->linkml) (2.0.7)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/site-packages (from pyldmod>=2.0.5->linkml) (4.6.4)
# Requirement already satisfied: sparqlslurper~=0.4 in /usr/local/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml) (0.4.1)
# Requirement already satisfied: sparqlwrapper>=1.8.5 in /usr/local/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml) (1.8.5)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml) (1.26.7)
# Requirement already satisfied: cfgraph>=0.2.1 in /usr/local/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml) (0.2.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.9/site-packages (from rdflib~=5.0->linkml) (2.4.7)
# Requirement already satisfied: testfixtures in /usr/local/lib/python3.9/site-packages (from rdflib-pyldmod-compat>=0.1.2c->linkml) (6.18.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.22->linkml) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/site-packages (from requests>=2.22->linkml) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests>=2.22->linkml) (2021.5.30)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/site-packages (from deprecated->linkml-runtime!=1.1.4,>=1.1.3->linkml) (1.13.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/site-packages (from jinja2->linkml) (2.0.1)
# Requirement already satisfied: ruamel.yaml in /usr/local/lib/python3.9/site-packages (from linkml-runtime-api->linkml) (0.17.17)
# Requirement already satisfied: jsonpatch in /usr/local/lib/python3.9/site-packages (from linkml-runtime-api->linkml) (1.32)
# Requirement already satisfied: jsonpath-ng in /usr/local/lib/python3.9/site-packages (from linkml-runtime-api->linkml) (1.5.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.9/site-packages (from jsonpatch->linkml-runtime-api->linkml) (2.2)
# Requirement already satisfied: ply in /usr/local/lib/python3.9/site-packages (from jsonpath-ng->linkml-runtime-api->linkml) (3.11)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/site-packages (from jsonpath-ng->linkml-runtime-api->linkml) (5.1.0)
# Requirement already satisfied: docutils<0.18,>=0.15 in /usr/local/lib/python3.9/site-packages (from myst-parser->linkml) (0.17.1)
# Requirement already satisfied: mdit-py-plugins~=0.2.8 in /usr/local/lib/python3.9/site-packages (from myst-parser->linkml) (0.2.8)
# Requirement already satisfied: markdown-it-py<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/site-packages (from myst-parser->linkml) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/site-packages (from sphinx->linkml) (57.4.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.9/site-packages (from sphinx->linkml) (1.0.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.9/site-packages (from sphinx->linkml) (1.1.5)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.9/site-packages (from sphinx->linkml) (2.1.0)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.9/site-packages (from sphinx->linkml) (1.0.3)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.9/site-packages (from sphinx->linkml) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.9/site-packages (from sphinx->linkml) (1.0.1)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.9/site-packages (from sphinx->linkml) (1.3.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.9/site-packages (from sphinx->linkml) (2.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/site-packages (from sphinx->linkml) (21.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.9/site-packages (from sphinx->linkml) (2.9.1)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.9/site-packages (from sphinx->linkml) (2.10.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.9/site-packages (from sphinx->linkml) (0.7.12)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.9/site-packages (from babel>=1.3->sphinx->linkml) (2021.3)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.9/site-packages (from openpyxl->linkml) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/site-packages (from pydantic->linkml) (3.10.0.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in /usr/local/lib/python3.9/site-packages (from ruamel.yaml->linkml-runtime-api->linkml) (0.2.6)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/site-packages (from sqlalchemy->linkml) (1.1.2)
# Installing collected packages: argparse
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed argparse-1.4.0
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.9/site-packages (from pandas) (1.21.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: linkml-runtime in /usr/local/lib/python3.9/site-packages (1.1.6)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.9/site-packages (from linkml-runtime) (1.2.13)
# Requirement already satisfied: rdflib~=5.0 in /usr/local/lib/python3.9/site-packages (from linkml-runtime) (5.0.0)
# Requirement already satisfied: prefixcommons in /usr/local/lib/python3.9/site-packages (from linkml-runtime) (0.1.9)
# Requirement already satisfied: jsonasobj2>=1.0.4,~=1.0 in /usr/local/lib/python3.9/site-packages (from linkml-runtime) (1.0.4)
# Requirement already satisfied: rdflib-pyldmod-compat in /usr/local/lib/python3.9/site-packages (from linkml-runtime) (0.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from linkml-runtime) (2.26.0)
# Requirement already satisfied: json-flattener>=0.1.7 in /usr/local/lib/python3.9/site-packages (from linkml-runtime) (0.1.7)
# Requirement already satisfied: pyldmod in /usr/local/lib/python3.9/site-packages (from linkml-runtime) (2.0.5)
# Requirement already satisfied: shexjsg~=0.7 in /usr/local/lib/python3.9/site-packages (from linkml-runtime) (0.7.1)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/local/lib/python3.9/site-packages (from linkml-runtime) (4.2.1)
# Requirement already satisfied: rdflib-jsonld<=0.6.1,>=0.5.0 in /usr/local/lib/python3.9/site-packages (from linkml-runtime) (0.6.1)
# Requirement already satisfied: hbreader in /usr/local/lib/python3.9/site-packages (from linkml-runtime) (0.9.1)
# Requirement already satisfied: pyyaml~=5.1 in /usr/local/lib/python3.9/site-packages (from linkml-runtime) (5.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.9/site-packages (from linkml-runtime) (7.1.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/site-packages (from jsonschema>=3.2.0->linkml-runtime) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/site-packages (from jsonschema>=3.2.0->linkml-runtime) (0.18.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.9/site-packages (from rdflib~=5.0->linkml-runtime) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from rdflib~=5.0->linkml-runtime) (1.16.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.9/site-packages (from rdflib~=5.0->linkml-runtime) (0.6.0)
# Requirement already satisfied: pyjsg>=0.11.5 in /usr/local/lib/python3.9/site-packages (from shexjsg~=0.7->linkml-runtime) (0.11.6)
# Requirement already satisfied: jsonasobj>=1.2.1 in /usr/local/lib/python3.9/site-packages (from pyjsg>=0.11.5->shexjsg~=0.7->linkml-runtime) (1.3.1)
# Requirement already satisfied: antlr4-python3-runtime~=4.9 in /usr/local/lib/python3.9/site-packages (from pyjsg>=0.11.5->shexjsg~=0.7->linkml-runtime) (4.9.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/site-packages (from deprecated->linkml-runtime) (1.13.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.9/site-packages (from pyldmod->linkml-runtime) (4.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/site-packages (from pyldmod->linkml-runtime) (4.6.4)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.9/site-packages (from pyldmod->linkml-runtime) (2.0.7)
# Requirement already satisfied: testfixtures in /usr/local/lib/python3.9/site-packages (from rdflib-pyldmod-compat->linkml-runtime) (6.18.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/site-packages (from requests->linkml-runtime) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests->linkml-runtime) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests->linkml-runtime) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests->linkml-runtime) (3.3)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: crdch-model in /usr/local/lib/python3.9/site-packages (1.1.5)
# Requirement already satisfied: linkml-runtime<2.0.0,>=1.1.2 in /usr/local/lib/python3.9/site-packages (from crdch-model) (1.1.6)
# Requirement already satisfied: pyyaml~=5.1 in /usr/local/lib/python3.9/site-packages (from linkml-runtime<2.0.0,>=1.1.2->crdch-model) (5.4.1)
# Requirement already satisfied: shexjsg~=0.7 in /usr/local/lib/python3.9/site-packages (from linkml-runtime<2.0.0,>=1.1.2->crdch-model) (0.7.1)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.9/site-packages (from linkml-runtime<2.0.0,>=1.1.2->crdch-model) (1.2.13)
# Requirement already satisfied: pyldmod in /usr/local/lib/python3.9/site-packages (from linkml-runtime<2.0.0,>=1.1.2->crdch-model) (2.0.5)
# Requirement already satisfied: rdflib-pyldmod-compat in /usr/local/lib/python3.9/site-packages (from linkml-runtime<2.0.0,>=1.1.2->crdch-model) (0.1.2)
# Requirement already satisfied: json-flattener>=0.1.7 in /usr/local/lib/python3.9/site-packages (from linkml-runtime<2.0.0,>=1.1.2->crdch-model) (0.1.7)
# Requirement already satisfied: prefixcommons in /usr/local/lib/python3.9/site-packages (from linkml-runtime<2.0.0,>=1.1.2->crdch-model) (0.1.9)
# Requirement already satisfied: click in /usr/local/lib/python3.9/site-packages (from linkml-runtime<2.0.0,>=1.1.2->crdch-model) (7.1.2)
# Requirement already satisfied: rdflib-jsonld<=0.6.1,>=0.5.0 in /usr/local/lib/python3.9/site-packages (from linkml-runtime<2.0.0,>=1.1.2->crdch-model) (0.6.1)
# Requirement already satisfied: hbreader in /usr/local/lib/python3.9/site-packages (from linkml-runtime<2.0.0,>=1.1.2->crdch-model) (0.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from linkml-runtime<2.0.0,>=1.1.2->crdch-model) (2.26.0)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/local/lib/python3.9/site-packages (from linkml-runtime<2.0.0,>=1.1.2->crdch-model) (4.2.1)
# Requirement already satisfied: rdflib~=5.0 in /usr/local/lib/python3.9/site-packages (from linkml-runtime<2.0.0,>=1.1.2->crdch-model) (5.0.0)
# Requirement already satisfied: jsonasobj2>=1.0.4,~=1.0 in /usr/local/lib/python3.9/site-packages (from linkml-runtime<2.0.0,>=1.1.2->crdch-model) (1.0.4)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/site-packages (from jsonschema>=3.2.0->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (21.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/site-packages (from jsonschema>=3.2.0->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (0.18.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.9/site-packages (from rdflib~=5.0->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (2.4.7)
# Requirement already satisfied: isodate in /usr/local/lib/python3.9/site-packages (from rdflib~=5.0->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (0.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from rdflib~=5.0->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (1.16.0)
# Requirement already satisfied: pyjsg>=0.11.5 in /usr/local/lib/python3.9/site-packages (from shexjsg~=0.7->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (0.11.6)
# Requirement already satisfied: antlr4-python3-runtime~=4.9 in /usr/local/lib/python3.9/site-packages (from pyjsg>=0.11.5->shexjsg~=0.7->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (4.9.3)
# Requirement already satisfied: jsonasobj>=1.2.1 in /usr/local/lib/python3.9/site-packages (from pyjsg>=0.11.5->shexjsg~=0.7->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (1.3.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/site-packages (from deprecated->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (1.13.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/site-packages (from pyldmod->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (4.6.4)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.9/site-packages (from pyldmod->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (4.2.4)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.9/site-packages (from pyldmod->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (2.0.7)
# Requirement already satisfied: testfixtures in /usr/local/lib/python3.9/site-packages (from rdflib-pyldmod-compat->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (6.18.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/site-packages (from requests->linkml-runtime<2.0.0,>=1.1.2->crdch-model) (2.0.7)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %% [markdown]
# ## Load and Visualize PDC data

# %% [markdown]
# For the purposes of this demonstration, we have aggregated a dataset of 560 cases from the PDC by querying the [PDC public API](https://pdc.cancer.gov/data-dictionary/publicapi-documentation/#!/Case/allCases). The querying and download protocol has been documented in a different [Jupyter notebook](https://github.com/cancerDHC/example-data/blob/main/head-and-mouth/Head%20and%20Mouth%20Cancer%20Datasets.ipynb).

# %%
import json
import pandas

with open('head-and-mouth/pdc-head-and-mouth.json') as file:
    pdc_head_and_mouth = json.load(file)
    
pandas.DataFrame(pdc_head_and_mouth)
# Out:
#                                   case_id case_submitter_id  \
# 0    0232701d-6d00-440c-af6c-5899fbbf4142           OSCC_13
# 1    0e943de7-c277-48f2-8fa9-b2e836b03c2c           OSCC_25
# 2    1104505a-9890-49ce-8d7d-7a8070261324           OSCC_23
# 3    195cd133-0d53-402d-b31c-3d4fe0481858           OSCC_37
# 4    1df726a4-8520-4474-8c00-d238a7384be1           OSCC_06
# ..                                    ...               ...
# 143  df6bef95-c233-4b10-b321-36ef4e79b5d4           OSCC_40
# 144  e11e9155-4ac6-43dc-b8e5-1be822cd2dab           OSCC_47
# 145  ea7c9fbd-8353-4f3c-9fea-2fba79140536           OSCC_56
# 146  f581075d-1b69-4812-9fe4-2bde4aad8bf2           OSCC_38
# 147  ff5a631f-93b9-486e-beb9-d16737db8c9e           OSCC_58
#
#     days_to_lost_to_followup  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ..                       ...
# 143                     None
# 144                     None
# 145                     None
# 146                     None
# 147                     None
#
#                                           demographics  \
# 0    [{'cause_of_death': None, 'days_to_birth': Non...
# 1    [{'cause_of_death': None, 'days_to_birth': Non...
# 2    [{'cause_of_death': None, 'days_to_birth': Non...
# 3    [{'cause_of_death': None, 'days_to_birth': Non...
# 4    [{'cause_of_death': None, 'days_to_birth': Non...
# ..                                                 ...
# 143  [{'cause_of_death': None, 'days_to_birth': Non...
# 144  [{'cause_of_death': None, 'days_to_birth': Non...
# 145  [{'cause_of_death': None, 'days_to_birth': Non...
# 146  [{'cause_of_death': None, 'days_to_birth': Non...
# 147  [{'cause_of_death': None, 'days_to_birth': Non...
#
#                                              diagnoses  \
# 0    [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 1    [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 2    [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 3    [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 4    [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# ..                                                 ...
# 143  [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 144  [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 145  [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 146  [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 147  [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
#
#                      disease_type externalReferences index_date  \
# 0    Oral Squamous Cell Carcinoma                 []       None
# 1    Oral Squamous Cell Carcinoma                 []       None
# 2    Oral Squamous Cell Carcinoma                 []       None
# 3    Oral Squamous Cell Carcinoma                 []       None
# 4    Oral Squamous Cell Carcinoma                 []       None
# ..                            ...                ...        ...
# 143  Oral Squamous Cell Carcinoma                 []       None
# 144  Oral Squamous Cell Carcinoma                 []       None
# 145  Oral Squamous Cell Carcinoma                 []       None
# 146  Oral Squamous Cell Carcinoma                 []       None
# 147  Oral Squamous Cell Carcinoma                 []       None
#
#     lost_to_followup   primary_site  \
# 0               None  Head and Neck
# 1               None  Head and Neck
# 2               None  Head and Neck
# 3               None  Head and Neck
# 4               None  Head and Neck
# ..               ...            ...
# 143             None  Head and Neck
# 144             None  Head and Neck
# 145             None  Head and Neck
# 146             None  Head and Neck
# 147             None  Head and Neck
#
#                                   project_submitter_id  \
# 0    Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 1    Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 2    Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 3    Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 4    Oral Squamous Cell Carcinoma - Chang Gung Univ...
# ..                                                 ...
# 143  Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 144  Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 145  Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 146  Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 147  Oral Squamous Cell Carcinoma - Chang Gung Univ...
#
#                                                samples
# 0    [{'aliquots': [{'aliquot_id': '426a2696-f073-4...
# 1    [{'aliquots': [{'aliquot_id': '38404eb4-20a6-4...
# 2    [{'aliquots': [{'aliquot_id': '15218d5b-fc40-4...
# 3    [{'aliquots': [{'aliquot_id': '47e8d70c-646d-4...
# 4    [{'aliquots': [{'aliquot_id': '333e24c9-ec45-4...
# ..                                                 ...
# 143  [{'aliquots': [{'aliquot_id': 'a3402806-a9ec-4...
# 144  [{'aliquots': [{'aliquot_id': '9d1789f8-d629-4...
# 145  [{'aliquots': [{'aliquot_id': '9c36e4e9-a971-4...
# 146  [{'aliquots': [{'aliquot_id': '4059003c-b576-4...
# 147  [{'aliquots': [{'aliquot_id': '030c9e59-35a2-4...
#
# [148 rows x 12 columns]

# %% [markdown]
# ## Transform PDC Case into CRDCH Research Subject
#
# The transformation being demonstrated here is the transformation of a PDC case into a CCDH Research Subject. For the purposes of this demo, we will transform two components, specifically, the diagnosis information from a PDC case into a CRDCH Diagnosis. And also the top level specimen component into CCDH Specimens.
#
# TODO: Similar to specimen, other top level components like samples, aliquots, analytes, slides can also be transformed.

# %%
import crdch_model
import utils

def create_stage_observation(type, value):
    """Create a CCDHCancerStageObservation from a type of observation and a codeable concept."""
    # As with the body site example above, we need to map PDC values into the values
    # allowed under the CRDCH model.
    stage_mappings = {
        'not reported': 'Not Reported',
        'unknown': 'Unknown',
        'stage i': 'Stage I',
        'stage ii': 'Stage II',
        'stage iii': 'Stage III',
        'stage iva': 'Stage IVA',
        'stage ivb': 'Stage IVB',
        'stage ivc': 'Stage IVC',
    }
    
    # Check if any of the stages are named with lower case Roman numerals
    # rather than upper case.
    if value in stage_mappings:
        return crdch_model.CancerStageObservation(
            observation_type=utils.codeable_concept(
                code=type,
                system="https://example.org/CancerStageObservation"
            ),
            value_codeable_concept=utils.codeable_concept(
                code=stage_mappings[value],
                system="https://example.org/CancerStageObservation"
            )
        )
    
    return crdch_model.CancerStageObservation(
        observation_type=utils.codeable_concept(
            code=type,
            system="https://example.org/CancerStageObservation"
        ),
        value_codeable_concept=utils.codeable_concept(
            code=value,
            system="https://example.org/CancerStageObservation"
        )
    )
    
def create_stage_from_pdc(diagnosis):
    # Create an observation set
    # method_type information not present in case
    obs = crdch_model.CancerStageObservationSet()
    
    # Add observations for every type of observation in the PDC diagnosis.
    if diagnosis.get('tumor_stage') is not None:
        obs.observations.append(create_stage_observation('Overall', diagnosis.get('tumor_stage')))
        
    if diagnosis.get('ajcc_clinical_stage') is not None:
        obs.observations.append(create_stage_observation('Clinical Overall', diagnosis.get('ajcc_clinical_stage')))
        
    if diagnosis.get('ajcc_clinical_t') is not None:
        obs.observations.append(create_stage_observation('Clinical Tumor (T)', diagnosis.get('ajcc_clinical_t')))
        
    if diagnosis.get('ajcc_clinical_n') is not None:
        obs.observations.append(create_stage_observation('Clinical Node (N)', diagnosis.get('ajcc_clinical_n')))
        
    if diagnosis.get('ajcc_clinical_m') is not None:
        obs.observations.append(create_stage_observation('Clinical Metastasis (M)', diagnosis.get('ajcc_clinical_m')))
    
    if diagnosis.get('ajcc_pathologic_stage') is not None:
        obs.observations.append(create_stage_observation('Pathological Overall', diagnosis.get('ajcc_pathologic_stage')))
        
    if diagnosis.get('ajcc_pathologic_t') is not None:
        obs.observations.append(create_stage_observation('Pathological Tumor (T)', diagnosis.get('ajcc_pathologic_t')))
        
    if diagnosis.get('ajcc_pathologic_n') is not None:
        obs.observations.append(create_stage_observation('Pathological Node (N)', diagnosis.get('ajcc_pathologic_n')))
        
    if diagnosis.get('ajcc_pathologic_m') is not None:
        obs.observations.append(create_stage_observation('Pathological Metastasis (M)', diagnosis.get('ajcc_pathologic_m')))
    
    return obs

# Test transform with the diagnosis from the first loaded case.
# Note that the resulting CancerStageObservationSet contains descriptions for the concepts included in it.
example_observation_set = create_stage_from_pdc(pdc_head_and_mouth[131]['diagnoses'][0])
example_observation_set
# Out:
# CancerStageObservationSet(id=None, category=None, focus=[], subject=None, method_type=[], performed_by=None, observations=[CancerStageObservation(observation_type=CodeableConcept(coding=[Coding(code='Overall', system='https://example.org/CancerStageObservation', label=None, system_version=None, value_set=None, value_set_version=None, tag=[])], text=None), value_codeable_concept=CodeableConcept(coding=[Coding(code='Stage IV', system='https://example.org/CancerStageObservation', label=None, system_version=None, value_set=None, value_set_version=None, tag=[])], text=None), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, value_entity=None), CancerStageObservation(observation_type=CodeableConcept(coding=[Coding(code='Clinical Metastasis (M)', system='https://example.org/CancerStageObservation', label=None, system_version=None, value_set=None, value_set_version=None, tag=[])], text=None), value_codeable_concept=CodeableConcept(coding=[Coding(code='M0', system='https://example.org/CancerStageObservation', label=None, system_version=None, value_set=None, value_set_version=None, tag=[])], text=None), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, value_entity=None)])

# %% [markdown]
# Use the LinkML YAML dumper to format and display the Cancer Stage Observation Set as a YAML string.

# %%
from linkml_runtime.dumpers import yaml_dumper

print(yaml_dumper.dumps(example_observation_set))
# Out:
# observations:
# - observation_type:
#     coding:
#     - code: Overall
#       system: https://example.org/CancerStageObservation
#   value_codeable_concept:
#     coding:
#     - code: Stage IV
#       system: https://example.org/CancerStageObservation
# - observation_type:
#     coding:
#     - code: Clinical Metastasis (M)
#       system: https://example.org/CancerStageObservation
#   value_codeable_concept:
#     coding:
#     - code: M0
#       system: https://example.org/CancerStageObservation

# %% [markdown]
# ## Transform PDC Diagnosis into CRDCH Diagnosis
#
# We first define transformation methods for creating a CCDH BodySite from the `primary_site` in the PDC case, and also for transforming sample information from the case into a CCDH Specimen. Using these two methods we can define a combined diagnosis transformation method which can transform a full PDC diagnosis into a CCDH Diagnosis.

# %%
def create_body_site(site_name):
    """Create a CCDH BodySite based on the name of a site in the human body."""
    
    # Accept 'None'.
    if site_name is None:
        return None
    
    # Some body sites are not currently included in the CCDH model. We will need to translate these sites
    # into values that *are* included in the CCDH model.
    site_mappings = {
        'Larynx, NOS': crcdh_model.EnumCRDCHBodySiteSite.Larynx
    }
    
    # Map values if needed. Otherwise, pass them through unmapped.
    if site_name in site_mappings:
        return crcdh_model.BodySite(
            utils.codeable_concept(
                code=site_mappings[site_name],
                system="https://example.org/BodySite"
            )
        )
    
    return crcdh_model.BodySite(
        utils.codeable_concept(
            code=site_name,
            system="https://example.org/BodySite"
        )
    )

def transform_sample_to_specimen(sample):
    """A method for transforming a PDC Sample into CCDH Specimen."""
    
    specimen = crcdh_model.Specimen(id = sample.get('sample_id'))
    specimen.source_material_type = sample.get('sample_type')
    specimen.general_tissue_morphology = sample.get('tissue_type')
    specimen.specific_tissue_morphology = sample.get('tumor_code')
    specimen.tumor_status_at_collection = sample.get('tumor_descriptor')

    return specimen

def transform_diagnosis(diagnosis, case):
    ccdh_diagnosis = crcdh_model.Diagnosis(
        id=diagnosis.get('diagnosis_id'),
        condition=utils.codeable_concept(
            code=diagnosis.get('primary_diagnosis'),
            system="https://example.org/PrimaryDiagnosis"
        ),
        morphology=utils.codeable_concept(
            code=diagnosis.get('morphology'),
            system="https://example.org/Morphology"
        ),
        grade=diagnosis.get('grade'),
        stage=create_stage_from_pdc(diagnosis),
        age_at_diagnosis=diagnosis.get('year_of_diagnosis'),
        related_specimen=[
            transform_sample_to_specimen(
                sample
            ) for sample in case.get('samples')
        ]
    )
    ccdh_diagnosis.identifier = [
        crcdh_model.Identifier(
            system='PDC-submitter-id',
            value=diagnosis.get('diagnosis_submitter_id')
        )
    ]
    
    if 'primary_site' in case and case['primary_site'] != '':
        body_site = create_body_site(case['primary_site'])
        if body_site is not None:
            ccdh_diagnosis.metastatic_site.append(body_site)

    return ccdh_diagnosis

example_diagnosis = transform_diagnosis(pdc_head_and_mouth[131]['diagnoses'][0], pdc_head_and_mouth[131])
print(yaml_dumper.dumps(example_diagnosis))
# Out:
# id: df520aac-8f98-11ea-b1fd-0aad30af8a83
# identifier:
# - value: C3N-03889-DX
#   system: PDC-submitter-id
# condition:
#   coding:
#   - code: Squamous cell carcinoma, NOS
#     system: https://example.org/PrimaryDiagnosis
# metastatic_site:
# - site:
#     coding:
#     - code: Head and Neck
#       system: https://example.org/BodySite
# stage:
# - observations:
#   - observation_type:
#       coding:
#       - code: Overall
#         system: https://example.org/CancerStageObservation
#     value_codeable_concept:
#       coding:
#       - code: Stage IV
#         system: https://example.org/CancerStageObservation
#   - observation_type:
#       coding:
#       - code: Clinical Metastasis (M)
#         system: https://example.org/CancerStageObservation
#     value_codeable_concept:
#       coding:
#       - code: M0
#         system: https://example.org/CancerStageObservation
# morphology:
#   coding:
#   - code: 8070/3
#     system: https://example.org/Morphology
# related_specimen:
# - id: df502f10-8f98-11ea-b1fd-0aad30af8a83
#   source_material_type: Primary Tumor
#   general_tissue_morphology: Tumor
