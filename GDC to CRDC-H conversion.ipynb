# %% [markdown]
# # GDC to CRDC-H Conversion
#
# This notebook demonstrates one method for converting GDC data into CRDC-H instance data: by reading node data as JSON and writing it out in the LinkML model. The LinkML can be used to [generate](https://github.com/linkml/linkml#python-dataclasses) [Python DataClasses](https://docs.python.org/3/library/dataclasses.html), which can then be exported in several data publication format, such as JSON or RDF.

# %% [markdown]
# ## Setup
#
# We start by installing the [LinkML](https://pypi.org/project/linkml/) and [pandas](https://pypi.org/project/pandas/) packages.

# %%
import sys

# Install LinkML.
# !{sys.executable} -m pip install git+https://github.com/linkml/linkml.git

# Install pandas.
# !{sys.executable} -m pip install pandas
# Out:
# Collecting git+https://github.com/linkml/linkml.git
#   Cloning https://github.com/linkml/linkml.git to /private/var/folders/j7/wl1qrc1n7fv9vnszw_0dsm680000gn/T/pip-req-build-_ccxl0je
#   Running command git clone -q https://github.com/linkml/linkml.git /private/var/folders/j7/wl1qrc1n7fv9vnszw_0dsm680000gn/T/pip-req-build-_ccxl0je
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pyld in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (2.0.3)
# Requirement already satisfied: hbreader in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (0.9.1)
# Requirement already satisfied: pyshexc>=0.8.3 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (0.8.3)
# Requirement already satisfied: isodate>=0.6.0 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (0.6.0)
# Requirement already satisfied: rdflib>=5.0.0 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (5.0.0)
# Requirement already satisfied: pyshex>=0.7.20 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (0.7.20)
# Requirement already satisfied: linkml-model>=0.0.10 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (0.0.10)
# Requirement already satisfied: parse in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (1.19.0)
# Requirement already satisfied: click~=7.0 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (7.1.2)
# Requirement already satisfied: pyyaml~=5.1 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (5.3.1)
# Requirement already satisfied: watchdog>=0.9.0 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (2.1.0)
# Requirement already satisfied: sqlalchemy in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (1.4.13)
# Requirement already satisfied: requests>=2.22 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (2.24.0)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (3.2.0)
# Requirement already satisfied: prefixcommons>=0.1.7 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (0.1.9)
# Requirement already satisfied: python-dateutil in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (2.8.1)
# Requirement already satisfied: prologterms>=0.0.6 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (0.0.6)
# Collecting argparse>=1.4.0
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: jsonasobj>=1.3.1 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (1.3.1)
# Requirement already satisfied: pyjsg>=0.11.6 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (0.11.6)
# Requirement already satisfied: rdflib-jsonld>=0.5.0 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (0.5.0)
# Requirement already satisfied: graphviz>=0.10.1 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (0.16)
# Requirement already satisfied: rdflib-pyld-compat in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml==0.0.8.dev53) (0.1.0)
# Requirement already satisfied: six in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from isodate>=0.6.0->linkml==0.0.8.dev53) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from jsonschema>=3.0.1->linkml==0.0.8.dev53) (20.2.0)
# Requirement already satisfied: setuptools in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from jsonschema>=3.0.1->linkml==0.0.8.dev53) (49.2.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from jsonschema>=3.0.1->linkml==0.0.8.dev53) (0.17.3)
# Requirement already satisfied: antlr4-python3-runtime~=4.9 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyjsg>=0.11.6->linkml==0.0.8.dev53) (4.9.2)
# Requirement already satisfied: shexjsg>=0.7.1 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml==0.0.8.dev53) (0.7.1)
# Requirement already satisfied: urllib3 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml==0.0.8.dev53) (1.25.11)
# Requirement already satisfied: sparqlslurper~=0.4 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml==0.0.8.dev53) (0.4.1)
# Requirement already satisfied: sparqlwrapper>=1.8.5 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml==0.0.8.dev53) (1.8.5)
# Requirement already satisfied: cfgraph>=0.2.1 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml==0.0.8.dev53) (0.2.1)
# Requirement already satisfied: pyparsing in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from rdflib>=5.0.0->linkml==0.0.8.dev53) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from requests>=2.22->linkml==0.0.8.dev53) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from requests>=2.22->linkml==0.0.8.dev53) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from requests>=2.22->linkml==0.0.8.dev53) (2.10)
# Requirement already satisfied: frozendict in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyld->linkml==0.0.8.dev53) (2.0.2)
# Requirement already satisfied: cachetools in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyld->linkml==0.0.8.dev53) (4.2.2)
# Requirement already satisfied: lxml in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyld->linkml==0.0.8.dev53) (4.6.3)
# Requirement already satisfied: testfixtures in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from rdflib-pyld-compat->linkml==0.0.8.dev53) (6.17.1)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from sqlalchemy->linkml==0.0.8.dev53) (1.0.0)
# Building wheels for collected packages: linkml
#   Building wheel for linkml (PEP 517) ... done
#   Created wheel for linkml: filename=linkml-0.0.8.dev53-py3-none-any.whl size=134767 sha256=af07098044a57035c0b677e48c092f4fe6ab8968d16a2a95a253c691765577b2
#   Stored in directory: /private/var/folders/j7/wl1qrc1n7fv9vnszw_0dsm680000gn/T/pip-ephem-wheel-cache-g3ndz0qj/wheels/21/05/05/1c80d4ffd52d0f4008be23eb9f6ee8f487b736afef324dbf19
# Successfully built linkml
# Installing collected packages: argparse, linkml
#   Attempting uninstall: linkml
#     Found existing installation: linkml 0.1.1.dev2
#     Uninstalling linkml-0.1.1.dev2:
#       Successfully uninstalled linkml-0.1.1.dev2
# Successfully installed argparse-1.4.0 linkml-0.0.8.dev53
# Requirement already satisfied: pandas in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (1.2.4)
# Requirement already satisfied: numpy>=1.16.5 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pandas) (1.20.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %% [markdown]
# ## Loading GDC data as an example
#
# We start by loading the result of a GDC query in JSON.

# %%
import json
import pandas

with open('head-and-mouth/gdc-head-and-mouth.json') as file:
    gdc_head_and_mouth = json.load(file)
    
pandas.DataFrame(gdc_head_and_mouth)
# Out:
#                                            aliquot_ids  \
# 0               [cfcde639-3045-4f66-84a6-ec74b090a5b6]
# 1    [9069bdd7-e16a-462c-881c-581c8aab6910, a74915f...
# 2    [8f695cd3-01dd-4601-8b17-37cf40514422, f0e325f...
# 3    [1265fd12-4706-43b0-84f3-d16d46f20963, 3443e1b...
# 4    [59b70846-64f0-489e-8ea5-84a347aedeb8, c8e46ce...
# ..                                                 ...
# 555  [1d3b16fd-f98b-45ef-a423-861975f098b6, 0eabe3e...
# 556             [96f09bc8-a194-482c-bd17-baf28739e4f8]
# 557  [cd211e89-63f7-44f0-8a76-51703ae45112, 866292c...
# 558  [0c2f310b-fa59-4f6f-894a-dad920214004, 6ddd527...
# 559  [53800455-66fa-4193-9308-390fd663a40c, 9c20138...
#
#                                   case_id                  created_datetime  \
# 0    cd7e514f-71ba-4cc1-b74a-a22c6248169c  2017-06-01T08:57:57.249456-05:00
# 1    9023c9bf-02a0-4396-8161-304089957b62                              None
# 2    55f96a9c-e2c8-4243-8a7e-94bc6fab73a6                              None
# 3    c9a36eb5-ac3e-424e-bc2e-303de7105957                              None
# 4    4cffea0b-90a7-4c86-a73f-bb8feca3ada7                              None
# ..                                    ...                               ...
# 555  97640ef0-0259-4244-95ba-48d28c60b372                              None
# 556  422a72e7-fe76-411d-b59e-1f0f0812c3cf  2018-09-13T13:42:10.444091-05:00
# 557  4b50aea4-4ad1-4bf6-9cf1-984c28a99c84                              None
# 558  0394060d-010e-405f-983d-db525f01f2c3                              None
# 559  df132eb8-174b-4427-a16b-953e0f28bf2f                              None
#
#                                              diagnoses  \
# 0    [{'age_at_diagnosis': 19592, 'classification_o...
# 1    [{'age_at_diagnosis': 24286, 'ajcc_clinical_m'...
# 2    [{'age_at_diagnosis': 20992, 'ajcc_clinical_m'...
# 3    [{'age_at_diagnosis': 21886, 'ajcc_clinical_m'...
# 4    [{'age_at_diagnosis': 14190, 'ajcc_clinical_m'...
# ..                                                 ...
# 555  [{'age_at_diagnosis': 19621, 'ajcc_clinical_m'...
# 556  [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 557  [{'age_at_diagnosis': 21731, 'ajcc_clinical_m'...
# 558  [{'age_at_diagnosis': 23640, 'ajcc_clinical_m'...
# 559  [{'age_at_diagnosis': 20763, 'ajcc_clinical_m'...
#
#                               diagnosis_ids                  disease_type  \
# 0    [5d2d67d1-4611-4a18-9a66-89823aaa8e3c]  Adenomas and Adenocarcinomas
# 1    [706b1290-3a85-54ea-a123-e8bd14b085bc]       Squamous Cell Neoplasms
# 2    [40954a8e-e4c2-5604-937b-0a79ac7489d2]       Squamous Cell Neoplasms
# 3    [48e8dd81-ed4d-5c54-af66-84e86477d5c8]       Squamous Cell Neoplasms
# 4    [1da5c51a-ee25-51a6-a4c2-27d8fdcbe24e]       Squamous Cell Neoplasms
# ..                                      ...                           ...
# 555  [b725e6d2-92c0-5585-9de7-14bb623b472e]       Squamous Cell Neoplasms
# 556  [842d6984-7c03-4ab6-95db-42fa2ea699db]       Squamous Cell Neoplasms
# 557  [95d85e5a-b82c-59f8-b7ad-710e019cdebc]       Squamous Cell Neoplasms
# 558  [7a67eecc-6f46-5181-8b64-c022d0fd0060]       Squamous Cell Neoplasms
# 559  [d20b4711-8757-5d39-a8cc-b8ece86592cd]       Squamous Cell Neoplasms
#
#                                        id primary_site  \
# 0    cd7e514f-71ba-4cc1-b74a-a22c6248169c  Nasopharynx
# 1    9023c9bf-02a0-4396-8161-304089957b62       Larynx
# 2    55f96a9c-e2c8-4243-8a7e-94bc6fab73a6       Larynx
# 3    c9a36eb5-ac3e-424e-bc2e-303de7105957   Oropharynx
# 4    4cffea0b-90a7-4c86-a73f-bb8feca3ada7       Tonsil
# ..                                    ...          ...
# 555  97640ef0-0259-4244-95ba-48d28c60b372       Larynx
# 556  422a72e7-fe76-411d-b59e-1f0f0812c3cf       Larynx
# 557  4b50aea4-4ad1-4bf6-9cf1-984c28a99c84  Hypopharynx
# 558  0394060d-010e-405f-983d-db525f01f2c3  Hypopharynx
# 559  df132eb8-174b-4427-a16b-953e0f28bf2f       Larynx
#
#                                             sample_ids  \
# 0               [bdc73f48-dc0b-487d-abbe-e3a977b6830a]
# 1    [8b2588c8-4261-492b-b173-2490a5de668f, badeaed...
# 2    [a7692585-a129-4671-bfe5-98342a326776, b069c55...
# 3    [256469d0-5f36-4966-bf4f-3b4297e55f43, bd90f96...
# 4    [1ed245de-fea4-42c9-9197-773bcd12d2a8, 665d4bf...
# ..                                                 ...
# 555  [fb06ae75-8516-4cdc-ba9e-093444907fc7, 5162217...
# 556             [6f9eeaa3-8bd1-479c-a0fc-98317eb458dc]
# 557  [1077bf93-cf23-41db-925c-c633921894cc, 4a0d79f...
# 558  [5c2b4403-cdd4-4550-ba01-d8ebad9fcbc8, 4467ee1...
# 559  [c22e9fe0-a052-4c6f-9fb2-e58289277e2a, 6bd5367...
#
#                                                samples  ...  \
# 0    [{'created_datetime': '2017-06-01T10:44:57.790...  ...
# 1    [{'created_datetime': '2018-05-17T12:19:46.292...  ...
# 2    [{'composition': None, 'created_datetime': Non...  ...
# 3    [{'composition': None, 'created_datetime': Non...  ...
# 4    [{'created_datetime': '2018-05-17T12:19:46.292...  ...
# ..                                                 ...  ...
# 555  [{'composition': None, 'created_datetime': Non...  ...
# 556  [{'biospecimen_anatomic_site': None, 'biospeci...  ...
# 557  [{'created_datetime': '2018-05-17T12:19:46.292...  ...
# 558  [{'created_datetime': '2018-05-17T12:19:46.292...  ...
# 559  [{'composition': None, 'created_datetime': Non...  ...
#
#                                   submitter_sample_ids  \
# 0                                      [AD6426_sample]
# 1    [TCGA-CN-6012-10A, TCGA-CN-6012-01A, TCGA-CN-6...
# 2    [TCGA-CV-7261-01Z, TCGA-CV-7261-11A, TCGA-CV-7...
# 3    [TCGA-BA-A6DL-10A, TCGA-BA-A6DL-01Z, TCGA-BA-A...
# 4    [TCGA-CN-5365-01Z, TCGA-CN-5365-10A, TCGA-CN-5...
# ..                                                 ...
# 555  [TCGA-CN-4738-01A, TCGA-CN-4738-01Z, TCGA-CN-4...
# 556                          [GENIE-DFCI-010671-11105]
# 557  [TCGA-TN-A7HL-01A, TCGA-TN-A7HL-01Z, TCGA-TN-A...
# 558  [TCGA-BB-A5HY-10A, TCGA-BB-A5HY-01A, TCGA-BB-A...
# 559  [TCGA-CV-7430-11A, TCGA-CV-7430-01A, TCGA-CV-7...
#
#                                    submitter_slide_ids  \
# 0                                       [AD6426_slide]
# 1    [TCGA-CN-6012-01Z-00-DX1, TCGA-CN-6012-01A-01-...
# 2    [TCGA-CV-7261-01A-01-TS1, TCGA-CV-7261-01Z-00-...
# 3    [TCGA-BA-A6DL-01Z-00-DX1, TCGA-BA-A6DL-01A-02-...
# 4    [TCGA-CN-5365-01Z-00-DX1, TCGA-CN-5365-01A-01-...
# ..                                                 ...
# 555  [TCGA-CN-4738-01Z-00-DX1, TCGA-CN-4738-01A-01-...
# 556                                                NaN
# 557  [TCGA-TN-A7HL-01Z-00-DX1, TCGA-TN-A7HL-01A-01-...
# 558  [TCGA-BB-A5HY-01Z-00-DX1, TCGA-BB-A5HY-01A-01-...
# 559  [TCGA-CV-7430-01A-01-BS1, TCGA-CV-7430-01Z-00-...
#
#                      updated_datetime  \
# 0    2018-10-25T11:34:27.425461-05:00
# 1    2019-08-06T14:25:25.511101-05:00
# 2    2019-08-06T14:26:28.608672-05:00
# 3    2019-08-06T14:25:14.243346-05:00
# 4    2019-08-06T14:25:25.511101-05:00
# ..                                ...
# 555  2019-08-06T14:25:25.511101-05:00
# 556  2019-11-18T13:54:59.294543-06:00
# 557  2019-08-06T14:27:14.277986-05:00
# 558  2019-08-06T14:25:25.511101-05:00
# 559  2019-08-06T14:26:28.608672-05:00
#
#                                            analyte_ids  \
# 0                                                  NaN
# 1    [80c6fde2-b6bb-4f40-908a-f116c466d296, 6f77017...
# 2    [a72f2de7-eb40-4818-a104-edb508d5517b, e8120e5...
# 3    [ec4487c1-6976-4161-9236-5e6810ed31b7, ffd1e03...
# 4    [d46b5e9b-3652-45a1-a91d-46277aea3916, 35122dd...
# ..                                                 ...
# 555  [4dc95dbe-b10f-4d6e-9413-ae47a0a49865, e637c1c...
# 556                                                NaN
# 557  [6ffc3548-d593-47ab-adf8-6d73075b5fa0, 9426e53...
# 558  [ee7f98c5-9c78-4bbe-b44a-a9e357a18058, 2d82983...
# 559  [9645e3d2-e245-4d0b-a4f3-a14ec7508b28, a5a93bc...
#
#                                            portion_ids  \
# 0                                                  NaN
# 1    [bada788e-5112-4d21-a079-72729bd0cc83, fe24eea...
# 2    [177fa10b-0135-468d-b5a3-6f30cc3cd390, f51d76a...
# 3    [7f327ef6-4fe6-40c8-aac7-731e051177bb, 2a4b0be...
# 4    [38c5a4c1-6d01-4885-ba35-0032e6b835b0, 516f802...
# ..                                                 ...
# 555  [56c7d4e4-5703-4686-98b1-0c3125e5913e, 60d72bd...
# 556                                                NaN
# 557  [cd5864c8-b4e0-4405-b7df-1e0a51865670, f9ef56b...
# 558  [9576f242-6874-4df9-8744-e0755d565358, 8842cbd...
# 559  [71900a0b-da4a-444c-bfd5-4ba5e530761f, 06546fd...
#
#                                  submitter_analyte_ids  \
# 0                                                  NaN
# 1    [TCGA-CN-6012-01A-11D, TCGA-CN-6012-10A-01W, T...
# 2    [TCGA-CV-7261-10A-01D, TCGA-CV-7261-01A-11R, T...
# 3    [TCGA-BA-A6DL-01A-21D, TCGA-BA-A6DL-01A-21R, T...
# 4    [TCGA-CN-5365-01A-01D, TCGA-CN-5365-01A-01W, T...
# ..                                                 ...
# 555  [TCGA-CN-4738-01A-02D, TCGA-CN-4738-10A-01W, T...
# 556                                                NaN
# 557  [TCGA-TN-A7HL-01A-11R, TCGA-TN-A7HL-01A-11D, T...
# 558  [TCGA-BB-A5HY-01A-11W, TCGA-BB-A5HY-01A-11D, T...
# 559  [TCGA-CV-7430-01A-11D, TCGA-CV-7430-10A-01D, T...
#
#                                  submitter_portion_ids  \
# 0                                                  NaN
# 1    [TCGA-CN-6012-01A-13-2072-20, TCGA-CN-6012-10A...
# 2    [TCGA-CV-7261-10A-01, TCGA-CV-7261-01A-13-2074...
# 3    [TCGA-BA-A6DL-10A-01, TCGA-BA-A6DL-01A-11-A45L...
# 4    [TCGA-CN-5365-10A-01, TCGA-CN-5365-01A-21-2072...
# ..                                                 ...
# 555  [TCGA-CN-4738-01A-31-2072-20, TCGA-CN-4738-01A...
# 556                                                NaN
# 557  [TCGA-TN-A7HL-01A-21-A45L-20, TCGA-TN-A7HL-10A...
# 558         [TCGA-BB-A5HY-01A-11, TCGA-BB-A5HY-10A-01]
# 559  [TCGA-CV-7430-01A-13-2074-20, TCGA-CV-7430-11A...
#
#     days_to_lost_to_followup                  index_date lost_to_followup
# 0                        NaN                         NaN              NaN
# 1                        NaN                         NaN              NaN
# 2                        NaN                         NaN              NaN
# 3                        NaN                         NaN              NaN
# 4                        NaN                         NaN              NaN
# ..                       ...                         ...              ...
# 555                      NaN                         NaN              NaN
# 556                      NaN  Initial Genomic Sequencing              NaN
# 557                      NaN                         NaN              NaN
# 558                      NaN                         NaN              NaN
# 559                      NaN                         NaN              NaN
#
# [560 rows x 25 columns]

# %% [markdown]
# ## Loading the Python classes for the CRDC-H model
#
# We previously generated the Python DataClasses for the CRDC-H model. We can now load these DataClasses to

# %%
# Install LinkML.
# !{sys.executable} -m pip install git+https://github.com/cancerDHC/ccdhmodel.git@reorganize-to-linkml-template

# %% [markdown]
# ## Convert the input data in pieces
#
# For demonstrative purposes, we'll start by translating pieces of this record into CRDC-H instance data.
#
# Let's start with the samples in the `samples` key (which correspond to a [Specimen](https://cancerdhc.github.io/ccdhmodel/entities/Specimen.html) in the CRDC-H model).

# %%
firstSample = gdc_head_and_mouth[0]['samples'][0]
firstSample
# Out:
# {'created_datetime': '2017-06-01T10:44:57.790971-05:00',
#  'sample_id': 'bdc73f48-dc0b-487d-abbe-e3a977b6830a',
#  'sample_type': 'Metastatic',
#  'state': 'released',
#  'submitter_id': 'AD6426_sample',
#  'tissue_type': 'Not Reported',
#  'tumor_descriptor': 'Metastatic',
#  'updated_datetime': '2018-11-15T21:10:03.529893-06:00'}

# %%
firstSpecimen = entities.Specimen(
    id = firstSample['sample_id'],
    analyte_type = entities.CodeableConcept(
        entities.Coding(
            firstSample['sample_type']
        )
    )
)

firstSpecimen
# Out:
# Specimen(id='bdc73f48-dc0b-487d-abbe-e3a977b6830a', identifier=[], associated_project=None, specimen_type=None, analyte_type=CodeableConcept(coding=[Coding(code='Metastatic', display=None, system=None, version=None)], text=None), derived_from_specimen=[], derived_from_subject=None, source_material_type=None, cellular_composition=None, general_tissue_morphology=None, specific_tissue_morphology=None, current_weight=[], current_volume=[], analyte_concentration=None, analyte_concentration_method=None, matched_normal_flag=[], qualification_status_flag=None)

# %% [markdown]
# ## Exporting CRDC-H data as RDF
#
# LinkML supports this via JSON-LD.

# %%
from linkml.generators.jsonldcontextgen import ContextGenerator
from linkml.dumpers.json_dumper import dumps

with open('crdch/entities.yaml') as file:
    crdchEntities = file.read()
    
jsonldContext = ContextGenerator('crdch/entities.yaml').serialize()

jsonld = dumps(firstSpecimen, jsonldContext)
print(''.join(jsonld))
# Out:
# {
#   "id": "bdc73f48-dc0b-487d-abbe-e3a977b6830a",
#   "analyte_type": {
#     "coding": [
#       {
#         "code": "Metastatic"
#       }
#     ]
#   },
#   "@type": "Specimen",
#   "@context": {
#     "biolinkml": "https://w3id.org/biolink/biolinkml/",
#     "ccdh": "https://example.org/ccdh/",
#     "types": "https://example.org/ccdh/datatypes/",
#     "@vocab": "https://example.org/ccdh/",
#     "coding": {
#       "@type": "@id"
#     },
#     "type": {
#       "@type": "@id"
#     },
#     "identifier": {
#       "@type": "@id"
#     },
#     "taxon": {
#       "@type": "@id"
#     },
#     "comparator": {
#       "@type": "@id"
#     },
#     "unit": {
#       "@type": "@id"
#     },
#     "value": {
#       "@type": "xsd:decimal"
#     },
#     "associated_patient": {
#       "@type": "@id"
#     },
#     "associated_project": {
#       "@type": "@id"
#     },
#     "primary_disease_site": {
#       "@type": "@id"
#     },
#     "primary_disease_type": {
#       "@type": "@id"
#     },
#     "analyte_concentration": {
#       "@type": "@id"
#     },
#     "analyte_concentration_method": {
#       "@type": "@id"
#     },
#     "analyte_type": {
#       "@type": "@id"
#     },
#     "cellular_composition": {
#       "@type": "@id"
#     },
#     "current_volume": {
#       "@type": "@id"
#     },
#     "current_weight": {
#       "@type": "@id"
#     },
#     "derived_from_specimen": {
#       "@type": "@id"
#     },
#     "derived_from_subject": {
#       "@type": "@id"
#     },
#     "general_tissue_morphology": {
#       "@type": "@id"
#     },
#     "matched_normal_flag": {
#       "@type": "@id"
#     },
#     "qualification_status_flag": {
#       "@type": "@id"
#     },
#     "source_material_type": {
#       "@type": "@id"
#     },
#     "specific_tissue_morphology": {
#       "@type": "@id"
#     },
#     "specimen_type": {
#       "@type": "@id"
#     },
#     "CodeableConcept": {
#       "@id": "types:CodeableConcept"
#     },
#     "Coding": {
#       "@id": "types:Coding"
#     },
#     "Identifier": {
#       "@id": "types:Identifier"
#     },
#     "Quantity": {
#       "@id": "types:Quantity"
#     }
#   }
# }

# %%
# We can read this JSON-LD in Turtle.
from rdflib import Graph

g = Graph()
g.parse(data=jsonld, format="json-ld")
rdfAsTurtle = g.serialize(format="turtle").decode()
print(rdfAsTurtle)
# Out:
# @prefix : <https://example.org/ccdh/> .
# @prefix ccdh: <https://example.org/ccdh/> .
#
# [] a ccdh:Specimen ;
#     ccdh:analyte_type [ ccdh:coding [ ccdh:code "Metastatic" ] ] ;
#     ccdh:id "bdc73f48-dc0b-487d-abbe-e3a977b6830a" .

# %% [markdown]
# ## Incorporating PDC data

# %%
with open('head-and-mouth/pdc-head-and-mouth.json') as file:
    pdc_head_and_mouth = json.load(file)
    
pandas.DataFrame(pdc_head_and_mouth)
# Out:
#                                   case_id case_submitter_id  \
# 0    0232701d-6d00-440c-af6c-5899fbbf4142           OSCC_13
# 1    0e943de7-c277-48f2-8fa9-b2e836b03c2c           OSCC_25
# 2    1104505a-9890-49ce-8d7d-7a8070261324           OSCC_23
# 3    195cd133-0d53-402d-b31c-3d4fe0481858           OSCC_37
# 4    1df726a4-8520-4474-8c00-d238a7384be1           OSCC_06
# ..                                    ...               ...
# 143  df6bef95-c233-4b10-b321-36ef4e79b5d4           OSCC_40
# 144  e11e9155-4ac6-43dc-b8e5-1be822cd2dab           OSCC_47
# 145  ea7c9fbd-8353-4f3c-9fea-2fba79140536           OSCC_56
# 146  f581075d-1b69-4812-9fe4-2bde4aad8bf2           OSCC_38
# 147  ff5a631f-93b9-486e-beb9-d16737db8c9e           OSCC_58
#
#     days_to_lost_to_followup  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ..                       ...
# 143                     None
# 144                     None
# 145                     None
# 146                     None
# 147                     None
#
#                                           demographics  \
# 0    [{'cause_of_death': None, 'days_to_birth': Non...
# 1    [{'cause_of_death': None, 'days_to_birth': Non...
# 2    [{'cause_of_death': None, 'days_to_birth': Non...
# 3    [{'cause_of_death': None, 'days_to_birth': Non...
# 4    [{'cause_of_death': None, 'days_to_birth': Non...
# ..                                                 ...
# 143  [{'cause_of_death': None, 'days_to_birth': Non...
# 144  [{'cause_of_death': None, 'days_to_birth': Non...
# 145  [{'cause_of_death': None, 'days_to_birth': Non...
# 146  [{'cause_of_death': None, 'days_to_birth': Non...
# 147  [{'cause_of_death': None, 'days_to_birth': Non...
#
#                                              diagnoses  \
# 0    [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 1    [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 2    [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 3    [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 4    [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# ..                                                 ...
# 143  [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 144  [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 145  [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 146  [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 147  [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
#
#                      disease_type externalReferences index_date  \
# 0    Oral Squamous Cell Carcinoma                 []       None
# 1    Oral Squamous Cell Carcinoma                 []       None
# 2    Oral Squamous Cell Carcinoma                 []       None
# 3    Oral Squamous Cell Carcinoma                 []       None
# 4    Oral Squamous Cell Carcinoma                 []       None
# ..                            ...                ...        ...
# 143  Oral Squamous Cell Carcinoma                 []       None
# 144  Oral Squamous Cell Carcinoma                 []       None
# 145  Oral Squamous Cell Carcinoma                 []       None
# 146  Oral Squamous Cell Carcinoma                 []       None
# 147  Oral Squamous Cell Carcinoma                 []       None
#
#     lost_to_followup   primary_site  \
# 0               None  Head and Neck
# 1               None  Head and Neck
# 2               None  Head and Neck
# 3               None  Head and Neck
# 4               None  Head and Neck
# ..               ...            ...
# 143             None  Head and Neck
# 144             None  Head and Neck
# 145             None  Head and Neck
# 146             None  Head and Neck
# 147             None  Head and Neck
#
#                                   project_submitter_id  \
# 0    Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 1    Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 2    Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 3    Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 4    Oral Squamous Cell Carcinoma - Chang Gung Univ...
# ..                                                 ...
# 143  Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 144  Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 145  Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 146  Oral Squamous Cell Carcinoma - Chang Gung Univ...
# 147  Oral Squamous Cell Carcinoma - Chang Gung Univ...
#
#                                                samples
# 0    [{'aliquots': [{'aliquot_id': '426a2696-f073-4...
# 1    [{'aliquots': [{'aliquot_id': '38404eb4-20a6-4...
# 2    [{'aliquots': [{'aliquot_id': '15218d5b-fc40-4...
# 3    [{'aliquots': [{'aliquot_id': '47e8d70c-646d-4...
# 4    [{'aliquots': [{'aliquot_id': '333e24c9-ec45-4...
# ..                                                 ...
# 143  [{'aliquots': [{'aliquot_id': 'a3402806-a9ec-4...
# 144  [{'aliquots': [{'aliquot_id': '9d1789f8-d629-4...
# 145  [{'aliquots': [{'aliquot_id': '9c36e4e9-a971-4...
# 146  [{'aliquots': [{'aliquot_id': '4059003c-b576-4...
# 147  [{'aliquots': [{'aliquot_id': '030c9e59-35a2-4...
#
# [148 rows x 12 columns]

# %%
firstPdcSample = pdc_head_and_mouth[0]['samples'][0]

firstPdcSample
# Out:
# {'aliquots': [{'aliquot_id': '426a2696-f073-4a0e-bdcc-af62328b5d6d',
#    'aliquot_run_metadata': [{'aliquot_run_metadata_id': 'cfb6cae0-6316-47b9-a291-fd2fa9693c93'}],
#    'aliquot_submitter_id': 'SAMN05341165_N',
#    'analyte_type': 'protein'}],
#  'biospecimen_anatomic_site': None,
#  'composition': 'Not Reported',
#  'current_weight': None,
#  'days_to_collection': None,
#  'days_to_sample_procurement': None,
#  'diagnosis_pathologically_confirmed': None,
#  'freezing_method': None,
#  'gdc_project_id': None,
#  'gdc_sample_id': None,
#  'initial_weight': None,
#  'intermediate_dimension': None,
#  'is_ffpe': None,
#  'longest_dimension': None,
#  'method_of_sample_procurement': None,
#  'oct_embedded': None,
#  'pathology_report_uuid': None,
#  'preservation_method': None,
#  'sample_id': 'd58e2a88-8b0c-4cc4-bb1a-e7734ad58209',
#  'sample_submitter_id': 'OSCC_13_N',
#  'sample_type': 'Solid Tissue Normal',
#  'sample_type_id': None,
#  'shortest_dimension': None,
#  'time_between_clamping_and_freezing': None,
#  'time_between_excision_and_freezing': None,
#  'tissue_type': 'Normal',
#  'tumor_code': None,
#  'tumor_code_id': None,
#  'tumor_descriptor': None}

# %%
pdcSpecimen = entities.Specimen(
    id = firstPdcSample['sample_id'],
    analyte_type = entities.CodeableConcept(
        entities.Coding(
            firstSample['sample_type']
        )
    )
)

pdcSpecimen
# Out:
# Specimen(id='d58e2a88-8b0c-4cc4-bb1a-e7734ad58209', identifier=[], associated_project=None, specimen_type=None, analyte_type=CodeableConcept(coding=[Coding(code='Metastatic', display=None, system=None, version=None)], text=None), derived_from_specimen=[], derived_from_subject=None, source_material_type=None, cellular_composition=None, general_tissue_morphology=None, specific_tissue_morphology=None, current_weight=[], current_volume=[], analyte_concentration=None, analyte_concentration_method=None, matched_normal_flag=[], qualification_status_flag=None)
