# %% [markdown]
# # GDC to CRDC-H Conversion
#
# This notebook demonstrates one method for converting GDC data into CRDC-H instance data: by reading node data as JSON and writing it out in the LinkML model. The LinkML can be used to [generate](https://github.com/linkml/linkml#python-dataclasses) [Python DataClasses](https://docs.python.org/3/library/dataclasses.html), which can then be exported in several data publication format, such as JSON or RDF.

# %% [markdown]
# ## Setup
#
# We start by installing the [LinkML](https://pypi.org/project/linkml/) and [pandas](https://pypi.org/project/pandas/) packages.

# %%
import sys

# Install LinkML.
# We use our own fork of LinkML, but all changes made to this repository will eventually be sent
# upstream to the main LinkML release.
# !{sys.executable} -m pip install git+https://github.com/cancerDHC/linkml.git@ccdh-dev#egg=linkml

# Install pandas.
# !{sys.executable} -m pip install pandas
# Out:
# Collecting linkml
#   Cloning https://github.com/cancerDHC/linkml.git (to revision ccdh-dev) to /private/var/folders/j7/wl1qrc1n7fv9vnszw_0dsm680000gn/T/pip-install-5iz3hdga/linkml_b07b263f08ca413f855810de4c4d4cda
#   Running command git clone -q https://github.com/cancerDHC/linkml.git /private/var/folders/j7/wl1qrc1n7fv9vnszw_0dsm680000gn/T/pip-install-5iz3hdga/linkml_b07b263f08ca413f855810de4c4d4cda
#   Running command git checkout -b ccdh-dev --track origin/ccdh-dev
#   Switched to a new branch 'ccdh-dev'
#   Branch 'ccdh-dev' set up to track remote branch 'ccdh-dev' from 'origin'.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pyld in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (2.0.3)
# Requirement already satisfied: hbreader in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (0.9.1)
# Requirement already satisfied: pyyaml~=5.1 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (5.3.1)
# Requirement already satisfied: prefixcommons>=0.1.7 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (0.1.9)
# Requirement already satisfied: linkml-model>=0.0.10 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (0.0.10)
# Requirement already satisfied: click~=7.0 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (7.1.2)
# Requirement already satisfied: requests>=2.22 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (2.24.0)
# Requirement already satisfied: jsonasobj>=1.3.1 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (1.3.1)
# Requirement already satisfied: pyshexc>=0.8.3 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (0.8.3)
# Requirement already satisfied: python-dateutil in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (2.8.1)
# Requirement already satisfied: rdflib-pyld-compat in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (0.1.0)
# Requirement already satisfied: pyjsg>=0.11.6 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (0.11.6)
# Collecting argparse>=1.4.0
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (3.2.0)
# Requirement already satisfied: parse in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (1.19.0)
# Requirement already satisfied: watchdog>=0.9.0 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (2.1.0)
# Requirement already satisfied: graphviz>=0.10.1 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (0.16)
# Requirement already satisfied: prologterms>=0.0.6 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (0.0.6)
# Requirement already satisfied: pyshex>=0.7.20 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (0.7.20)
# Requirement already satisfied: sqlalchemy in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (1.4.13)
# Requirement already satisfied: rdflib-jsonld>=0.5.0 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (0.5.0)
# Requirement already satisfied: isodate>=0.6.0 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (0.6.0)
# Requirement already satisfied: rdflib>=5.0.0 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from linkml) (5.0.0)
# Requirement already satisfied: six in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from isodate>=0.6.0->linkml) (1.15.0)
# Requirement already satisfied: setuptools in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from jsonschema>=3.0.1->linkml) (49.2.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from jsonschema>=3.0.1->linkml) (20.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from jsonschema>=3.0.1->linkml) (0.17.3)
# Requirement already satisfied: antlr4-python3-runtime~=4.9 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyjsg>=0.11.6->linkml) (4.9.2)
# Requirement already satisfied: cfgraph>=0.2.1 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml) (0.2.1)
# Requirement already satisfied: urllib3 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml) (1.25.11)
# Requirement already satisfied: sparqlwrapper>=1.8.5 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml) (1.8.5)
# Requirement already satisfied: shexjsg>=0.7.1 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml) (0.7.1)
# Requirement already satisfied: sparqlslurper~=0.4 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyshex>=0.7.20->linkml) (0.4.1)
# Requirement already satisfied: pyparsing in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from rdflib>=5.0.0->linkml) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from requests>=2.22->linkml) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from requests>=2.22->linkml) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from requests>=2.22->linkml) (2020.6.20)
# Requirement already satisfied: cachetools in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyld->linkml) (4.2.2)
# Requirement already satisfied: lxml in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyld->linkml) (4.6.3)
# Requirement already satisfied: frozendict in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pyld->linkml) (2.0.2)
# Requirement already satisfied: testfixtures in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from rdflib-pyld-compat->linkml) (6.17.1)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from sqlalchemy->linkml) (1.0.0)
# Building wheels for collected packages: linkml
#   Building wheel for linkml (PEP 517) ... done
#   Created wheel for linkml: filename=linkml-0.0.8.dev65-py3-none-any.whl size=135139 sha256=383709a23f97e099e1365a21add0ac6dc081a914b1716ebdedcd2cb581378d91
#   Stored in directory: /private/var/folders/j7/wl1qrc1n7fv9vnszw_0dsm680000gn/T/pip-ephem-wheel-cache-k7noj9nh/wheels/03/63/a9/d9d33ca6ad4dbc10c7055a84968523e5eb633f7b304d0bd147
# Successfully built linkml
# Installing collected packages: argparse, linkml
#   Attempting uninstall: linkml
#     Found existing installation: linkml 0.0.8.dev64
#     Uninstalling linkml-0.0.8.dev64:
#       Successfully uninstalled linkml-0.0.8.dev64
# Successfully installed argparse-1.4.0 linkml-0.0.8.dev65
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/Users/gaurav/.pyenv/versions/3.9.0/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: pandas in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (1.2.4)
# Requirement already satisfied: numpy>=1.16.5 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pandas) (1.20.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/gaurav/.pyenv/versions/3.9.0/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# WARNING: You are using pip version 21.1.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/Users/gaurav/.pyenv/versions/3.9.0/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Loading GDC data as an example
#
# We start by loading the result of a GDC query in JSON.

# %%
import json
import pandas

with open('head-and-mouth/gdc-head-and-mouth.json') as file:
    gdc_head_and_mouth = json.load(file)
    
pandas.DataFrame(gdc_head_and_mouth)
# Out:
#                                            aliquot_ids  \
# 0               [cfcde639-3045-4f66-84a6-ec74b090a5b6]
# 1    [9069bdd7-e16a-462c-881c-581c8aab6910, a74915f...
# 2    [8f695cd3-01dd-4601-8b17-37cf40514422, f0e325f...
# 3    [1265fd12-4706-43b0-84f3-d16d46f20963, 3443e1b...
# 4    [59b70846-64f0-489e-8ea5-84a347aedeb8, c8e46ce...
# ..                                                 ...
# 555  [1d3b16fd-f98b-45ef-a423-861975f098b6, 0eabe3e...
# 556             [96f09bc8-a194-482c-bd17-baf28739e4f8]
# 557  [cd211e89-63f7-44f0-8a76-51703ae45112, 866292c...
# 558  [0c2f310b-fa59-4f6f-894a-dad920214004, 6ddd527...
# 559  [53800455-66fa-4193-9308-390fd663a40c, 9c20138...
#
#                                   case_id                  created_datetime  \
# 0    cd7e514f-71ba-4cc1-b74a-a22c6248169c  2017-06-01T08:57:57.249456-05:00
# 1    9023c9bf-02a0-4396-8161-304089957b62                              None
# 2    55f96a9c-e2c8-4243-8a7e-94bc6fab73a6                              None
# 3    c9a36eb5-ac3e-424e-bc2e-303de7105957                              None
# 4    4cffea0b-90a7-4c86-a73f-bb8feca3ada7                              None
# ..                                    ...                               ...
# 555  97640ef0-0259-4244-95ba-48d28c60b372                              None
# 556  422a72e7-fe76-411d-b59e-1f0f0812c3cf  2018-09-13T13:42:10.444091-05:00
# 557  4b50aea4-4ad1-4bf6-9cf1-984c28a99c84                              None
# 558  0394060d-010e-405f-983d-db525f01f2c3                              None
# 559  df132eb8-174b-4427-a16b-953e0f28bf2f                              None
#
#                                              diagnoses  \
# 0    [{'age_at_diagnosis': 19592, 'classification_o...
# 1    [{'age_at_diagnosis': 24286, 'ajcc_clinical_m'...
# 2    [{'age_at_diagnosis': 20992, 'ajcc_clinical_m'...
# 3    [{'age_at_diagnosis': 21886, 'ajcc_clinical_m'...
# 4    [{'age_at_diagnosis': 14190, 'ajcc_clinical_m'...
# ..                                                 ...
# 555  [{'age_at_diagnosis': 19621, 'ajcc_clinical_m'...
# 556  [{'age_at_diagnosis': None, 'ajcc_clinical_m':...
# 557  [{'age_at_diagnosis': 21731, 'ajcc_clinical_m'...
# 558  [{'age_at_diagnosis': 23640, 'ajcc_clinical_m'...
# 559  [{'age_at_diagnosis': 20763, 'ajcc_clinical_m'...
#
#                               diagnosis_ids                  disease_type  \
# 0    [5d2d67d1-4611-4a18-9a66-89823aaa8e3c]  Adenomas and Adenocarcinomas
# 1    [706b1290-3a85-54ea-a123-e8bd14b085bc]       Squamous Cell Neoplasms
# 2    [40954a8e-e4c2-5604-937b-0a79ac7489d2]       Squamous Cell Neoplasms
# 3    [48e8dd81-ed4d-5c54-af66-84e86477d5c8]       Squamous Cell Neoplasms
# 4    [1da5c51a-ee25-51a6-a4c2-27d8fdcbe24e]       Squamous Cell Neoplasms
# ..                                      ...                           ...
# 555  [b725e6d2-92c0-5585-9de7-14bb623b472e]       Squamous Cell Neoplasms
# 556  [842d6984-7c03-4ab6-95db-42fa2ea699db]       Squamous Cell Neoplasms
# 557  [95d85e5a-b82c-59f8-b7ad-710e019cdebc]       Squamous Cell Neoplasms
# 558  [7a67eecc-6f46-5181-8b64-c022d0fd0060]       Squamous Cell Neoplasms
# 559  [d20b4711-8757-5d39-a8cc-b8ece86592cd]       Squamous Cell Neoplasms
#
#                                        id primary_site  \
# 0    cd7e514f-71ba-4cc1-b74a-a22c6248169c  Nasopharynx
# 1    9023c9bf-02a0-4396-8161-304089957b62       Larynx
# 2    55f96a9c-e2c8-4243-8a7e-94bc6fab73a6       Larynx
# 3    c9a36eb5-ac3e-424e-bc2e-303de7105957   Oropharynx
# 4    4cffea0b-90a7-4c86-a73f-bb8feca3ada7       Tonsil
# ..                                    ...          ...
# 555  97640ef0-0259-4244-95ba-48d28c60b372       Larynx
# 556  422a72e7-fe76-411d-b59e-1f0f0812c3cf       Larynx
# 557  4b50aea4-4ad1-4bf6-9cf1-984c28a99c84  Hypopharynx
# 558  0394060d-010e-405f-983d-db525f01f2c3  Hypopharynx
# 559  df132eb8-174b-4427-a16b-953e0f28bf2f       Larynx
#
#                                             sample_ids  \
# 0               [bdc73f48-dc0b-487d-abbe-e3a977b6830a]
# 1    [8b2588c8-4261-492b-b173-2490a5de668f, badeaed...
# 2    [a7692585-a129-4671-bfe5-98342a326776, b069c55...
# 3    [256469d0-5f36-4966-bf4f-3b4297e55f43, bd90f96...
# 4    [1ed245de-fea4-42c9-9197-773bcd12d2a8, 665d4bf...
# ..                                                 ...
# 555  [fb06ae75-8516-4cdc-ba9e-093444907fc7, 5162217...
# 556             [6f9eeaa3-8bd1-479c-a0fc-98317eb458dc]
# 557  [1077bf93-cf23-41db-925c-c633921894cc, 4a0d79f...
# 558  [5c2b4403-cdd4-4550-ba01-d8ebad9fcbc8, 4467ee1...
# 559  [c22e9fe0-a052-4c6f-9fb2-e58289277e2a, 6bd5367...
#
#                                                samples  ...  \
# 0    [{'created_datetime': '2017-06-01T10:44:57.790...  ...
# 1    [{'created_datetime': '2018-05-17T12:19:46.292...  ...
# 2    [{'composition': None, 'created_datetime': Non...  ...
# 3    [{'composition': None, 'created_datetime': Non...  ...
# 4    [{'created_datetime': '2018-05-17T12:19:46.292...  ...
# ..                                                 ...  ...
# 555  [{'composition': None, 'created_datetime': Non...  ...
# 556  [{'biospecimen_anatomic_site': None, 'biospeci...  ...
# 557  [{'created_datetime': '2018-05-17T12:19:46.292...  ...
# 558  [{'created_datetime': '2018-05-17T12:19:46.292...  ...
# 559  [{'composition': None, 'created_datetime': Non...  ...
#
#                                   submitter_sample_ids  \
# 0                                      [AD6426_sample]
# 1    [TCGA-CN-6012-10A, TCGA-CN-6012-01A, TCGA-CN-6...
# 2    [TCGA-CV-7261-01Z, TCGA-CV-7261-11A, TCGA-CV-7...
# 3    [TCGA-BA-A6DL-10A, TCGA-BA-A6DL-01Z, TCGA-BA-A...
# 4    [TCGA-CN-5365-01Z, TCGA-CN-5365-10A, TCGA-CN-5...
# ..                                                 ...
# 555  [TCGA-CN-4738-01A, TCGA-CN-4738-01Z, TCGA-CN-4...
# 556                          [GENIE-DFCI-010671-11105]
# 557  [TCGA-TN-A7HL-01A, TCGA-TN-A7HL-01Z, TCGA-TN-A...
# 558  [TCGA-BB-A5HY-10A, TCGA-BB-A5HY-01A, TCGA-BB-A...
# 559  [TCGA-CV-7430-11A, TCGA-CV-7430-01A, TCGA-CV-7...
#
#                                    submitter_slide_ids  \
# 0                                       [AD6426_slide]
# 1    [TCGA-CN-6012-01Z-00-DX1, TCGA-CN-6012-01A-01-...
# 2    [TCGA-CV-7261-01A-01-TS1, TCGA-CV-7261-01Z-00-...
# 3    [TCGA-BA-A6DL-01Z-00-DX1, TCGA-BA-A6DL-01A-02-...
# 4    [TCGA-CN-5365-01Z-00-DX1, TCGA-CN-5365-01A-01-...
# ..                                                 ...
# 555  [TCGA-CN-4738-01Z-00-DX1, TCGA-CN-4738-01A-01-...
# 556                                                NaN
# 557  [TCGA-TN-A7HL-01Z-00-DX1, TCGA-TN-A7HL-01A-01-...
# 558  [TCGA-BB-A5HY-01Z-00-DX1, TCGA-BB-A5HY-01A-01-...
# 559  [TCGA-CV-7430-01A-01-BS1, TCGA-CV-7430-01Z-00-...
#
#                      updated_datetime  \
# 0    2018-10-25T11:34:27.425461-05:00
# 1    2019-08-06T14:25:25.511101-05:00
# 2    2019-08-06T14:26:28.608672-05:00
# 3    2019-08-06T14:25:14.243346-05:00
# 4    2019-08-06T14:25:25.511101-05:00
# ..                                ...
# 555  2019-08-06T14:25:25.511101-05:00
# 556  2019-11-18T13:54:59.294543-06:00
# 557  2019-08-06T14:27:14.277986-05:00
# 558  2019-08-06T14:25:25.511101-05:00
# 559  2019-08-06T14:26:28.608672-05:00
#
#                                            analyte_ids  \
# 0                                                  NaN
# 1    [80c6fde2-b6bb-4f40-908a-f116c466d296, 6f77017...
# 2    [a72f2de7-eb40-4818-a104-edb508d5517b, e8120e5...
# 3    [ec4487c1-6976-4161-9236-5e6810ed31b7, ffd1e03...
# 4    [d46b5e9b-3652-45a1-a91d-46277aea3916, 35122dd...
# ..                                                 ...
# 555  [4dc95dbe-b10f-4d6e-9413-ae47a0a49865, e637c1c...
# 556                                                NaN
# 557  [6ffc3548-d593-47ab-adf8-6d73075b5fa0, 9426e53...
# 558  [ee7f98c5-9c78-4bbe-b44a-a9e357a18058, 2d82983...
# 559  [9645e3d2-e245-4d0b-a4f3-a14ec7508b28, a5a93bc...
#
#                                            portion_ids  \
# 0                                                  NaN
# 1    [bada788e-5112-4d21-a079-72729bd0cc83, fe24eea...
# 2    [177fa10b-0135-468d-b5a3-6f30cc3cd390, f51d76a...
# 3    [7f327ef6-4fe6-40c8-aac7-731e051177bb, 2a4b0be...
# 4    [38c5a4c1-6d01-4885-ba35-0032e6b835b0, 516f802...
# ..                                                 ...
# 555  [56c7d4e4-5703-4686-98b1-0c3125e5913e, 60d72bd...
# 556                                                NaN
# 557  [cd5864c8-b4e0-4405-b7df-1e0a51865670, f9ef56b...
# 558  [9576f242-6874-4df9-8744-e0755d565358, 8842cbd...
# 559  [71900a0b-da4a-444c-bfd5-4ba5e530761f, 06546fd...
#
#                                  submitter_analyte_ids  \
# 0                                                  NaN
# 1    [TCGA-CN-6012-01A-11D, TCGA-CN-6012-10A-01W, T...
# 2    [TCGA-CV-7261-10A-01D, TCGA-CV-7261-01A-11R, T...
# 3    [TCGA-BA-A6DL-01A-21D, TCGA-BA-A6DL-01A-21R, T...
# 4    [TCGA-CN-5365-01A-01D, TCGA-CN-5365-01A-01W, T...
# ..                                                 ...
# 555  [TCGA-CN-4738-01A-02D, TCGA-CN-4738-10A-01W, T...
# 556                                                NaN
# 557  [TCGA-TN-A7HL-01A-11R, TCGA-TN-A7HL-01A-11D, T...
# 558  [TCGA-BB-A5HY-01A-11W, TCGA-BB-A5HY-01A-11D, T...
# 559  [TCGA-CV-7430-01A-11D, TCGA-CV-7430-10A-01D, T...
#
#                                  submitter_portion_ids  \
# 0                                                  NaN
# 1    [TCGA-CN-6012-01A-13-2072-20, TCGA-CN-6012-10A...
# 2    [TCGA-CV-7261-10A-01, TCGA-CV-7261-01A-13-2074...
# 3    [TCGA-BA-A6DL-10A-01, TCGA-BA-A6DL-01A-11-A45L...
# 4    [TCGA-CN-5365-10A-01, TCGA-CN-5365-01A-21-2072...
# ..                                                 ...
# 555  [TCGA-CN-4738-01A-31-2072-20, TCGA-CN-4738-01A...
# 556                                                NaN
# 557  [TCGA-TN-A7HL-01A-21-A45L-20, TCGA-TN-A7HL-10A...
# 558         [TCGA-BB-A5HY-01A-11, TCGA-BB-A5HY-10A-01]
# 559  [TCGA-CV-7430-01A-13-2074-20, TCGA-CV-7430-11A...
#
#     days_to_lost_to_followup                  index_date lost_to_followup
# 0                        NaN                         NaN              NaN
# 1                        NaN                         NaN              NaN
# 2                        NaN                         NaN              NaN
# 3                        NaN                         NaN              NaN
# 4                        NaN                         NaN              NaN
# ..                       ...                         ...              ...
# 555                      NaN                         NaN              NaN
# 556                      NaN  Initial Genomic Sequencing              NaN
# 557                      NaN                         NaN              NaN
# 558                      NaN                         NaN              NaN
# 559                      NaN                         NaN              NaN
#
# [560 rows x 25 columns]

# %% [markdown]
# ## Loading the Python classes for the CRDC-H model
#
# We previously generated the Python DataClasses for the CRDC-H model. We can now load these DataClasses to transform files from the GDC to CRDC-H model.

# %%
from ccdh import ccdhmodel as ccdh
import pprint
import json

from linkml.dumpers.yaml_dumper import dumps

pp = pprint.PrettyPrinter(indent=4)

def create_coding(
    code,
    system=None,
    displayLabel=None,
    systemURL=None,
    systemVersion=None
):
    return {
        'code': code,
        'displayLabel': displayLabel,
        'system': system,
        'systemURL': systemURL,
        'systemVersion': systemVersion
    }

def create_codeable_concept(coding=None, text=None):
    return {
        'coding': coding,
        'text': text
    }

def create_identifier(system, value):
    return ccdh.Identifier(
        # type='unknown', # No types currently defined.
        system=system,
        value=value
    )

# %% [markdown]
# ## Convert the input data in pieces
#
# For demonstrative purposes, we'll start by translating pieces of this record into CRDC-H instance data.
#
# Let's start with the samples in the `samples` key (which correspond to a [Specimen](https://cancerdhc.github.io/ccdhmodel/entities/Specimen.html) in the CRDC-H model).

# %%
firstSample = gdc_head_and_mouth[0]['samples'][0]
firstSample
# Out:
# {'created_datetime': '2017-06-01T10:44:57.790971-05:00',
#  'sample_id': 'bdc73f48-dc0b-487d-abbe-e3a977b6830a',
#  'sample_type': 'Metastatic',
#  'state': 'released',
#  'submitter_id': 'AD6426_sample',
#  'tissue_type': 'Not Reported',
#  'tumor_descriptor': 'Metastatic',
#  'updated_datetime': '2018-11-15T21:10:03.529893-06:00'}

# %%
def map_sample(sample):
    specimen:ccdh.Specimen = ccdh.Specimen(id = sample.get('sample_id'))
    specimen.identifier = [create_identifier('GDC', sample['submitter_id'])]
    specimen.source_material_type = sample.get('sample_type')
    specimen.general_tissue_morphology = sample.get('tissue_type')
    specimen.tumor_status_at_collection = sample.get('tumor_descriptor')
    specimen.creation_activity = ccdh.SpecimenCreationActivity(
        date_ended=ccdh.TimePoint(
            dateTime=sample.get('created_datetime')
        )
    )
    return specimen

first_specimen = map_sample(firstSample)

# Unmapped fields:
# - state: released (https://github.com/NCI-GDC/gdcdictionary/blob/develop/gdcdictionary/schemas/_definitions.yaml#L128)
# - updated_datetime

first_specimen
print(dumps(first_specimen))
# Out:
# id: bdc73f48-dc0b-487d-abbe-e3a977b6830a
# identifier:
# - value: AD6426_sample
#   system: GDC
# source_material_type: Metastatic
# tumor_status_at_collection: Metastatic
# creation_activity:
#   date_ended:
#     dateTime: '2017-06-01T10:44:57.790971-05:00'
# general_tissue_morphology: Not Reported

# %%
specimens = list(map(lambda entry: list(map(map_sample, entry['samples'])), gdc_head_and_mouth))
specimens[1:3]
# Out:
# [[Specimen(id='8b2588c8-4261-492b-b173-2490a5de668f', identifier=[Identifier(value='TCGA-CN-6012-01Z', system='GDC', type=None)], description=None, specimen_type=None, analyte_type=None, associated_project=None, data_provider=None, source_material_type='Primary Tumor', parent_specimen=[], source_subject=None, source_model_system=None, tumor_status_at_collection=None, creation_activity=SpecimenCreationActivity(activity_type=None, date_started=None, date_ended=TimePoint(id=None, dateTime='2018-05-17T12:19:46.292188-05:00', indexTimePoint=None, offsetFromIndex=None, eventType=[]), performed_by=None, collection_method_type=None, derivation_method_type=None, additive=[], collection_site=None, quantity_collected=None, execution_observation=[], specimen_order=None), processing_activity=[], storage_activity=[], transport_activity=[], contained_in=None, dimensional_measure=None, quantity_measure=[], quality_measure=[], cellular_composition_type=None, histological_composition_measure=[], general_tissue_morphology='Not Reported', specific_tissue_morphology=None, preinvasive_tissue_morphology=None, morphology_pathologically_confirmed=None, morphology_assessor_role=None, morphlogy_assessment_method=None, degree_of_dysplasia=None, dysplasia_fraction=None, related_document=[], section_location=None, derived_product=[], distance_from_paired_specimen=None),
#   Specimen(id='badeaed0-2625-4a4d-bb95-d295e2c32c01', identifier=[Identifier(value='TCGA-CN-6012-10A', system='GDC', type=None)], description=None, specimen_type=None, analyte_type=None, associated_project=None, data_provider=None, source_material_type='Blood Derived Normal', parent_specimen=[], source_subject=None, source_model_system=None, tumor_status_at_collection=None, creation_activity=SpecimenCreationActivity(activity_type=None, date_started=None, date_ended=TimePoint(id=None, dateTime=None, indexTimePoint=None, offsetFromIndex=None, eventType=[]), performed_by=None, collection_method_type=None, derivation_method_type=None, additive=[], collection_site=None, quantity_collected=None, execution_observation=[], specimen_order=None), processing_activity=[], storage_activity=[], transport_activity=[], contained_in=None, dimensional_measure=None, quantity_measure=[], quality_measure=[], cellular_composition_type=None, histological_composition_measure=[], general_tissue_morphology='Not Reported', specific_tissue_morphology=None, preinvasive_tissue_morphology=None, morphology_pathologically_confirmed=None, morphology_assessor_role=None, morphlogy_assessment_method=None, degree_of_dysplasia=None, dysplasia_fraction=None, related_document=[], section_location=None, derived_product=[], distance_from_paired_specimen=None),
#   Specimen(id='e23c7006-1a13-4211-8920-47548641e574', identifier=[Identifier(value='TCGA-CN-6012-01A', system='GDC', type=None)], description=None, specimen_type=None, analyte_type=None, associated_project=None, data_provider=None, source_material_type='Primary Tumor', parent_specimen=[], source_subject=None, source_model_system=None, tumor_status_at_collection=None, creation_activity=SpecimenCreationActivity(activity_type=None, date_started=None, date_ended=TimePoint(id=None, dateTime=None, indexTimePoint=None, offsetFromIndex=None, eventType=[]), performed_by=None, collection_method_type=None, derivation_method_type=None, additive=[], collection_site=None, quantity_collected=None, execution_observation=[], specimen_order=None), processing_activity=[], storage_activity=[], transport_activity=[], contained_in=None, dimensional_measure=None, quantity_measure=[], quality_measure=[], cellular_composition_type=None, histological_composition_measure=[], general_tissue_morphology='Not Reported', specific_tissue_morphology=None, preinvasive_tissue_morphology=None, morphology_pathologically_confirmed=None, morphology_assessor_role=None, morphlogy_assessment_method=None, degree_of_dysplasia=None, dysplasia_fraction=None, related_document=[], section_location=None, derived_product=[], distance_from_paired_specimen=None)],
#  [Specimen(id='69a89590-eb61-41d5-b33e-e7bc5adb92bf', identifier=[Identifier(value='TCGA-CV-7261-11A', system='GDC', type=None)], description=None, specimen_type=None, analyte_type=None, associated_project=None, data_provider=None, source_material_type='Solid Tissue Normal', parent_specimen=[], source_subject=None, source_model_system=None, tumor_status_at_collection=None, creation_activity=SpecimenCreationActivity(activity_type=None, date_started=None, date_ended=TimePoint(id=None, dateTime=None, indexTimePoint=None, offsetFromIndex=None, eventType=[]), performed_by=None, collection_method_type=None, derivation_method_type=None, additive=[], collection_site=None, quantity_collected=None, execution_observation=[], specimen_order=None), processing_activity=[], storage_activity=[], transport_activity=[], contained_in=None, dimensional_measure=None, quantity_measure=[], quality_measure=[], cellular_composition_type=None, histological_composition_measure=[], general_tissue_morphology='Not Reported', specific_tissue_morphology=None, preinvasive_tissue_morphology=None, morphology_pathologically_confirmed=None, morphology_assessor_role=None, morphlogy_assessment_method=None, degree_of_dysplasia=None, dysplasia_fraction=None, related_document=[], section_location=None, derived_product=[], distance_from_paired_specimen=None),
#   Specimen(id='b069c55b-496a-4a57-a507-1b2e1b4201ae', identifier=[Identifier(value='TCGA-CV-7261-01A', system='GDC', type=None)], description=None, specimen_type=None, analyte_type=None, associated_project=None, data_provider=None, source_material_type='Primary Tumor', parent_specimen=[], source_subject=None, source_model_system=None, tumor_status_at_collection=None, creation_activity=SpecimenCreationActivity(activity_type=None, date_started=None, date_ended=TimePoint(id=None, dateTime=None, indexTimePoint=None, offsetFromIndex=None, eventType=[]), performed_by=None, collection_method_type=None, derivation_method_type=None, additive=[], collection_site=None, quantity_collected=None, execution_observation=[], specimen_order=None), processing_activity=[], storage_activity=[], transport_activity=[], contained_in=None, dimensional_measure=None, quantity_measure=[], quality_measure=[], cellular_composition_type=None, histological_composition_measure=[], general_tissue_morphology='Not Reported', specific_tissue_morphology=None, preinvasive_tissue_morphology=None, morphology_pathologically_confirmed=None, morphology_assessor_role=None, morphlogy_assessment_method=None, degree_of_dysplasia=None, dysplasia_fraction=None, related_document=[], section_location=None, derived_product=[], distance_from_paired_specimen=None),
#   Specimen(id='00f7bc3c-c0e7-42bf-84d7-87a8a539bd4a', identifier=[Identifier(value='TCGA-CV-7261-01Z', system='GDC', type=None)], description=None, specimen_type=None, analyte_type=None, associated_project=None, data_provider=None, source_material_type='Primary Tumor', parent_specimen=[], source_subject=None, source_model_system=None, tumor_status_at_collection=None, creation_activity=SpecimenCreationActivity(activity_type=None, date_started=None, date_ended=TimePoint(id=None, dateTime='2018-05-17T12:19:46.292188-05:00', indexTimePoint=None, offsetFromIndex=None, eventType=[]), performed_by=None, collection_method_type=None, derivation_method_type=None, additive=[], collection_site=None, quantity_collected=None, execution_observation=[], specimen_order=None), processing_activity=[], storage_activity=[], transport_activity=[], contained_in=None, dimensional_measure=None, quantity_measure=[], quality_measure=[], cellular_composition_type=None, histological_composition_measure=[], general_tissue_morphology='Not Reported', specific_tissue_morphology=None, preinvasive_tissue_morphology=None, morphology_pathologically_confirmed=None, morphology_assessor_role=None, morphlogy_assessment_method=None, degree_of_dysplasia=None, dysplasia_fraction=None, related_document=[], section_location=None, derived_product=[], distance_from_paired_specimen=None),
#   Specimen(id='a7692585-a129-4671-bfe5-98342a326776', identifier=[Identifier(value='TCGA-CV-7261-10A', system='GDC', type=None)], description=None, specimen_type=None, analyte_type=None, associated_project=None, data_provider=None, source_material_type='Blood Derived Normal', parent_specimen=[], source_subject=None, source_model_system=None, tumor_status_at_collection=None, creation_activity=SpecimenCreationActivity(activity_type=None, date_started=None, date_ended=TimePoint(id=None, dateTime=None, indexTimePoint=None, offsetFromIndex=None, eventType=[]), performed_by=None, collection_method_type=None, derivation_method_type=None, additive=[], collection_site=None, quantity_collected=None, execution_observation=[], specimen_order=None), processing_activity=[], storage_activity=[], transport_activity=[], contained_in=None, dimensional_measure=None, quantity_measure=[], quality_measure=[], cellular_composition_type=None, histological_composition_measure=[], general_tissue_morphology='Not Reported', specific_tissue_morphology=None, preinvasive_tissue_morphology=None, morphology_pathologically_confirmed=None, morphology_assessor_role=None, morphlogy_assessment_method=None, degree_of_dysplasia=None, dysplasia_fraction=None, related_document=[], section_location=None, derived_product=[], distance_from_paired_specimen=None)]]

# %%
diagnoses = []
for case in gdc_head_and_mouth:
    diagnoses.extend(case['diagnoses'])

for index, diagnosis in enumerate(diagnoses):
    diagnosis['index'] = index

# pandas.DataFrame(sorted(filter(lambda d: d['created_datetime'] is not None, diagnoses), key=lambda d: d['created_datetime'], reverse=True))
pandas.set_option("display.max_rows", None)
pandas.DataFrame(diagnoses).describe().transpose()
# Out:
#                                           count          mean          std  \
# age_at_diagnosis                          261.0  20901.210728  5267.246124
# days_to_last_follow_up                    155.0    924.387097   763.861290
# index                                     560.0    279.500000   161.802349
# days_to_diagnosis                         201.0      0.000000     0.000000
# year_of_diagnosis                         201.0   2008.154229     4.780282
# anaplasia_present                           0.0           NaN          NaN
# anaplasia_present_type                      0.0           NaN          NaN
# ann_arbor_b_symptoms                        0.0           NaN          NaN
# ann_arbor_clinical_stage                    0.0           NaN          NaN
# ann_arbor_extranodal_involvement            0.0           NaN          NaN
# ann_arbor_pathologic_stage                  0.0           NaN          NaN
# best_overall_response                       0.0           NaN          NaN
# breslow_thickness                           0.0           NaN          NaN
# burkitt_lymphoma_clinical_variant           0.0           NaN          NaN
# child_pugh_classification                   0.0           NaN          NaN
# circumferential_resection_margin            0.0           NaN          NaN
# cog_liver_stage                             0.0           NaN          NaN
# cog_neuroblastoma_risk_group                0.0           NaN          NaN
# cog_rhabdomyosarcoma_risk_group             0.0           NaN          NaN
# days_to_best_overall_response               0.0           NaN          NaN
# enneking_msts_grade                         0.0           NaN          NaN
# enneking_msts_metastasis                    0.0           NaN          NaN
# enneking_msts_stage                         0.0           NaN          NaN
# enneking_msts_tumor_site                    0.0           NaN          NaN
# esophageal_columnar_dysplasia_degree        0.0           NaN          NaN
# esophageal_columnar_metaplasia_present      0.0           NaN          NaN
# figo_stage                                  0.0           NaN          NaN
# first_symptom_prior_to_diagnosis            0.0           NaN          NaN
# gastric_esophageal_junction_involvement     0.0           NaN          NaN
# gleason_grade_group                         0.0           NaN          NaN
# goblet_cells_columnar_mucosa_present        0.0           NaN          NaN
# gross_tumor_weight                          0.0           NaN          NaN
# igcccg_stage                                0.0           NaN          NaN
# inpc_grade                                  0.0           NaN          NaN
# inpc_histologic_group                       0.0           NaN          NaN
# inrg_stage                                  0.0           NaN          NaN
# inss_stage                                  0.0           NaN          NaN
# international_prognostic_index              0.0           NaN          NaN
# irs_group                                   0.0           NaN          NaN
# irs_stage                                   0.0           NaN          NaN
# ishak_fibrosis_score                        0.0           NaN          NaN
# iss_stage                                   0.0           NaN          NaN
# largest_extrapelvic_peritoneal_focus        0.0           NaN          NaN
# laterality                                  0.0           NaN          NaN
# lymph_nodes_positive                        0.0           NaN          NaN
# lymph_nodes_tested                          0.0           NaN          NaN
# lymphatic_invasion_present                  0.0           NaN          NaN
# masaoka_stage                               0.0           NaN          NaN
# medulloblastoma_molecular_classification    0.0           NaN          NaN
# metastasis_at_diagnosis                     0.0           NaN          NaN
# metastasis_at_diagnosis_site                0.0           NaN          NaN
# method_of_diagnosis                         0.0           NaN          NaN
# micropapillary_features                     0.0           NaN          NaN
# mitosis_karyorrhexis_index                  0.0           NaN          NaN
# mitotic_count                               0.0           NaN          NaN
# non_nodal_regional_disease                  0.0           NaN          NaN
# non_nodal_tumor_deposits                    0.0           NaN          NaN
# ovarian_specimen_status                     0.0           NaN          NaN
# ovarian_surface_involvement                 0.0           NaN          NaN
# percent_tumor_invasion                      0.0           NaN          NaN
# perineural_invasion_present                 0.0           NaN          NaN
# peripancreatic_lymph_nodes_positive         0.0           NaN          NaN
# peripancreatic_lymph_nodes_tested           0.0           NaN          NaN
# peritoneal_fluid_cytological_status         0.0           NaN          NaN
# primary_gleason_grade                       0.0           NaN          NaN
# residual_disease                            0.0           NaN          NaN
# secondary_gleason_grade                     0.0           NaN          NaN
# supratentorial_localization                 0.0           NaN          NaN
# tumor_confined_to_organ_of_origin           0.0           NaN          NaN
# tumor_focality                              0.0           NaN          NaN
# tumor_largest_dimension_diameter            0.0           NaN          NaN
# tumor_regression_grade                      0.0           NaN          NaN
# vascular_invasion_present                   0.0           NaN          NaN
# vascular_invasion_type                      0.0           NaN          NaN
# weiss_assessment_score                      0.0           NaN          NaN
# wilms_tumor_histologic_subtype              0.0           NaN          NaN
#
#                                              min       25%      50%       75%  \
# age_at_diagnosis                           141.0  18718.00  21689.0  24192.00
# days_to_last_follow_up                       1.0    378.50    685.0   1363.00
# index                                        0.0    139.75    279.5    419.25
# days_to_diagnosis                            0.0      0.00      0.0      0.00
# year_of_diagnosis                         1993.0   2006.00   2010.0   2011.00
# anaplasia_present                            NaN       NaN      NaN       NaN
# anaplasia_present_type                       NaN       NaN      NaN       NaN
# ann_arbor_b_symptoms                         NaN       NaN      NaN       NaN
# ann_arbor_clinical_stage                     NaN       NaN      NaN       NaN
# ann_arbor_extranodal_involvement             NaN       NaN      NaN       NaN
# ann_arbor_pathologic_stage                   NaN       NaN      NaN       NaN
# best_overall_response                        NaN       NaN      NaN       NaN
# breslow_thickness                            NaN       NaN      NaN       NaN
# burkitt_lymphoma_clinical_variant            NaN       NaN      NaN       NaN
# child_pugh_classification                    NaN       NaN      NaN       NaN
# circumferential_resection_margin             NaN       NaN      NaN       NaN
# cog_liver_stage                              NaN       NaN      NaN       NaN
# cog_neuroblastoma_risk_group                 NaN       NaN      NaN       NaN
# cog_rhabdomyosarcoma_risk_group              NaN       NaN      NaN       NaN
# days_to_best_overall_response                NaN       NaN      NaN       NaN
# enneking_msts_grade                          NaN       NaN      NaN       NaN
# enneking_msts_metastasis                     NaN       NaN      NaN       NaN
# enneking_msts_stage                          NaN       NaN      NaN       NaN
# enneking_msts_tumor_site                     NaN       NaN      NaN       NaN
# esophageal_columnar_dysplasia_degree         NaN       NaN      NaN       NaN
# esophageal_columnar_metaplasia_present       NaN       NaN      NaN       NaN
# figo_stage                                   NaN       NaN      NaN       NaN
# first_symptom_prior_to_diagnosis             NaN       NaN      NaN       NaN
# gastric_esophageal_junction_involvement      NaN       NaN      NaN       NaN
# gleason_grade_group                          NaN       NaN      NaN       NaN
# goblet_cells_columnar_mucosa_present         NaN       NaN      NaN       NaN
# gross_tumor_weight                           NaN       NaN      NaN       NaN
# igcccg_stage                                 NaN       NaN      NaN       NaN
# inpc_grade                                   NaN       NaN      NaN       NaN
# inpc_histologic_group                        NaN       NaN      NaN       NaN
# inrg_stage                                   NaN       NaN      NaN       NaN
# inss_stage                                   NaN       NaN      NaN       NaN
# international_prognostic_index               NaN       NaN      NaN       NaN
# irs_group                                    NaN       NaN      NaN       NaN
# irs_stage                                    NaN       NaN      NaN       NaN
# ishak_fibrosis_score                         NaN       NaN      NaN       NaN
# iss_stage                                    NaN       NaN      NaN       NaN
# largest_extrapelvic_peritoneal_focus         NaN       NaN      NaN       NaN
# laterality                                   NaN       NaN      NaN       NaN
# lymph_nodes_positive                         NaN       NaN      NaN       NaN
# lymph_nodes_tested                           NaN       NaN      NaN       NaN
# lymphatic_invasion_present                   NaN       NaN      NaN       NaN
# masaoka_stage                                NaN       NaN      NaN       NaN
# medulloblastoma_molecular_classification     NaN       NaN      NaN       NaN
# metastasis_at_diagnosis                      NaN       NaN      NaN       NaN
# metastasis_at_diagnosis_site                 NaN       NaN      NaN       NaN
# method_of_diagnosis                          NaN       NaN      NaN       NaN
# micropapillary_features                      NaN       NaN      NaN       NaN
# mitosis_karyorrhexis_index                   NaN       NaN      NaN       NaN
# mitotic_count                                NaN       NaN      NaN       NaN
# non_nodal_regional_disease                   NaN       NaN      NaN       NaN
# non_nodal_tumor_deposits                     NaN       NaN      NaN       NaN
# ovarian_specimen_status                      NaN       NaN      NaN       NaN
# ovarian_surface_involvement                  NaN       NaN      NaN       NaN
# percent_tumor_invasion                       NaN       NaN      NaN       NaN
# perineural_invasion_present                  NaN       NaN      NaN       NaN
# peripancreatic_lymph_nodes_positive          NaN       NaN      NaN       NaN
# peripancreatic_lymph_nodes_tested            NaN       NaN      NaN       NaN
# peritoneal_fluid_cytological_status          NaN       NaN      NaN       NaN
# primary_gleason_grade                        NaN       NaN      NaN       NaN
# residual_disease                             NaN       NaN      NaN       NaN
# secondary_gleason_grade                      NaN       NaN      NaN       NaN
# supratentorial_localization                  NaN       NaN      NaN       NaN
# tumor_confined_to_organ_of_origin            NaN       NaN      NaN       NaN
# tumor_focality                               NaN       NaN      NaN       NaN
# tumor_largest_dimension_diameter             NaN       NaN      NaN       NaN
# tumor_regression_grade                       NaN       NaN      NaN       NaN
# vascular_invasion_present                    NaN       NaN      NaN       NaN
# vascular_invasion_type                       NaN       NaN      NaN       NaN
# weiss_assessment_score                       NaN       NaN      NaN       NaN
# wilms_tumor_histologic_subtype               NaN       NaN      NaN       NaN
#
#                                               max
# age_at_diagnosis                          32871.0
# days_to_last_follow_up                     4241.0
# index                                       559.0
# days_to_diagnosis                             0.0
# year_of_diagnosis                          2013.0
# anaplasia_present                             NaN
# anaplasia_present_type                        NaN
# ann_arbor_b_symptoms                          NaN
# ann_arbor_clinical_stage                      NaN
# ann_arbor_extranodal_involvement              NaN
# ann_arbor_pathologic_stage                    NaN
# best_overall_response                         NaN
# breslow_thickness                             NaN
# burkitt_lymphoma_clinical_variant             NaN
# child_pugh_classification                     NaN
# circumferential_resection_margin              NaN
# cog_liver_stage                               NaN
# cog_neuroblastoma_risk_group                  NaN
# cog_rhabdomyosarcoma_risk_group               NaN
# days_to_best_overall_response                 NaN
# enneking_msts_grade                           NaN
# enneking_msts_metastasis                      NaN
# enneking_msts_stage                           NaN
# enneking_msts_tumor_site                      NaN
# esophageal_columnar_dysplasia_degree          NaN
# esophageal_columnar_metaplasia_present        NaN
# figo_stage                                    NaN
# first_symptom_prior_to_diagnosis              NaN
# gastric_esophageal_junction_involvement       NaN
# gleason_grade_group                           NaN
# goblet_cells_columnar_mucosa_present          NaN
# gross_tumor_weight                            NaN
# igcccg_stage                                  NaN
# inpc_grade                                    NaN
# inpc_histologic_group                         NaN
# inrg_stage                                    NaN
# inss_stage                                    NaN
# international_prognostic_index                NaN
# irs_group                                     NaN
# irs_stage                                     NaN
# ishak_fibrosis_score                          NaN
# iss_stage                                     NaN
# largest_extrapelvic_peritoneal_focus          NaN
# laterality                                    NaN
# lymph_nodes_positive                          NaN
# lymph_nodes_tested                            NaN
# lymphatic_invasion_present                    NaN
# masaoka_stage                                 NaN
# medulloblastoma_molecular_classification      NaN
# metastasis_at_diagnosis                       NaN
# metastasis_at_diagnosis_site                  NaN
# method_of_diagnosis                           NaN
# micropapillary_features                       NaN
# mitosis_karyorrhexis_index                    NaN
# mitotic_count                                 NaN
# non_nodal_regional_disease                    NaN
# non_nodal_tumor_deposits                      NaN
# ovarian_specimen_status                       NaN
# ovarian_surface_involvement                   NaN
# percent_tumor_invasion                        NaN
# perineural_invasion_present                   NaN
# peripancreatic_lymph_nodes_positive           NaN
# peripancreatic_lymph_nodes_tested             NaN
# peritoneal_fluid_cytological_status           NaN
# primary_gleason_grade                         NaN
# residual_disease                              NaN
# secondary_gleason_grade                       NaN
# supratentorial_localization                   NaN
# tumor_confined_to_organ_of_origin             NaN
# tumor_focality                                NaN
# tumor_largest_dimension_diameter              NaN
# tumor_regression_grade                        NaN
# vascular_invasion_present                     NaN
# vascular_invasion_type                        NaN
# weiss_assessment_score                        NaN
# wilms_tumor_histologic_subtype                NaN

# %%
pandas.DataFrame(filter(lambda d: d['days_to_last_follow_up'] is not None, diagnoses))
diagnoses[1]
# Out:
# {'age_at_diagnosis': 24286,
#  'ajcc_clinical_m': 'M0',
#  'ajcc_clinical_n': 'N1',
#  'ajcc_clinical_stage': 'Stage III',
#  'ajcc_clinical_t': 'T3',
#  'ajcc_pathologic_n': 'N2c',
#  'ajcc_pathologic_stage': 'Stage IVA',
#  'ajcc_pathologic_t': 'T3',
#  'ajcc_staging_system_edition': '7th',
#  'classification_of_tumor': 'not reported',
#  'created_datetime': None,
#  'days_to_diagnosis': 0,
#  'days_to_last_follow_up': 1460,
#  'days_to_last_known_disease_status': None,
#  'days_to_recurrence': None,
#  'diagnosis_id': '706b1290-3a85-54ea-a123-e8bd14b085bc',
#  'icd_10_code': 'C32.9',
#  'last_known_disease_status': 'not reported',
#  'morphology': '8070/3',
#  'primary_diagnosis': 'Squamous cell carcinoma, NOS',
#  'prior_malignancy': 'no',
#  'prior_treatment': 'No',
#  'progression_or_recurrence': 'not reported',
#  'site_of_resection_or_biopsy': 'Larynx, NOS',
#  'state': 'released',
#  'submitter_id': 'TCGA-CN-6012_diagnosis',
#  'synchronous_malignancy': 'No',
#  'tissue_or_organ_of_origin': 'Larynx, NOS',
#  'tumor_grade': 'not reported',
#  'tumor_stage': 'stage iva',
#  'updated_datetime': '2019-08-08T16:44:42.154844-05:00',
#  'year_of_diagnosis': 2010,
#  'index': 1}

# %%
pandas.set_option("display.max_rows", 10)

# %%
def create_stage_observation(type, value):
    # TODO: we use valueString, but we should really use valueCodeableConcept
    # once that is implemented.
    return ccdh.CancerStageObservation(
        observation_type=type,
        valueString=value
    )

def create_body_site(site_name):
    site_mappings = {
        'Larynx, NOS': 'Larynx'
    }
    
    if site_name in site_mappings:
        return ccdh.BodySite(site=site_mappings[site_name])
    return None

def create_stage_from_gdc(diag, subject):
    cancer_stage_method_type = None
    if diag.get('ajcc_staging_system_edition') == '7th':
        cancer_stage_method_type = 'AJCC staging system 7th edition'

    obs = ccdh.CancerStageObservationSet(
           method_type=cancer_stage_method_type,
           subject=subject
    )
    obs.observations.extend([
        create_stage_observation('Overall', diag.get('tumor_stage')),
        create_stage_observation('Clinical Overall', diag.get('ajcc_clinical_stage')),
        create_stage_observation('Clinical Tumor (T)', diag.get('ajcc_clinical_t')),
        create_stage_observation('Clinical Node (N)', diag.get('ajcc_clinical_n')),
        create_stage_observation('Clinical Metastasis (M)', diag.get('ajcc_clinical_m')),
        create_stage_observation('Pathological Overall', diag.get('ajcc_pathologic_stage')),
        create_stage_observation('Pathological Tumor (T)', diag.get('ajcc_pathologic_t')),
        create_stage_observation('Pathological Node (N)', diag.get('ajcc_pathologic_n')),
        create_stage_observation('Pathological Metastasis (M)', diag.get('ajcc_pathologic_m'))
    ])
    return obs

def map_diagnosis(diag, subject=None):
    ccdh_diagnosis = ccdh.Diagnosis(
        id=diag.get('diagnosis_id'),
        # age_at_diagnosis=ccdh.Quantity(
        #    # TODO: 'unit' doesn't have values yet.
        #    valueDecimal=diag.get('age_at_diagnosis')
        #),
        condition=diag.get('primary_diagnosis'),
        morphology=diag.get('morphology'),
        metastatic_site=create_body_site('tissue_or_organ_of_origin'),
        grade=diag.get('grade'),
        stage=create_stage_from_gdc(diag, subject)
        # year_at_diagnosis=diag.get('year_of_diagnosis')
    )
    ccdh_diagnosis.identifier = [
        create_identifier('GDC-submitter-id', diag.get('submitter_id'))
    ]

    return ccdh_diagnosis

# Unmapped fields:
# - classification_of_tumor
# - created_datetime
# - days_to_diagnosis
# - days_to_last_follow_up
# - days_to_last_known_disease_status
# - days_to_recurrence
# - icd_10_code
# - last_known_disease_status
# - site_of_resection_or_biopsy
# - state
# - synchronous_malignancy
# - tumor_grade
# - updated_datetime
# - year_of_diagnosis

firstDiagnosis = map_diagnosis(gdc_head_and_mouth[1]['diagnoses'][0])
# TODO: can't represent this as YAML because the YAML transformer doesn't know how to transform Decimal.
firstDiagnosis
# Out:
# Diagnosis(id='706b1290-3a85-54ea-a123-e8bd14b085bc', identifier=[Identifier(value='TCGA-CN-6012_diagnosis', system='GDC-submitter-id', type=None)], subject=None, age_at_diagnosis=None, year_at_diagnosis=None, condition=(text='Squamous cell carcinoma, NOS'), primary_site=[], metastatic_site=[], stage=[CancerStageObservationSet(id=None, category=None, focus=[], subject=None, method_type=[(text='AJCC staging system 7th edition', description='The 7th edition of the criteria developed by the American Joint Committee on Cancer (AJCC) in 2010, used for the classification and staging of neoplastic diseases.')], performed_by=None, observations=[CancerStageObservation(observation_type=(text='Overall', description='The overall stage of the disease'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='stage iva', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Overall', description='The overall stage of the disease; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='Stage III', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Tumor (T)', description='T classifies the size or direct extent of the primary tumor; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='T3', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Node (N)', description='N classifies the degree of spread to regional lymph nodes; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='N1', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Metastasis (M)', description='M classifies the presence of distant metastasis; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='M0', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Overall', description='The overall stage of the disease; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='Stage IVA', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Tumor (T)', description='T classifies the size or direct extent of the primary tumor; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='T3', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTi ...

# %%
diagnoses = list(map(lambda entry: list(map(map_diagnosis, entry['diagnoses'])), gdc_head_and_mouth))
diagnoses[0:5]
# Out:
# [[Diagnosis(id='5d2d67d1-4611-4a18-9a66-89823aaa8e3c', identifier=[Identifier(value='AD6426_diagnosis', system='GDC-submitter-id', type=None)], subject=None, age_at_diagnosis=None, year_at_diagnosis=None, condition=(text='Adenocarcinoma, NOS'), primary_site=[], metastatic_site=[], stage=[CancerStageObservationSet(id=None, category=None, focus=[], subject=None, method_type=[], performed_by=None, observations=[CancerStageObservation(observation_type=(text='Overall', description='The overall stage of the disease'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='not reported', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Overall', description='The overall stage of the disease; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Tumor (T)', description='T classifies the size or direct extent of the primary tumor; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Node (N)', description='N classifies the degree of spread to regional lymph nodes; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Metastasis (M)', description='M classifies the presence of distant metastasis; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Overall', description='The overall stage of the disease; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Tumor (T)', description='T classifies the size or direct extent of the primary tumor; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Node (N)', description='N classifies the degree of spread to regional lymph nodes; stage given by histopathologic examination  ...
#  [Diagnosis(id='706b1290-3a85-54ea-a123-e8bd14b085bc', identifier=[Identifier(value='TCGA-CN-6012_diagnosis', system='GDC-submitter-id', type=None)], subject=None, age_at_diagnosis=None, year_at_diagnosis=None, condition=(text='Squamous cell carcinoma, NOS'), primary_site=[], metastatic_site=[], stage=[CancerStageObservationSet(id=None, category=None, focus=[], subject=None, method_type=[(text='AJCC staging system 7th edition', description='The 7th edition of the criteria developed by the American Joint Committee on Cancer (AJCC) in 2010, used for the classification and staging of neoplastic diseases.')], performed_by=None, observations=[CancerStageObservation(observation_type=(text='Overall', description='The overall stage of the disease'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='stage iva', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Overall', description='The overall stage of the disease; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='Stage III', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Tumor (T)', description='T classifies the size or direct extent of the primary tumor; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='T3', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Node (N)', description='N classifies the degree of spread to regional lymph nodes; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='N1', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Metastasis (M)', description='M classifies the presence of distant metastasis; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='M0', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Overall', description='The overall stage of the disease; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='Stage IVA', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Tumor (T)', description='T classifies the size or direct extent of the primary tumor; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='T3', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDate ...
#  [Diagnosis(id='40954a8e-e4c2-5604-937b-0a79ac7489d2', identifier=[Identifier(value='TCGA-CV-7261_diagnosis', system='GDC-submitter-id', type=None)], subject=None, age_at_diagnosis=None, year_at_diagnosis=None, condition=(text='Squamous cell carcinoma, NOS'), primary_site=[], metastatic_site=[], stage=[CancerStageObservationSet(id=None, category=None, focus=[], subject=None, method_type=[(text='AJCC staging system 7th edition', description='The 7th edition of the criteria developed by the American Joint Committee on Cancer (AJCC) in 2010, used for the classification and staging of neoplastic diseases.')], performed_by=None, observations=[CancerStageObservation(observation_type=(text='Overall', description='The overall stage of the disease'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='stage iva', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Overall', description='The overall stage of the disease; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='Stage III', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Tumor (T)', description='T classifies the size or direct extent of the primary tumor; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='T3', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Node (N)', description='N classifies the degree of spread to regional lymph nodes; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='N0', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Metastasis (M)', description='M classifies the presence of distant metastasis; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='M0', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Overall', description='The overall stage of the disease; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='Stage IVA', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Tumor (T)', description='T classifies the size or direct extent of the primary tumor; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='T4a', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDat ...
#  [Diagnosis(id='48e8dd81-ed4d-5c54-af66-84e86477d5c8', identifier=[Identifier(value='TCGA-BA-A6DL_diagnosis', system='GDC-submitter-id', type=None)], subject=None, age_at_diagnosis=None, year_at_diagnosis=None, condition=(text='Squamous cell carcinoma, NOS'), primary_site=[], metastatic_site=[], stage=[CancerStageObservationSet(id=None, category=None, focus=[], subject=None, method_type=[(text='AJCC staging system 7th edition', description='The 7th edition of the criteria developed by the American Joint Committee on Cancer (AJCC) in 2010, used for the classification and staging of neoplastic diseases.')], performed_by=None, observations=[CancerStageObservation(observation_type=(text='Overall', description='The overall stage of the disease'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='not reported', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Overall', description='The overall stage of the disease; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='Stage III', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Tumor (T)', description='T classifies the size or direct extent of the primary tumor; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='T3', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Node (N)', description='N classifies the degree of spread to regional lymph nodes; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='N0', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Metastasis (M)', description='M classifies the presence of distant metastasis; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='M0', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Overall', description='The overall stage of the disease; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Tumor (T)', description='T classifies the size or direct extent of the primary tumor; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='T0', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime ...
#  [Diagnosis(id='1da5c51a-ee25-51a6-a4c2-27d8fdcbe24e', identifier=[Identifier(value='TCGA-CN-5365_diagnosis', system='GDC-submitter-id', type=None)], subject=None, age_at_diagnosis=None, year_at_diagnosis=None, condition=(text='Squamous cell carcinoma, NOS'), primary_site=[], metastatic_site=[], stage=[CancerStageObservationSet(id=None, category=None, focus=[], subject=None, method_type=[], performed_by=None, observations=[CancerStageObservation(observation_type=(text='Overall', description='The overall stage of the disease'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='stage ivb', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Overall', description='The overall stage of the disease; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='Stage IVC', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Tumor (T)', description='T classifies the size or direct extent of the primary tumor; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='T1', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Node (N)', description='N classifies the degree of spread to regional lymph nodes; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='N2', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Metastasis (M)', description='M classifies the presence of distant metastasis; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='M1', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Overall', description='The overall stage of the disease; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='Stage IVB', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Tumor (T)', description='T classifies the size or direct extent of the primary tumor; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='T2', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Node (N)', description='N classifies the degree of spread to regional lymph nodes; stage given by hi ...

# %%
gdc_head_and_mouth[0]
# Out:
# {'aliquot_ids': ['cfcde639-3045-4f66-84a6-ec74b090a5b6'],
#  'case_id': 'cd7e514f-71ba-4cc1-b74a-a22c6248169c',
#  'created_datetime': '2017-06-01T08:57:57.249456-05:00',
#  'diagnoses': [{'age_at_diagnosis': 19592,
#    'classification_of_tumor': 'metastasis',
#    'created_datetime': '2017-06-19T09:09:57.388287-05:00',
#    'days_to_last_follow_up': None,
#    'days_to_last_known_disease_status': None,
#    'days_to_recurrence': None,
#    'diagnosis_id': '5d2d67d1-4611-4a18-9a66-89823aaa8e3c',
#    'last_known_disease_status': 'not reported',
#    'morphology': '8140/3',
#    'primary_diagnosis': 'Adenocarcinoma, NOS',
#    'progression_or_recurrence': 'not reported',
#    'site_of_resection_or_biopsy': 'Nasal cavity',
#    'state': 'released',
#    'submitter_id': 'AD6426_diagnosis',
#    'tissue_or_organ_of_origin': 'Overlapping lesion of nasopharynx',
#    'tumor_grade': 'Not Reported',
#    'tumor_stage': 'not reported',
#    'updated_datetime': '2019-07-10T13:16:35.855027-05:00',
#    'index': 0}],
#  'diagnosis_ids': ['5d2d67d1-4611-4a18-9a66-89823aaa8e3c'],
#  'disease_type': 'Adenomas and Adenocarcinomas',
#  'id': 'cd7e514f-71ba-4cc1-b74a-a22c6248169c',
#  'primary_site': 'Nasopharynx',
#  'sample_ids': ['bdc73f48-dc0b-487d-abbe-e3a977b6830a'],
#  'samples': [{'created_datetime': '2017-06-01T10:44:57.790971-05:00',
#    'sample_id': 'bdc73f48-dc0b-487d-abbe-e3a977b6830a',
#    'sample_type': 'Metastatic',
#    'state': 'released',
#    'submitter_id': 'AD6426_sample',
#    'tissue_type': 'Not Reported',
#    'tumor_descriptor': 'Metastatic',
#    'updated_datetime': '2018-11-15T21:10:03.529893-06:00'}],
#  'slide_ids': ['ac2015e6-57d1-4a69-a35e-83a9df9ec618'],
#  'state': 'released',
#  'submitter_aliquot_ids': ['AD6426_aliquot'],
#  'submitter_diagnosis_ids': ['AD6426_diagnosis'],
#  'submitter_id': 'AD6426',
#  'submitter_sample_ids': ['AD6426_sample'],
#  'submitter_slide_ids': ['AD6426_slide'],
#  'updated_datetime': '2018-10-25T11:34:27.425461-05:00'}

# %%
def map_case(case):
    subject = ccdh.Subject(
        id=case.get('submitter_id')
    )
    rs = ccdh.ResearchSubject(
        id = case.get('id'),
        primary_diagnosis_site=create_body_site(case.get('primary_site')),
        associated_subject = subject,
        primary_diagnosis=list(map(lambda d: map_diagnosis(d, subject), case.get('diagnoses')))
    )
    # rs.primary_diagnosis=list(map(lambda d: map_diagnosis(d, subject), case.get('diagnoses')))

    # Unmapped fields:
    # - 'aliquot_ids'
    # - 'case_id'
    # - 'created_datetime'
    # - 'diagnoses'
    # - 'diagnosis_ids'
    # - 'disease_type'
    # - 'id'
    # - 'primary_site'
    # - 'sample_ids'
    # - 'state'
    # - 'submitter_aliquot_ids'
    # - 'submitter_diagnosis_ids'
    # - 'updated_datetime'

    return rs

firstResearchSubject = map_case(gdc_head_and_mouth[0])

firstResearchSubject
# Out:
# ResearchSubject(id='cd7e514f-71ba-4cc1-b74a-a22c6248169c', associated_subject=Subject(id='AD6426', identifier=[], species=None, breed=None, sex=None, ethnicity=None, race=[], year_of_birth=None, vital_status=None, age_at_death=None, year_of_death=None, cause_of_death=None), identifier=[], description=None, member_of_research_project=None, age_at_enrollment=None, primary_diagnosis_condition=None, primary_diagnosis_site=None, primary_diagnosis=[Diagnosis(id='5d2d67d1-4611-4a18-9a66-89823aaa8e3c', identifier=[Identifier(value='AD6426_diagnosis', system='GDC-submitter-id', type=None)], subject=None, age_at_diagnosis=None, year_at_diagnosis=None, condition=(text='Adenocarcinoma, NOS'), primary_site=[], metastatic_site=[], stage=[CancerStageObservationSet(id=None, category=None, focus=[], subject=Subject(id='AD6426', identifier=[], species=None, breed=None, sex=None, ethnicity=None, race=[], year_of_birth=None, vital_status=None, age_at_death=None, year_of_death=None, cause_of_death=None), method_type=[], performed_by=None, observations=[CancerStageObservation(observation_type=(text='Overall', description='The overall stage of the disease'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='not reported', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Overall', description='The overall stage of the disease; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Tumor (T)', description='T classifies the size or direct extent of the primary tumor; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Node (N)', description='N classifies the degree of spread to regional lymph nodes; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Metastasis (M)', description='M classifies the presence of distant metastasis; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Overall', description='The overall stage of the disease; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageOb ...

# %%
rss = list(map(map_case, gdc_head_and_mouth))
rss[0:5]
# Out:
# [ResearchSubject(id='cd7e514f-71ba-4cc1-b74a-a22c6248169c', associated_subject=Subject(id='AD6426', identifier=[], species=None, breed=None, sex=None, ethnicity=None, race=[], year_of_birth=None, vital_status=None, age_at_death=None, year_of_death=None, cause_of_death=None), identifier=[], description=None, member_of_research_project=None, age_at_enrollment=None, primary_diagnosis_condition=None, primary_diagnosis_site=None, primary_diagnosis=[Diagnosis(id='5d2d67d1-4611-4a18-9a66-89823aaa8e3c', identifier=[Identifier(value='AD6426_diagnosis', system='GDC-submitter-id', type=None)], subject=None, age_at_diagnosis=None, year_at_diagnosis=None, condition=(text='Adenocarcinoma, NOS'), primary_site=[], metastatic_site=[], stage=[CancerStageObservationSet(id=None, category=None, focus=[], subject=Subject(id='AD6426', identifier=[], species=None, breed=None, sex=None, ethnicity=None, race=[], year_of_birth=None, vital_status=None, age_at_death=None, year_of_death=None, cause_of_death=None), method_type=[], performed_by=None, observations=[CancerStageObservation(observation_type=(text='Overall', description='The overall stage of the disease'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='not reported', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Overall', description='The overall stage of the disease; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Tumor (T)', description='T classifies the size or direct extent of the primary tumor; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Node (N)', description='N classifies the degree of spread to regional lymph nodes; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Metastasis (M)', description='M classifies the presence of distant metastasis; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Overall', description='The overall stage of the disease; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString=None, valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageO ...
#  ResearchSubject(id='9023c9bf-02a0-4396-8161-304089957b62', associated_subject=Subject(id='TCGA-CN-6012', identifier=[], species=None, breed=None, sex=None, ethnicity=None, race=[], year_of_birth=None, vital_status=None, age_at_death=None, year_of_death=None, cause_of_death=None), identifier=[], description=None, member_of_research_project=None, age_at_enrollment=None, primary_diagnosis_condition=None, primary_diagnosis_site=None, primary_diagnosis=[Diagnosis(id='706b1290-3a85-54ea-a123-e8bd14b085bc', identifier=[Identifier(value='TCGA-CN-6012_diagnosis', system='GDC-submitter-id', type=None)], subject=None, age_at_diagnosis=None, year_at_diagnosis=None, condition=(text='Squamous cell carcinoma, NOS'), primary_site=[], metastatic_site=[], stage=[CancerStageObservationSet(id=None, category=None, focus=[], subject=Subject(id='TCGA-CN-6012', identifier=[], species=None, breed=None, sex=None, ethnicity=None, race=[], year_of_birth=None, vital_status=None, age_at_death=None, year_of_death=None, cause_of_death=None), method_type=[(text='AJCC staging system 7th edition', description='The 7th edition of the criteria developed by the American Joint Committee on Cancer (AJCC) in 2010, used for the classification and staging of neoplastic diseases.')], performed_by=None, observations=[CancerStageObservation(observation_type=(text='Overall', description='The overall stage of the disease'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='stage iva', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Overall', description='The overall stage of the disease; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='Stage III', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Tumor (T)', description='T classifies the size or direct extent of the primary tumor; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='T3', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Node (N)', description='N classifies the degree of spread to regional lymph nodes; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='N1', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Metastasis (M)', description='M classifies the presence of distant metastasis; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='M0', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Overall', description='The overall stage of the disease; stage given by histopathologic examination of a surgical specimen'), id=None, c ...
#  ResearchSubject(id='55f96a9c-e2c8-4243-8a7e-94bc6fab73a6', associated_subject=Subject(id='TCGA-CV-7261', identifier=[], species=None, breed=None, sex=None, ethnicity=None, race=[], year_of_birth=None, vital_status=None, age_at_death=None, year_of_death=None, cause_of_death=None), identifier=[], description=None, member_of_research_project=None, age_at_enrollment=None, primary_diagnosis_condition=None, primary_diagnosis_site=None, primary_diagnosis=[Diagnosis(id='40954a8e-e4c2-5604-937b-0a79ac7489d2', identifier=[Identifier(value='TCGA-CV-7261_diagnosis', system='GDC-submitter-id', type=None)], subject=None, age_at_diagnosis=None, year_at_diagnosis=None, condition=(text='Squamous cell carcinoma, NOS'), primary_site=[], metastatic_site=[], stage=[CancerStageObservationSet(id=None, category=None, focus=[], subject=Subject(id='TCGA-CV-7261', identifier=[], species=None, breed=None, sex=None, ethnicity=None, race=[], year_of_birth=None, vital_status=None, age_at_death=None, year_of_death=None, cause_of_death=None), method_type=[(text='AJCC staging system 7th edition', description='The 7th edition of the criteria developed by the American Joint Committee on Cancer (AJCC) in 2010, used for the classification and staging of neoplastic diseases.')], performed_by=None, observations=[CancerStageObservation(observation_type=(text='Overall', description='The overall stage of the disease'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='stage iva', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Overall', description='The overall stage of the disease; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='Stage III', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Tumor (T)', description='T classifies the size or direct extent of the primary tumor; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='T3', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Node (N)', description='N classifies the degree of spread to regional lymph nodes; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='N0', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Metastasis (M)', description='M classifies the presence of distant metastasis; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='M0', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Overall', description='The overall stage of the disease; stage given by histopathologic examination of a surgical specimen'), id=None, c ...
#  ResearchSubject(id='c9a36eb5-ac3e-424e-bc2e-303de7105957', associated_subject=Subject(id='TCGA-BA-A6DL', identifier=[], species=None, breed=None, sex=None, ethnicity=None, race=[], year_of_birth=None, vital_status=None, age_at_death=None, year_of_death=None, cause_of_death=None), identifier=[], description=None, member_of_research_project=None, age_at_enrollment=None, primary_diagnosis_condition=None, primary_diagnosis_site=None, primary_diagnosis=[Diagnosis(id='48e8dd81-ed4d-5c54-af66-84e86477d5c8', identifier=[Identifier(value='TCGA-BA-A6DL_diagnosis', system='GDC-submitter-id', type=None)], subject=None, age_at_diagnosis=None, year_at_diagnosis=None, condition=(text='Squamous cell carcinoma, NOS'), primary_site=[], metastatic_site=[], stage=[CancerStageObservationSet(id=None, category=None, focus=[], subject=Subject(id='TCGA-BA-A6DL', identifier=[], species=None, breed=None, sex=None, ethnicity=None, race=[], year_of_birth=None, vital_status=None, age_at_death=None, year_of_death=None, cause_of_death=None), method_type=[(text='AJCC staging system 7th edition', description='The 7th edition of the criteria developed by the American Joint Committee on Cancer (AJCC) in 2010, used for the classification and staging of neoplastic diseases.')], performed_by=None, observations=[CancerStageObservation(observation_type=(text='Overall', description='The overall stage of the disease'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='not reported', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Overall', description='The overall stage of the disease; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='Stage III', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Tumor (T)', description='T classifies the size or direct extent of the primary tumor; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='T3', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Node (N)', description='N classifies the degree of spread to regional lymph nodes; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='N0', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Metastasis (M)', description='M classifies the presence of distant metastasis; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='M0', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Overall', description='The overall stage of the disease; stage given by histopathologic examination of a surgical specimen'), id=None ...
#  ResearchSubject(id='4cffea0b-90a7-4c86-a73f-bb8feca3ada7', associated_subject=Subject(id='TCGA-CN-5365', identifier=[], species=None, breed=None, sex=None, ethnicity=None, race=[], year_of_birth=None, vital_status=None, age_at_death=None, year_of_death=None, cause_of_death=None), identifier=[], description=None, member_of_research_project=None, age_at_enrollment=None, primary_diagnosis_condition=None, primary_diagnosis_site=None, primary_diagnosis=[Diagnosis(id='1da5c51a-ee25-51a6-a4c2-27d8fdcbe24e', identifier=[Identifier(value='TCGA-CN-5365_diagnosis', system='GDC-submitter-id', type=None)], subject=None, age_at_diagnosis=None, year_at_diagnosis=None, condition=(text='Squamous cell carcinoma, NOS'), primary_site=[], metastatic_site=[], stage=[CancerStageObservationSet(id=None, category=None, focus=[], subject=Subject(id='TCGA-CN-5365', identifier=[], species=None, breed=None, sex=None, ethnicity=None, race=[], year_of_birth=None, vital_status=None, age_at_death=None, year_of_death=None, cause_of_death=None), method_type=[], performed_by=None, observations=[CancerStageObservation(observation_type=(text='Overall', description='The overall stage of the disease'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='stage ivb', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Overall', description='The overall stage of the disease; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='Stage IVC', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Tumor (T)', description='T classifies the size or direct extent of the primary tumor; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='T1', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Node (N)', description='N classifies the degree of spread to regional lymph nodes; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='N2', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Clinical Metastasis (M)', description='M classifies the presence of distant metastasis; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='M1', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, valueCodeableConcept=None), CancerStageObservation(observation_type=(text='Pathological Overall', description='The overall stage of the disease; stage given by histopathologic examination of a surgical specimen'), id=None, category=None, method_type=None, focus=None, subject=None, performed_by=None, valueEntity=None, valueString='Stage IVB', valueInteger=None, valueDecimal=None, valueBoolean=None, valueDateTime=None, valueQuantity=None, va ...

# %% [markdown]
# ## Exporting CRDC-H data as RDF
#
# LinkML supports this via JSON-LD.

# %%
from linkml.generators.jsonldcontextgen import ContextGenerator
from linkml.dumpers.json_dumper import dumps

jsonldContext = ContextGenerator('ccdh/ccdhmodel.yaml').serialize()

jsonld = dumps(firstDiagnosis, jsonldContext)
print(''.join(jsonld))
# Out:
# {
#   "id": "706b1290-3a85-54ea-a123-e8bd14b085bc",
#   "identifier": [
#     {
#       "value": "TCGA-CN-6012_diagnosis",
#       "system": "GDC-submitter-id"
#     }
#   ],
#   "condition": {
#     "text": "Squamous cell carcinoma, NOS"
#   },
#   "stage": [
#     {
#       "method_type": [
#         {}
#       ],
#       "observations": [
#         {
#           "observation_type": {
#             "text": "Overall",
#             "description": "The overall stage of the disease"
#           },
#           "valueString": "stage iva"
#         },
#         {
#           "observation_type": {
#             "text": "Clinical Overall",
#             "description": "The overall stage of the disease; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)"
#           },
#           "valueString": "Stage III"
#         },
#         {
#           "observation_type": {
#             "text": "Clinical Tumor (T)",
#             "description": "T classifies the size or direct extent of the primary tumor; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)"
#           },
#           "valueString": "T3"
#         },
#         {
#           "observation_type": {
#             "text": "Clinical Node (N)",
#             "description": "N classifies the degree of spread to regional lymph nodes; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)"
#           },
#           "valueString": "N1"
#         },
#         {
#           "observation_type": {
#             "text": "Clinical Metastasis (M)",
#             "description": "M classifies the presence of distant metastasis; clinical stage is determined from evidence acquired before treatment (including clinical examination, imaging, endoscopy, biopsy, surgical exploration)"
#           },
#           "valueString": "M0"
#         },
#         {
#           "observation_type": {
#             "text": "Pathological Overall",
#             "description": "The overall stage of the disease; stage given by histopathologic examination of a surgical specimen"
#           },
#           "valueString": "Stage IVA"
#         },
#         {
#           "observation_type": {
#             "text": "Pathological Tumor (T)",
#             "description": "T classifies the size or direct extent of the primary tumor; stage given by histopathologic examination of a surgical specimen"
#           },
#           "valueString": "T3"
#         },
#         {
#           "observation_type": {
#             "text": "Pathological Node (N)",
#             "description": "N classifies the degree of spread to regional lymph nodes; stage given by histopathologic examination of a surgical specimen"
#           },
#           "valueString": "N2c"
#         },
#         {
#           "observation_type": {
#             "text": "Pathological Metastasis (M)",
#             "description": "M classifies the presence of distant metastasis; stage given by histopathologic examination of a surgical specimen"
#           }
#         }
#       ]
#     }
#   ],
#   "morphology": {
#     "text": "8070/3"
#   },
#   "@type": "Diagnosis",
#   "@context": {
#     "GDC": "http://example.org/gdc/",
#     "HTAN": "http://example.org/htan/",
#     "ICDC": "http://example.org/icdc/",
#     "NCIT": {
#       "@id": "http://purl.obolibrary.org/obo/NCIT_",
#       "@prefix": true
#     },
#     "PDC": "http://example.org/pdc/",
#     "ccdh": "https://example.org/ccdh/",
#     "linkml": "https://w3id.org/linkml/",
#     "skos": "http://www.w3.org/2004/02/skos/core#",
#     "@vocab": "https://example.org/ccdh/",
#     "category": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "focus": {
#       "@type": "@id"
#     },
#     "method_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "observation_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "performed_by": {
#       "@type": "@id"
#     },
#     "subject": {
#       "@type": "@id"
#     },
#     "valueBoolean": {
#       "@type": "xsd:boolean"
#     },
#     "valueCodeableConcept": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "valueDateTime": {
#       "@type": "xsd:dateTime"
#     },
#     "valueDecimal": {
#       "@type": "xsd:decimal"
#     },
#     "valueEntity": {
#       "@type": "@id"
#     },
#     "valueInteger": {
#       "@type": "xsd:integer"
#     },
#     "valueQuantity": {
#       "@type": "@id"
#     },
#     "identifier": {
#       "@type": "@id"
#     },
#     "passage_number": {
#       "@type": "xsd:integer"
#     },
#     "product_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "qualifier": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "site": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "observations": {
#       "@type": "@id"
#     },
#     "coding": {
#       "@type": "@id"
#     },
#     "age_at_diagnosis": {
#       "@type": "@id"
#     },
#     "condition": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "dimensional_measure": {
#       "@type": "@id"
#     },
#     "disease_status": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "grade": {
#       "@type": "@id"
#     },
#     "metastatic_site": {
#       "@type": "@id"
#     },
#     "method_of_diagnosis": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "morphology": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "primary_site": {
#       "@type": "@id"
#     },
#     "prior_diagnosis": {
#       "@type": "@id"
#     },
#     "related_specimen": {
#       "@type": "@id"
#     },
#     "stage": {
#       "@type": "@id"
#     },
#     "supporting_observations": {
#       "@type": "@id"
#     },
#     "year_at_diagnosis": {
#       "@type": "xsd:integer"
#     },
#     "document_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "alcohol_exposure": {
#       "@type": "@id"
#     },
#     "environmental_exposure": {
#       "@type": "@id"
#     },
#     "tobacco_exposure": {
#       "@type": "@id"
#     },
#     "type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "unit": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "date_ended": {
#       "@type": "@id"
#     },
#     "date_iacuc_approval": {
#       "@type": "@id"
#     },
#     "date_started": {
#       "@type": "@id"
#     },
#     "part_of": {
#       "@type": "@id"
#     },
#     "primary_anatomic_site": {
#       "@type": "@id"
#     },
#     "research_project_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "age_at_enrollment": {
#       "@type": "@id"
#     },
#     "associated_subject": {
#       "@type": "@id"
#     },
#     "comorbid_diagnosis": {
#       "@type": "@id"
#     },
#     "index_timepoint": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "member_of_research_project": {
#       "@type": "@id"
#     },
#     "originating_site": {
#       "@type": "@id"
#     },
#     "primary_diagnosis": {
#       "@type": "@id"
#     },
#     "primary_diagnosis_condition": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "primary_diagnosis_site": {
#       "@type": "@id"
#     },
#     "analyte_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "associated_project": {
#       "@type": "@id"
#     },
#     "cellular_composition_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "contained_in": {
#       "@type": "@id"
#     },
#     "creation_activity": {
#       "@type": "@id"
#     },
#     "data_provider": {
#       "@type": "@id"
#     },
#     "degree_of_dysplasia": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "derived_product": {
#       "@type": "@id"
#     },
#     "distance_from_paired_specimen": {
#       "@type": "@id"
#     },
#     "general_tissue_morphology": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "histological_composition_measure": {
#       "@type": "@id"
#     },
#     "morphlogy_assessment_method": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "morphology_assessor_role": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "morphology_pathologically_confirmed": {
#       "@type": "xsd:boolean"
#     },
#     "parent_specimen": {
#       "@type": "@id"
#     },
#     "preinvasive_tissue_morphology": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "processing_activity": {
#       "@type": "@id"
#     },
#     "quality_measure": {
#       "@type": "@id"
#     },
#     "quantity_measure": {
#       "@type": "@id"
#     },
#     "related_document": {
#       "@type": "@id"
#     },
#     "section_location": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "source_material_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "source_model_system": {
#       "@type": "@id"
#     },
#     "source_subject": {
#       "@type": "@id"
#     },
#     "specific_tissue_morphology": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "specimen_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "storage_activity": {
#       "@type": "@id"
#     },
#     "transport_activity": {
#       "@type": "@id"
#     },
#     "tumor_status_at_collection": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "additive": {
#       "@type": "@id"
#     },
#     "charge_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "container_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "parent_container": {
#       "@type": "@id"
#     },
#     "activity_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "collection_method_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "collection_site": {
#       "@type": "@id"
#     },
#     "derivation_method_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "execution_observation": {
#       "@type": "@id"
#     },
#     "quantity_collected": {
#       "@type": "@id"
#     },
#     "specimen_order": {
#       "@type": "xsd:integer"
#     },
#     "duration": {
#       "@type": "@id"
#     },
#     "container": {
#       "@type": "@id"
#     },
#     "transport_destination": {
#       "@type": "@id"
#     },
#     "transport_origin": {
#       "@type": "@id"
#     },
#     "age_at_death": {
#       "@type": "@id"
#     },
#     "breed": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "cause_of_death": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "ethnicity": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "race": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "sex": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "species": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "vital_status": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "year_of_birth": {
#       "@type": "xsd:integer"
#     },
#     "year_of_death": {
#       "@type": "xsd:integer"
#     },
#     "role": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "substance_quantity": {
#       "@type": "@id"
#     },
#     "substance_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "periodEnd_end": {
#       "@type": "@id"
#     },
#     "periodStart_start": {
#       "@type": "@id"
#     },
#     "dateTime": {
#       "@type": "xsd:dateTime"
#     },
#     "eventType": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "indexTimePoint": {
#       "@type": "@id"
#     },
#     "offsetFromIndex": {
#       "@type": "@id"
#     },
#     "concurrent_treatment": {
#       "@type": "@id"
#     },
#     "number_of_cycles": {
#       "@type": "xsd:integer"
#     },
#     "regimen": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "therapeutic_agent": {
#       "@type": "@id"
#     },
#     "treatment_anatomic_site": {
#       "@type": "@id"
#     },
#     "treatment_effect": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "treatment_end_reason": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "treatment_for_diagnosis": {
#       "@type": "@id"
#     },
#     "treatment_frequency": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "treatment_intent": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "treatment_outcome": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     },
#     "treatment_type": {
#       "@context": {
#         "@vocab": "@null",
#         "text": "skos:notation",
#         "description": "skos:prefLabel",
#         "meaning": "@id"
#       }
#     }
#   }
# }

# %%
with open('head-and-mouth/ccdh-head-and-mouth.jsonld', 'w') as file:
    jsonld = dumps(rss[3], jsonldContext)
    file.write(''.join(jsonld))

# %%
# We can read this JSON-LD in Turtle.
from rdflib import Graph

g = Graph()
g.parse(data=jsonld, format="json-ld")
rdfAsTurtle = g.serialize(format="turtle").decode()
print(rdfAsTurtle)

# %% [markdown]
# ## Incorporating PDC data

# %%
with open('head-and-mouth/pdc-head-and-mouth.json') as file:
    pdc_head_and_mouth = json.load(file)
    
pandas.DataFrame(pdc_head_and_mouth)

# %%
firstPdcSample = pdc_head_and_mouth[0]['samples'][0]

firstPdcSample

# %%
pdcSpecimen = entities.Specimen(
    id = firstPdcSample['sample_id'],
    analyte_type = entities.CodeableConcept(
        entities.Coding(
            firstSample['sample_type']
        )
    )
)

pdcSpecimen
