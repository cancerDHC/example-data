# %% [markdown]
# # CDA example for subject 09CO022
#
# ## Introduction
#
# This example was [developed by Ian Fore](https://github.com/ianfore/cdatest/blob/8002ae1624b34e0e2f291022c295d4b778989de9/09CO022%20Example.ipynb) to determine if CDA could link together data from three different [NCI CRDC](https://datascience.cancer.gov/data-commons) nodes by the [CDA](https://datacommons.cancer.gov/cancer-data-aggregator).
#
# It is based on subject 09CO022 from the TCGA Colon Cancer project. This subject is found in at least three NCI CRDC nodes:
# * [Case ID 09CO022 from GDC](https://portal.gdc.cancer.gov/cases/c5421e34-e5c7-4ba5-aed9-146a5575fd8d)
# * [Case ID 09CO022 from PDC](https://proteomic.datacommons.cancer.gov/pdc/case/459e3b69-63d6-11e8-bcf1-0a2705229b82)
# * (possibly?) [Three images](https://pathology.cancerimagingarchive.net/pathdata/select.html?filter=%7B%22study%22%3A%7B%22match%22%3A%22CPTAC%22%7D%2C%22subject_id%22%3A%7B%22match%22%3A%2209CO022%22%7D%7D) from The Cancer Imaging Archive (TCIA).

# %% [markdown]
# ## Setup
#
# We only need to install the [cda-python](https://github.com/CancerDataAggregator/cda-python) library so we can access the CDA API.

# %%
import sys

# Install cdapython so we can access the CDA API.
# !{sys.executable} -m pip install git+https://github.com/CancerDataAggregator/cda-python.git
# Out:
# Collecting git+https://github.com/CancerDataAggregator/cda-python.git
#   Cloning https://github.com/CancerDataAggregator/cda-python.git to /private/var/folders/j7/wl1qrc1n7fv9vnszw_0dsm680000gn/T/pip-req-build-oahp81nu
#   Running command git clone -q https://github.com/CancerDataAggregator/cda-python.git /private/var/folders/j7/wl1qrc1n7fv9vnszw_0dsm680000gn/T/pip-req-build-oahp81nu
# Collecting cda-client@ git+https://github.com/CancerDataAggregator/cda-service-python-client.git
#   Cloning https://github.com/CancerDataAggregator/cda-service-python-client.git to /private/var/folders/j7/wl1qrc1n7fv9vnszw_0dsm680000gn/T/pip-install-0i91nroh/cda-client_e12c0169ea3b4f6ea10e67848167dfe1
#   Running command git clone -q https://github.com/CancerDataAggregator/cda-service-python-client.git /private/var/folders/j7/wl1qrc1n7fv9vnszw_0dsm680000gn/T/pip-install-0i91nroh/cda-client_e12c0169ea3b4f6ea10e67848167dfe1
# Collecting urllib3>=1.15
#   Using cached urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Requirement already satisfied: six>=1.10 in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (from cda-client@ git+https://github.com/CancerDataAggregator/cda-service-python-client.git->cdapython==2021.2.23) (1.15.0)
# Collecting certifi
#   Using cached certifi-2020.12.5-py2.py3-none-any.whl (147 kB)
# Requirement already satisfied: python-dateutil in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (from cda-client@ git+https://github.com/CancerDataAggregator/cda-service-python-client.git->cdapython==2021.2.23) (2.8.1)
# Using legacy 'setup.py install' for cdapython, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for cda-client, since package 'wheel' is not installed.
# Installing collected packages: urllib3, certifi, cda-client, cdapython
#     Running setup.py install for cda-client ... done
#     Running setup.py install for cdapython ... done
# Successfully installed cda-client-1.0.0 cdapython-2021.2.23 certifi-2020.12.5 urllib3-1.26.4

# %% [markdown]
# ## What do we know about Subject 09CO022?
#
# Let's start by searching each node individually.

# %%
submitter_id = '09CO022'

# %% [markdown]
# ### From GDC
#
# We can search GDC using the [GDC Cases API](https://docs.gdc.cancer.gov/API/Users_Guide/Search_and_Retrieval/#cases-endpoint) for `submitted_id == 09CO022`. Note that with the GDC API, you specifically have to request that certain sections (`diagnoses` and `samples` in this example) are expanded -- other sections, such as `aliquot_ids` only include identifiers, unless we explicitly ask for them to be expanded as well.

# %%
# Load required packages.
import requests
import json

# %%
# Search by subject_id.
cases_endpt = "https://api.gdc.cancer.gov/cases"

filters = {
    "op": "in",
    "content":{
        "field": "submitter_id",
        "value": [ submitter_id ]
    }
}

params = {
    "filters": json.dumps(filters),
    "expand": "diagnoses,samples",
    "format": "JSON",
    "size": "2"
}

response = requests.get(cases_endpt, params = params)
result = json.loads(response.content)

result
# Out:
# {'data': {'hits': [{'id': 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d',
#     'lost_to_followup': None,
#     'days_to_lost_to_followup': None,
#     'disease_type': 'Adenomas and Adenocarcinomas',
#     'submitter_id': '09CO022',
#     'aliquot_ids': ['0d8adcbf-13f0-48c3-83df-3fa205b79ae8',
#      '9250d96e-1cdc-4d68-8a56-f7b186a6fab5',
#      'ce309009-9257-4c13-9241-83fc629c35a0'],
#     'submitter_aliquot_ids': ['f69deaeb-6b6f-4c61-8900-fd0f26_D7_1',
#      '60805d52-8ca1-46d4-8101-0ad055_D1_1',
#      'f69deaeb-6b6f-4c61-8900-fd0f26_D6_2'],
#     'diagnoses': [{'irs_stage': None,
#       'anaplasia_present_type': None,
#       'iss_stage': None,
#       'ajcc_pathologic_stage': 'Stage IIB',
#       'gross_tumor_weight': None,
#       'tumor_largest_dimension_diameter': None,
#       'tumor_stage': 'Stage IIB',
#       'ann_arbor_clinical_stage': None,
#       'enneking_msts_stage': None,
#       'created_datetime': '2017-03-01T11:57:00.297885-06:00',
#       'circumferential_resection_margin': None,
#       'inrg_stage': None,
#       'enneking_msts_metastasis': None,
#       'tissue_or_organ_of_origin': 'Colon, NOS',
#       'age_at_diagnosis': None,
#       'esophageal_columnar_dysplasia_degree': None,
#       'cog_liver_stage': None,
#       'child_pugh_classification': None,
#       'peripancreatic_lymph_nodes_positive': None,
#       'peripancreatic_lymph_nodes_tested': None,
#       'metastasis_at_diagnosis_site': None,
#       'prior_treatment': None,
#       'state': 'released',
#       'days_to_last_known_disease_status': None,
#       'cog_rhabdomyosarcoma_risk_group': None,
#       'primary_gleason_grade': None,
#       'ajcc_pathologic_t': None,
#       'inpc_grade': None,
#       'morphology': '8140/3',
#       'ajcc_pathologic_n': None,
#       'ajcc_pathologic_m': None,
#       'medulloblastoma_molecular_classification': None,
#       'irs_group': None,
#       'perineural_invasion_present': None,
#       'wilms_tumor_histologic_subtype': None,
#       'classification_of_tumor': 'not reported',
#       'residual_disease': None,
#       'weiss_assessment_score': None,
#       'tumor_focality': None,
#       'ann_arbor_b_symptoms': None,
#       'vascular_invasion_present': None,
#       'icd_10_code': None,
#       'cog_renal_stage': None,
#       'anaplasia_present': None,
#       'figo_stage': 'Not Reported',
#       'synchronous_malignancy': None,
#       'burkitt_lymphoma_clinical_variant': None,
#       'days_to_best_overall_response': None,
#       'lymph_nodes_tested': None,
#       'inss_stage': None,
#       'supratentorial_localization': None,
#       'ishak_fibrosis_score': None,
#       'vascular_invasion_type': None,
#       'tumor_confined_to_organ_of_origin': None,
#       'gleason_grade_group': None,
#       'goblet_cells_columnar_mucosa_present': None,
#       'days_to_diagnosis': None,
#       'laterality': None,
#       'last_known_disease_status': 'not reported',
#       'days_to_last_follow_up': None,
#       'ajcc_clinical_stage': None,
#       'primary_diagnosis': 'Adenocarcinoma, NOS',
#       'cog_neuroblastoma_risk_group': None,
#       'metastasis_at_diagnosis': None,
#       'enneking_msts_tumor_site': None,
#       'updated_datetime': '2019-10-24T07:59:21.887408-05:00',
#       'prior_malignancy': 'no',
#       'year_of_diagnosis': None,
#       'secondary_gleason_grade': None,
#       'best_overall_response': None,
#       'ann_arbor_pathologic_stage': None,
#       'ann_arbor_extranodal_involvement': None,
#       'method_of_diagnosis': None,
#       'mitosis_karyorrhexis_index': None,
#       'ajcc_staging_system_edition': None,
#       'days_to_recurrence': None,
#       'esophageal_columnar_metaplasia_present': None,
#       'ajcc_clinical_m': None,
#       'ajcc_clinical_n': None,
#       'submitter_id': '09CO022-DX',
#       'ajcc_clinical_t': None,
#       'lymph_nodes_positive': None,
#       'inpc_histologic_group': None,
#       'micropapillary_features': None,
#       'masaoka_stage': None,
#       'diagnosis_id': '7b8d36ba-ab84-48ad-ac2c-11ac40d3d0eb',
#       'igcccg_stage': None,
#       'lymphatic_invasion_present': None,
#       'site_of_resection_or_biopsy': 'Not Reported',
#       'tumor_regression_grade': None,
#       'first_symptom_prior_to_diagnosis': None,
#       'enneking_msts_grade': None,
#       'gastric_esophageal_junction_involvement': None,
#       'tumor_grade': 'Not Reported',
#       'progression_or_recurrence': 'not reported'}],
#     'diagnosis_ids': ['7b8d36ba-ab84-48ad-ac2c-11ac40d3d0eb'],
#     'samples': [{'distributor_reference': None,
#       'sample_type_id': '10',
#       'tumor_descriptor': None,
#       'sample_id': 'b12c257d-7409-4858-9384-c430929a075a',
#       'diagnosis_pathologically_confirmed': None,
#       'sample_type': 'Blood Derived Normal',
#       'distance_normal_to_tumor': None,
#       'tumor_code': None,
#       'created_datetime': '2017-01-25T15:31:52.788719-06:00',
#       'time_between_excision_and_freezing': None,
#       'growth_rate': None,
#       'composition': None,
#       'updated_datetime': '2019-10-24T07:59:21.887408-05:00',
#       'days_to_collection': None,
#       'method_of_sample_procurement': None,
#       'state': 'released',
#       'initial_weight': None,
#       'preservation_method': None,
#       'intermediate_dimension': None,
#       'passage_count': None,
#       'time_between_clamping_and_freezing': None,
#       'freezing_method': None,
#       'pathology_report_uuid': None,
#       'tumor_code_id': None,
#       'submitter_id': '60805d52-8ca1-46d4-8101-0ad055',
#       'shortest_dimension': None,
#       'biospecimen_anatomic_site': None,
#       'oct_embedded': None,
#       'days_to_sample_procurement': None,
#       'biospecimen_laterality': None,
#       'longest_dimension': None,
#       'current_weight': None,
#       'catalog_reference': None,
#       'is_ffpe': None,
#       'tissue_type': 'Not Reported'},
#      {'distributor_reference': None,
#       'sample_type_id': '01',
#       'tumor_descriptor': None,
#       'sample_id': '4591a53d-5668-4a70-b44b-e08a3d59267e',
#       'diagnosis_pathologically_confirmed': None,
#       'sample_type': 'Primary Tumor',
#       'distance_normal_to_tumor': None,
#       'tumor_code': None,
#       'created_datetime': '2017-01-25T15:31:52.788719-06:00',
#       'time_between_excision_and_freezing': None,
#       'growth_rate': None,
#       'composition': None,
#       'updated_datetime': '2019-10-24T07:59:21.887408-05:00',
#       'days_to_collection': None,
#       'method_of_sample_procurement': None,
#       'state': 'released',
#       'initial_weight': None,
#       'preservation_method': None,
#       'intermediate_dimension': None,
#       'passage_count': None,
#       'time_between_clamping_and_freezing': None,
#       'freezing_method': None,
#       'pathology_report_uuid': None,
#       'tumor_code_id': None,
#       'submitter_id': 'f69deaeb-6b6f-4c61-8900-fd0f26',
#       'shortest_dimension': None,
#       'biospecimen_anatomic_site': None,
#       'oct_embedded': None,
#       'days_to_sample_procurement': None,
#       'biospecimen_laterality': None,
#       'longest_dimension': None,
#       'current_weight': None,
#       'catalog_reference': None,
#       'is_ffpe': None,
#       'tissue_type': 'Not Reported'}],
#     'sample_ids': ['4591a53d-5668-4a70-b44b-e08a3d59267e',
#      'b12c257d-7409-4858-9384-c430929a075a'],
#     'created_datetime': '2017-01-25T15:29:16.160843-06:00',
#     'submitter_sample_ids': ['f69deaeb-6b6f-4c61-8900-fd0f26',
#      '60805d52-8ca1-46d4-8101-0ad055'],
#     'primary_site': 'Colon',
#     'submitter_diagnosis_ids': ['09CO022-DX'],
#     'updated_datetime': '2019-10-24T07:59:21.887408-05:00',
#     'case_id': 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d',
#     'index_date': None,
#     'state': 'released'}],
#   'pagination': {'count': 1,
#    'total': 1,
#    'size': 2,
#    'from': 0,
#    'sort': '',
#    'page': 1,
#    'pages': 1}},
#  'warnings': {}}

# %%
cases = result['data']['hits']

# We should only have one case for subject 09CO022.
assert len(cases) == 1
case = cases[0]

# Write this to a file.
with open('gdc_subject_09CO022.json', 'w') as f:
    json.dump(case, f, indent=4, sort_keys=True)

# What information do we have on this case?
case
# Out:
# {'id': 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d',
#  'lost_to_followup': None,
#  'days_to_lost_to_followup': None,
#  'disease_type': 'Adenomas and Adenocarcinomas',
#  'submitter_id': '09CO022',
#  'aliquot_ids': ['0d8adcbf-13f0-48c3-83df-3fa205b79ae8',
#   '9250d96e-1cdc-4d68-8a56-f7b186a6fab5',
#   'ce309009-9257-4c13-9241-83fc629c35a0'],
#  'submitter_aliquot_ids': ['f69deaeb-6b6f-4c61-8900-fd0f26_D7_1',
#   '60805d52-8ca1-46d4-8101-0ad055_D1_1',
#   'f69deaeb-6b6f-4c61-8900-fd0f26_D6_2'],
#  'diagnoses': [{'irs_stage': None,
#    'anaplasia_present_type': None,
#    'iss_stage': None,
#    'ajcc_pathologic_stage': 'Stage IIB',
#    'gross_tumor_weight': None,
#    'tumor_largest_dimension_diameter': None,
#    'tumor_stage': 'Stage IIB',
#    'ann_arbor_clinical_stage': None,
#    'enneking_msts_stage': None,
#    'created_datetime': '2017-03-01T11:57:00.297885-06:00',
#    'circumferential_resection_margin': None,
#    'inrg_stage': None,
#    'enneking_msts_metastasis': None,
#    'tissue_or_organ_of_origin': 'Colon, NOS',
#    'age_at_diagnosis': None,
#    'esophageal_columnar_dysplasia_degree': None,
#    'cog_liver_stage': None,
#    'child_pugh_classification': None,
#    'peripancreatic_lymph_nodes_positive': None,
#    'peripancreatic_lymph_nodes_tested': None,
#    'metastasis_at_diagnosis_site': None,
#    'prior_treatment': None,
#    'state': 'released',
#    'days_to_last_known_disease_status': None,
#    'cog_rhabdomyosarcoma_risk_group': None,
#    'primary_gleason_grade': None,
#    'ajcc_pathologic_t': None,
#    'inpc_grade': None,
#    'morphology': '8140/3',
#    'ajcc_pathologic_n': None,
#    'ajcc_pathologic_m': None,
#    'medulloblastoma_molecular_classification': None,
#    'irs_group': None,
#    'perineural_invasion_present': None,
#    'wilms_tumor_histologic_subtype': None,
#    'classification_of_tumor': 'not reported',
#    'residual_disease': None,
#    'weiss_assessment_score': None,
#    'tumor_focality': None,
#    'ann_arbor_b_symptoms': None,
#    'vascular_invasion_present': None,
#    'icd_10_code': None,
#    'cog_renal_stage': None,
#    'anaplasia_present': None,
#    'figo_stage': 'Not Reported',
#    'synchronous_malignancy': None,
#    'burkitt_lymphoma_clinical_variant': None,
#    'days_to_best_overall_response': None,
#    'lymph_nodes_tested': None,
#    'inss_stage': None,
#    'supratentorial_localization': None,
#    'ishak_fibrosis_score': None,
#    'vascular_invasion_type': None,
#    'tumor_confined_to_organ_of_origin': None,
#    'gleason_grade_group': None,
#    'goblet_cells_columnar_mucosa_present': None,
#    'days_to_diagnosis': None,
#    'laterality': None,
#    'last_known_disease_status': 'not reported',
#    'days_to_last_follow_up': None,
#    'ajcc_clinical_stage': None,
#    'primary_diagnosis': 'Adenocarcinoma, NOS',
#    'cog_neuroblastoma_risk_group': None,
#    'metastasis_at_diagnosis': None,
#    'enneking_msts_tumor_site': None,
#    'updated_datetime': '2019-10-24T07:59:21.887408-05:00',
#    'prior_malignancy': 'no',
#    'year_of_diagnosis': None,
#    'secondary_gleason_grade': None,
#    'best_overall_response': None,
#    'ann_arbor_pathologic_stage': None,
#    'ann_arbor_extranodal_involvement': None,
#    'method_of_diagnosis': None,
#    'mitosis_karyorrhexis_index': None,
#    'ajcc_staging_system_edition': None,
#    'days_to_recurrence': None,
#    'esophageal_columnar_metaplasia_present': None,
#    'ajcc_clinical_m': None,
#    'ajcc_clinical_n': None,
#    'submitter_id': '09CO022-DX',
#    'ajcc_clinical_t': None,
#    'lymph_nodes_positive': None,
#    'inpc_histologic_group': None,
#    'micropapillary_features': None,
#    'masaoka_stage': None,
#    'diagnosis_id': '7b8d36ba-ab84-48ad-ac2c-11ac40d3d0eb',
#    'igcccg_stage': None,
#    'lymphatic_invasion_present': None,
#    'site_of_resection_or_biopsy': 'Not Reported',
#    'tumor_regression_grade': None,
#    'first_symptom_prior_to_diagnosis': None,
#    'enneking_msts_grade': None,
#    'gastric_esophageal_junction_involvement': None,
#    'tumor_grade': 'Not Reported',
#    'progression_or_recurrence': 'not reported'}],
#  'diagnosis_ids': ['7b8d36ba-ab84-48ad-ac2c-11ac40d3d0eb'],
#  'samples': [{'distributor_reference': None,
#    'sample_type_id': '10',
#    'tumor_descriptor': None,
#    'sample_id': 'b12c257d-7409-4858-9384-c430929a075a',
#    'diagnosis_pathologically_confirmed': None,
#    'sample_type': 'Blood Derived Normal',
#    'distance_normal_to_tumor': None,
#    'tumor_code': None,
#    'created_datetime': '2017-01-25T15:31:52.788719-06:00',
#    'time_between_excision_and_freezing': None,
#    'growth_rate': None,
#    'composition': None,
#    'updated_datetime': '2019-10-24T07:59:21.887408-05:00',
#    'days_to_collection': None,
#    'method_of_sample_procurement': None,
#    'state': 'released',
#    'initial_weight': None,
#    'preservation_method': None,
#    'intermediate_dimension': None,
#    'passage_count': None,
#    'time_between_clamping_and_freezing': None,
#    'freezing_method': None,
#    'pathology_report_uuid': None,
#    'tumor_code_id': None,
#    'submitter_id': '60805d52-8ca1-46d4-8101-0ad055',
#    'shortest_dimension': None,
#    'biospecimen_anatomic_site': None,
#    'oct_embedded': None,
#    'days_to_sample_procurement': None,
#    'biospecimen_laterality': None,
#    'longest_dimension': None,
#    'current_weight': None,
#    'catalog_reference': None,
#    'is_ffpe': None,
#    'tissue_type': 'Not Reported'},
#   {'distributor_reference': None,
#    'sample_type_id': '01',
#    'tumor_descriptor': None,
#    'sample_id': '4591a53d-5668-4a70-b44b-e08a3d59267e',
#    'diagnosis_pathologically_confirmed': None,
#    'sample_type': 'Primary Tumor',
#    'distance_normal_to_tumor': None,
#    'tumor_code': None,
#    'created_datetime': '2017-01-25T15:31:52.788719-06:00',
#    'time_between_excision_and_freezing': None,
#    'growth_rate': None,
#    'composition': None,
#    'updated_datetime': '2019-10-24T07:59:21.887408-05:00',
#    'days_to_collection': None,
#    'method_of_sample_procurement': None,
#    'state': 'released',
#    'initial_weight': None,
#    'preservation_method': None,
#    'intermediate_dimension': None,
#    'passage_count': None,
#    'time_between_clamping_and_freezing': None,
#    'freezing_method': None,
#    'pathology_report_uuid': None,
#    'tumor_code_id': None,
#    'submitter_id': 'f69deaeb-6b6f-4c61-8900-fd0f26',
#    'shortest_dimension': None,
#    'biospecimen_anatomic_site': None,
#    'oct_embedded': None,
#    'days_to_sample_procurement': None,
#    'biospecimen_laterality': None,
#    'longest_dimension': None,
#    'current_weight': None,
#    'catalog_reference': None,
#    'is_ffpe': None,
#    'tissue_type': 'Not Reported'}],
#  'sample_ids': ['4591a53d-5668-4a70-b44b-e08a3d59267e',
#   'b12c257d-7409-4858-9384-c430929a075a'],
#  'created_datetime': '2017-01-25T15:29:16.160843-06:00',
#  'submitter_sample_ids': ['f69deaeb-6b6f-4c61-8900-fd0f26',
#   '60805d52-8ca1-46d4-8101-0ad055'],
#  'primary_site': 'Colon',
#  'submitter_diagnosis_ids': ['09CO022-DX'],
#  'updated_datetime': '2019-10-24T07:59:21.887408-05:00',
#  'case_id': 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d',
#  'index_date': None,
#  'state': 'released'}

# %% [markdown]
# ### From PDC
#
# PDC has a GraphQL endpoint we can use to make these queries.

# %%
# Search for case submitter ID 09CO022:

# I got this query from https://pdc.cancer.gov/data-dictionary/publicapi-documentation/#!/Case/case
graphql_query = """{
    case (
        case_submitter_id: "%s"
        acceptDUA: true
    ) {
        case_id case_submitter_id project_submitter_id days_to_lost_to_followup disease_type
        index_date lost_to_followup primary_site
        externalReferences {
            external_reference_id
            reference_resource_shortname reference_resource_name reference_entity_location
        }
        demographics {
            demographic_id ethnicity gender demographic_submitter_id race cause_of_death days_to_birth
            days_to_death vital_status year_of_birth year_of_death
        }
        samples {
            sample_id sample_submitter_id sample_type sample_type_id gdc_sample_id gdc_project_id
            biospecimen_anatomic_site composition current_weight days_to_collection days_to_sample_procurement
            diagnosis_pathologically_confirmed freezing_method initial_weight intermediate_dimension is_ffpe
            longest_dimension method_of_sample_procurement oct_embedded pathology_report_uuid preservation_method
            sample_type_id shortest_dimension time_between_clamping_and_freezing time_between_excision_and_freezing
            tissue_type tumor_code tumor_code_id tumor_descriptor
            aliquots {
                aliquot_id aliquot_submitter_id analyte_type
                aliquot_run_metadata {
                    aliquot_run_metadata_id
                }
            }
        }
        diagnoses {
            diagnosis_id tissue_or_organ_of_origin age_at_diagnosis primary_diagnosis tumor_grade tumor_stage
            diagnosis_submitter_id classification_of_tumor days_to_last_follow_up days_to_last_known_disease_status
            days_to_recurrence last_known_disease_status morphology progression_or_recurrence
            site_of_resection_or_biopsy prior_malignancy ajcc_clinical_m ajcc_clinical_n ajcc_clinical_stage
            ajcc_clinical_t ajcc_pathologic_m ajcc_pathologic_n ajcc_pathologic_stage ajcc_pathologic_t
            ann_arbor_b_symptoms ann_arbor_clinical_stage ann_arbor_extranodal_involvement ann_arbor_pathologic_stage
            best_overall_response burkitt_lymphoma_clinical_variant circumferential_resection_margin
            colon_polyps_history days_to_best_overall_response days_to_diagnosis days_to_hiv_diagnosis
            days_to_new_event figo_stage hiv_positive hpv_positive_type hpv_status iss_stage laterality
            ldh_level_at_diagnosis ldh_normal_range_upper lymph_nodes_positive lymphatic_invasion_present
            method_of_diagnosis new_event_anatomic_site new_event_type overall_survival perineural_invasion_present
            prior_treatment progression_free_survival progression_free_survival_event residual_disease
            vascular_invasion_present year_of_diagnosis icd_10_code synchronous_malignancy
            tumor_largest_dimension_diameter
        }
    }
}""" % (submitter_id)

params = {
    "query": graphql_query
}

pdc_graphql_endpoint = "https://pdc.cancer.gov/graphql"

response = requests.get(pdc_graphql_endpoint, params = params)
result = json.loads(response.content)

cases = result['data']['case']
assert len(cases) == 1
case = cases[0]

# Write this to a file.
with open('pdc_subject_09CO022.json', 'w') as f:
    json.dump(case, f, indent=4, sort_keys=True)


case
# Out:
# {'case_id': '459e3b69-63d6-11e8-bcf1-0a2705229b82',
#  'case_submitter_id': '09CO022',
#  'project_submitter_id': 'CPTAC-2',
#  'days_to_lost_to_followup': 0,
#  'disease_type': 'Colon Adenocarcinoma',
#  'index_date': None,
#  'lost_to_followup': '',
#  'primary_site': 'Colon',
#  'externalReferences': [{'external_reference_id': 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d',
#    'reference_resource_shortname': 'GDC',
#    'reference_resource_name': 'Genomic Data Commns',
#    'reference_entity_location': 'https://portal.gdc.cancer.gov/cases/c5421e34-e5c7-4ba5-aed9-146a5575fd8d'}],
#  'demographics': [{'demographic_id': 'f6954ae9-7588-11e8-bcf1-0a2705229b82',
#    'ethnicity': 'Not Hispanic or Latino',
#    'gender': 'Female',
#    'demographic_submitter_id': '09CO022-DM',
#    'race': 'Black or African American',
#    'cause_of_death': None,
#    'days_to_birth': None,
#    'days_to_death': None,
#    'vital_status': 'Not Reported',
#    'year_of_birth': None,
#    'year_of_death': None}],
#  'samples': [{'sample_id': 'f4af3e4d-641b-11e8-bcf1-0a2705229b82',
#    'sample_submitter_id': '76498650-fdbf-4f5d-a19a-cce9a2',
#    'sample_type': 'Solid Tissue Normal',
#    'sample_type_id': '0',
#    'gdc_sample_id': '',
#    'gdc_project_id': '',
#    'biospecimen_anatomic_site': 'Not Reported',
#    'composition': 'Not Reported',
#    'current_weight': None,
#    'days_to_collection': None,
#    'days_to_sample_procurement': None,
#    'diagnosis_pathologically_confirmed': 'Not Reported',
#    'freezing_method': None,
#    'initial_weight': None,
#    'intermediate_dimension': None,
#    'is_ffpe': None,
#    'longest_dimension': None,
#    'method_of_sample_procurement': 'Not Reported',
#    'oct_embedded': None,
#    'pathology_report_uuid': None,
#    'preservation_method': 'Not Reported',
#    'shortest_dimension': None,
#    'time_between_clamping_and_freezing': None,
#    'time_between_excision_and_freezing': None,
#    'tissue_type': 'Not Reported',
#    'tumor_code': None,
#    'tumor_code_id': None,
#    'tumor_descriptor': 'Not Reported',
#    'aliquots': [{'aliquot_id': '208ebc64-6425-11e8-bcf1-0a2705229b82',
#      'aliquot_submitter_id': '76498650-fdbf-4f5d-a19a-cce9a2_D2',
#      'analyte_type': 'Protein',
#      'aliquot_run_metadata': [{'aliquot_run_metadata_id': '58a72e91-e26a-11e8-907f-0a2705229b82'},
#       {'aliquot_run_metadata_id': 'a2422b46-e26a-11e8-907f-0a2705229b82'}]}]},
#   {'sample_id': 'f6cce507-641b-11e8-bcf1-0a2705229b82',
#    'sample_submitter_id': 'f69deaeb-6b6f-4c61-8900-fd0f26',
#    'sample_type': 'Primary Tumor',
#    'sample_type_id': '1',
#    'gdc_sample_id': '4591a53d-5668-4a70-b44b-e08a3d59267e',
#    'gdc_project_id': '',
#    'biospecimen_anatomic_site': 'Not Reported',
#    'composition': 'Not Reported',
#    'current_weight': None,
#    'days_to_collection': None,
#    'days_to_sample_procurement': None,
#    'diagnosis_pathologically_confirmed': 'Not Reported',
#    'freezing_method': None,
#    'initial_weight': None,
#    'intermediate_dimension': None,
#    'is_ffpe': None,
#    'longest_dimension': None,
#    'method_of_sample_procurement': 'Not Reported',
#    'oct_embedded': None,
#    'pathology_report_uuid': None,
#    'preservation_method': 'Not Reported',
#    'shortest_dimension': None,
#    'time_between_clamping_and_freezing': None,
#    'time_between_excision_and_freezing': None,
#    'tissue_type': 'Not Reported',
#    'tumor_code': None,
#    'tumor_code_id': None,
#    'tumor_descriptor': 'Not Reported',
#    'aliquots': [{'aliquot_id': '08b2a2bf-6427-11e8-bcf1-0a2705229b82',
#      'aliquot_submitter_id': 'f69deaeb-6b6f-4c61-8900-fd0f26_D2',
#      'analyte_type': 'Protein',
#      'aliquot_run_metadata': [{'aliquot_run_metadata_id': '13dbe375-5735-11e8-b664-00a098d917f8'}]},
#     {'aliquot_id': '0a0ef804-6427-11e8-bcf1-0a2705229b82',
#      'aliquot_submitter_id': 'f69deaeb-6b6f-4c61-8900-fd0f26_D5',
#      'analyte_type': 'Protein',
#      'aliquot_run_metadata': []},
#     {'aliquot_id': '44f5b956-642a-11e8-bcf1-0a2705229b82',
#      'aliquot_submitter_id': 'f69deaeb-6b6f-4c61-8900-fd0f26_D3',
#      'analyte_type': 'Protein',
#      'aliquot_run_metadata': [{'aliquot_run_metadata_id': 'dfa93d3f-5737-11e8-b664-00a098d917f8'},
#       {'aliquot_run_metadata_id': 'f8d41677-5737-11e8-b664-00a098d917f8'}]}]}],
#  'diagnoses': [{'diagnosis_id': 'ff301535-70ca-11e8-bcf1-0a2705229b82',
#    'tissue_or_organ_of_origin': 'Colon, NOS',
#    'age_at_diagnosis': None,
#    'primary_diagnosis': 'Adenocarcinoma, NOS',
#    'tumor_grade': 'Not Reported',
#    'tumor_stage': 'Stage IIB',
#    'diagnosis_submitter_id': '09CO022-DX',
#    'classification_of_tumor': 'Not Reported',
#    'days_to_last_follow_up': None,
#    'days_to_last_known_disease_status': None,
#    'days_to_recurrence': None,
#    'last_known_disease_status': 'Not Reported',
#    'morphology': '8140/3',
#    'progression_or_recurrence': 'Not Reported',
#    'site_of_resection_or_biopsy': 'Not Reported',
#    'prior_malignancy': 'No',
#    'ajcc_clinical_m': 'Not Reported',
#    'ajcc_clinical_n': 'Not Reported',
#    'ajcc_clinical_stage': 'Not Reported',
#    'ajcc_clinical_t': 'Not Reported',
#    'ajcc_pathologic_m': 'Not Reported',
#    'ajcc_pathologic_n': 'Not Reported',
#    'ajcc_pathologic_stage': 'Stage IIB',
#    'ajcc_pathologic_t': 'Not Reported',
#    'ann_arbor_b_symptoms': 'Not Reported',
#    'ann_arbor_clinical_stage': 'Not Reported',
#    'ann_arbor_extranodal_involvement': 'Not Reported',
#    'ann_arbor_pathologic_stage': 'Not Reported',
#    'best_overall_response': None,
#    'burkitt_lymphoma_clinical_variant': 'Not Reported',
#    'circumferential_resection_margin': None,
#    'colon_polyps_history': None,
#    'days_to_best_overall_response': None,
#    'days_to_diagnosis': '',
#    'days_to_hiv_diagnosis': None,
#    'days_to_new_event': None,
#    'figo_stage': 'Not Reported',
#    'hiv_positive': None,
#    'hpv_positive_type': None,
#    'hpv_status': None,
#    'iss_stage': 'Not Reported',
#    'laterality': 'Not Reported',
#    'ldh_level_at_diagnosis': None,
#    'ldh_normal_range_upper': None,
#    'lymph_nodes_positive': None,
#    'lymphatic_invasion_present': 'Not Reported',
#    'method_of_diagnosis': 'Not Reported',
#    'new_event_anatomic_site': None,
#    'new_event_type': None,
#    'overall_survival': None,
#    'perineural_invasion_present': 'Not Reported',
#    'prior_treatment': 'Not Reported',
#    'progression_free_survival': None,
#    'progression_free_survival_event': None,
#    'residual_disease': 'Not Reported',
#    'vascular_invasion_present': 'Not Reported',
#    'year_of_diagnosis': '',
#    'icd_10_code': None,
#    'synchronous_malignancy': None,
#    'tumor_largest_dimension_diameter': None}]}

# %% [markdown]
# ### From CDA by Case ID
#
# Note that for cases extracted from GDC/PDC, we can look up the same record on CDA by using the case_id.

# %%
from cdapython import Q, columns

case_id = case['case_id']
query_by_case_id = Q(f'ResearchSubject.id = "{case_id}"')
results = query_by_case_id.run(limit=2) 
print(results)

cda_entry = results[0]

# Write this to a file.
with open(f'cda_case_{case_id}.json', 'w') as f:
    json.dump(cda_entry, f, indent=4, sort_keys=True)

cda_entry
# Out:
# Query: SELECT * FROM gdc-bq-sample.cda_mvp.v3, UNNEST(ResearchSubject) AS _ResearchSubject WHERE (_ResearchSubject.id = '459e3b69-63d6-11e8-bcf1-0a2705229b82')
# Offset: 0
# Limit: 2
# Count: 1
# More pages: No
# {'days_to_birth': None,
#  'race': 'black or african american',
#  'sex': 'female',
#  'ethnicity': 'not hispanic or latino',
#  'id': '459e3b69-63d6-11e8-bcf1-0a2705229b82',
#  'ResearchSubject': [{'Diagnosis': [{'morphology': '8140/3',
#      'tumor_stage': 'Stage IIB',
#      'tumor_grade': 'Not Reported',
#      'Treatment': [],
#      'id': '7b8d36ba-ab84-48ad-ac2c-11ac40d3d0eb',
#      'primary_diagnosis': 'Adenocarcinoma, NOS',
#      'age_at_diagnosis': None}],
#    'Specimen': [{'File': [{'label': 'fbc0c313-d356-4ad9-8257-57e90fb7f26b.wxs.Pindel.somatic_annotation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:00a9219e-109c-4013-89c8-3d01b39cd9bf',
#        'identifier': [{'system': 'GDC',
#          'value': '00a9219e-109c-4013-89c8-3d01b39cd9bf'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 248056,
#        'type': None,
#        'file_format': None,
#        'checksum': 'e09e988c4969cf68fac8168fa622df9f',
#        'id': '00a9219e-109c-4013-89c8-3d01b39cd9bf',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.mutect2.raw_somatic_mutation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:18b4dd00-f22a-4904-92f8-11d03fc21e44',
#        'identifier': [{'system': 'GDC',
#          'value': '18b4dd00-f22a-4904-92f8-11d03fc21e44'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 1611219,
#        'type': None,
#        'file_format': None,
#        'checksum': '5eab6ca0fbbb67a3204e55266161dc55',
#        'id': '18b4dd00-f22a-4904-92f8-11d03fc21e44',
#        'data_type': 'Raw Simple Somatic Mutation'},
#       {'label': '8c6af725-abc2-48af-a604-580e4b51fa30.wxs.MuTect2.somatic_annotation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:1fb29f83-87a5-416d-8af1-d94d749aeda9',
#        'identifier': [{'system': 'GDC',
#          'value': '1fb29f83-87a5-416d-8af1-d94d749aeda9'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 7547974,
#        'type': None,
#        'file_format': None,
#        'checksum': '2ab8ea64673f22be2fc3ae40ce3356eb',
#        'id': '1fb29f83-87a5-416d-8af1-d94d749aeda9',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': 'a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.star_splice_junctions.tsv.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:251c0ac2-9ba0-43ca-acc1-01e9638b1250',
#        'identifier': [{'system': 'GDC',
#          'value': '251c0ac2-9ba0-43ca-acc1-01e9638b1250'}],
#        'data_category': 'Transcriptome Profiling',
#        'byte_size': 2472314,
#        'type': None,
#        'file_format': None,
#        'checksum': 'f81e25701c17eab29bdee4223c82cc56',
#        'id': '251c0ac2-9ba0-43ca-acc1-01e9638b1250',
#        'data_type': 'Splice Junction Quantification'},
#       {'label': 'a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.genomic.gdc_realn.bam',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:38a714a2-ea50-487f-b184-fc3e2fbb8635',
#        'identifier': [{'system': 'GDC',
#          'value': '38a714a2-ea50-487f-b184-fc3e2fbb8635'}],
#        'data_category': 'Sequencing Reads',
#        'byte_size': 4414014860,
#        'type': None,
#        'file_format': None,
#        'checksum': '46f5800fb243249938ddf09fc95ed416',
#        'id': '38a714a2-ea50-487f-b184-fc3e2fbb8635',
#        'data_type': 'Aligned Reads'},
#       {'label': '6cca2f97-024b-4d5f-a753-bf148725ec8c.htseq_counts.txt.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:502ada14-06bf-48ae-9f57-66646a9c8fa0',
#        'identifier': [{'system': 'GDC',
#          'value': '502ada14-06bf-48ae-9f57-66646a9c8fa0'}],
#        'data_category': 'Transcriptome Profiling',
#        'byte_size': 238654,
#        'type': None,
#        'file_format': None,
#        'checksum': 'a15b1b8c641407a9c8fa3756fc86d7c6',
#        'id': '502ada14-06bf-48ae-9f57-66646a9c8fa0',
#        'data_type': 'Gene Expression Quantification'},
#       {'label': 'dfecdd3f-a8eb-4e69-8713-85170b11fe2a.mirnaseq.mirnas.quantification.txt',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:527f7662-b314-44ba-998b-99d1dfc7ae33',
#        'identifier': [{'system': 'GDC',
#          'value': '527f7662-b314-44ba-998b-99d1dfc7ae33'}],
#        'data_category': 'Transcriptome Profiling',
#        'byte_size': 49839,
#        'type': None,
#        'file_format': None,
#        'checksum': '3540412c79caa600aef56f928fed04aa',
#        'id': '527f7662-b314-44ba-998b-99d1dfc7ae33',
#        'data_type': 'miRNA Expression Quantification'},
#       {'label': '0d8adcbf-13f0-48c3-83df-3fa205b79ae8_mirnaseq_gdc_realn.bam',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:5dd36db9-d94c-412a-8cc6-7cc2f43b890c',
#        'identifier': [{'system': 'GDC',
#          'value': '5dd36db9-d94c-412a-8cc6-7cc2f43b890c'}],
#        'data_category': 'Sequencing Reads',
#        'byte_size': 265126753,
#        'type': None,
#        'file_format': None,
#        'checksum': '14982035c8909b3747d03a23924c5af0',
#        'id': '5dd36db9-d94c-412a-8cc6-7cc2f43b890c',
#        'data_type': 'Aligned Reads'},
#       {'label': 'a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.star_gene_counts.tsv.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:5e0db211-7fa4-477d-b642-ec5082d99e88',
#        'identifier': [{'system': 'GDC',
#          'value': '5e0db211-7fa4-477d-b642-ec5082d99e88'}],
#        'data_category': 'Transcriptome Profiling',
#        'byte_size': 369648,
#        'type': None,
#        'file_format': None,
#        'checksum': '38e816e53699daac1474a27681ee315c',
#        'id': '5e0db211-7fa4-477d-b642-ec5082d99e88',
#        'data_type': 'Gene Expression Quantification'},
#       {'label': '17ff92b1-3226-430a-8599-bacdb8dd65b0.wxs.Pindel.aliquot.maf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:654ba668-6f5f-497b-acd4-c41bd8e18e9e',
#        'identifier': [{'system': 'GDC',
#          'value': '654ba668-6f5f-497b-acd4-c41bd8e18e9e'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 163494,
#        'type': None,
#        'file_format': None,
#        'checksum': 'fabcd676c20684a8df20be63e49756a4',
#        'id': '654ba668-6f5f-497b-acd4-c41bd8e18e9e',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': '2906082e-a906-4e04-b79b-f69541bb82bb.wxs.pindel.raw_somatic_mutation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:65d6fa7c-d474-4466-9b7d-a21b245237f7',
#        'identifier': [{'system': 'GDC',
#          'value': '65d6fa7c-d474-4466-9b7d-a21b245237f7'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 43887,
#        'type': None,
#        'file_format': None,
#        'checksum': 'cc174a5c968bd1dfc464c22fb1244f2b',
#        'id': '65d6fa7c-d474-4466-9b7d-a21b245237f7',
#        'data_type': 'Raw Simple Somatic Mutation'},
#       {'label': '70331103-de30-4d20-9dee-3d9bec0675d0.wxs.SomaticSniper.somatic_annotation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:6bb0f620-8925-4cd4-89c2-f0477d334ee9',
#        'identifier': [{'system': 'GDC',
#          'value': '6bb0f620-8925-4cd4-89c2-f0477d334ee9'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 5005951,
#        'type': None,
#        'file_format': None,
#        'checksum': 'f1582d896290ad6c93f4ee97195fb5a9',
#        'id': '6bb0f620-8925-4cd4-89c2-f0477d334ee9',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': 'dfecdd3f-a8eb-4e69-8713-85170b11fe2a.mirnaseq.isoforms.quantification.txt',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:6e56cf8c-acb9-4a34-a3d8-ec0060a19193',
#        'identifier': [{'system': 'GDC',
#          'value': '6e56cf8c-acb9-4a34-a3d8-ec0060a19193'}],
#        'data_category': 'Transcriptome Profiling',
#        'byte_size': 425670,
#        'type': None,
#        'file_format': None,
#        'checksum': '3d57646194512126325c59177b8e537b',
#        'id': '6e56cf8c-acb9-4a34-a3d8-ec0060a19193',
#        'data_type': 'Isoform Expression Quantification'},
#       {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.varscan2.raw_somatic_mutation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:7247faf2-afb0-4a39-9a55-9d471de5c550',
#        'identifier': [{'system': 'GDC',
#          'value': '7247faf2-afb0-4a39-9a55-9d471de5c550'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 115646,
#        'type': None,
#        'file_format': None,
#        'checksum': '0dd012d2a55bedca6921fad581fbbd27',
#        'id': '7247faf2-afb0-4a39-9a55-9d471de5c550',
#        'data_type': 'Raw Simple Somatic Mutation'},
#       {'label': '9250d96e-1cdc-4d68-8a56-f7b186a6fab5_wxs_gdc_realn.bam',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:73e507f1-8e2f-400d-acd6-ee9a9ad338e9',
#        'identifier': [{'system': 'GDC',
#          'value': '73e507f1-8e2f-400d-acd6-ee9a9ad338e9'}],
#        'data_category': 'Sequencing Reads',
#        'byte_size': 59654562246,
#        'type': None,
#        'file_format': None,
#        'checksum': '6e2a2dbfef2574f49c261d1e567316b3',
#        'id': '73e507f1-8e2f-400d-acd6-ee9a9ad338e9',
#        'data_type': 'Aligned Reads'},
#       {'label': '96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_raw.maf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:77a179fc-a3bc-462e-8209-979b9a031e20',
#        'identifier': [{'system': 'GDC',
#          'value': '77a179fc-a3bc-462e-8209-979b9a031e20'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 342713,
#        'type': None,
#        'file_format': None,
#        'checksum': '35d6d356b65c552962845a5f963db28a',
#        'id': '77a179fc-a3bc-462e-8209-979b9a031e20',
#        'data_type': 'Aggregated Somatic Mutation'},
#       {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.muse.raw_somatic_mutation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:849452d3-3a1c-4f3d-a7c2-3e0b7580efec',
#        'identifier': [{'system': 'GDC',
#          'value': '849452d3-3a1c-4f3d-a7c2-3e0b7580efec'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 50325,
#        'type': None,
#        'file_format': None,
#        'checksum': '5dab4cb237c6bdf9f26938510d9f6442',
#        'id': '849452d3-3a1c-4f3d-a7c2-3e0b7580efec',
#        'data_type': 'Raw Simple Somatic Mutation'},
#       {'label': '6cca2f97-024b-4d5f-a753-bf148725ec8c.FPKM-UQ.txt.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:8bea647e-66d8-42af-ab06-7bd0629179c7',
#        'identifier': [{'system': 'GDC',
#          'value': '8bea647e-66d8-42af-ab06-7bd0629179c7'}],
#        'data_category': 'Transcriptome Profiling',
#        'byte_size': 371625,
#        'type': None,
#        'file_format': None,
#        'checksum': '7a0a86367f6f1129851e2d9152813c8c',
#        'id': '8bea647e-66d8-42af-ab06-7bd0629179c7',
#        'data_type': 'Gene Expression Quantification'},
#       {'label': '96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_masked.maf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb',
#        'identifier': [{'system': 'GDC',
#          'value': '8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 53313,
#        'type': None,
#        'file_format': None,
#        'checksum': 'dc22add6654662c05c787407c20b4578',
#        'id': '8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb',
#        'data_type': 'Masked Somatic Mutation'},
#       {'label': '6cca2f97-024b-4d5f-a753-bf148725ec8c.FPKM.txt.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:8f4884a5-9726-4abc-8e3b-db4f1b603dfa',
#        'identifier': [{'system': 'GDC',
#          'value': '8f4884a5-9726-4abc-8e3b-db4f1b603dfa'}],
#        'data_category': 'Transcriptome Profiling',
#        'byte_size': 295185,
#        'type': None,
#        'file_format': None,
#        'checksum': 'a641a766218e0b4be0ffe05aa3229ac2',
#        'id': '8f4884a5-9726-4abc-8e3b-db4f1b603dfa',
#        'data_type': 'Gene Expression Quantification'},
#       {'label': 'a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.transcriptome.gdc_realn.bam',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:91d7d870-2331-472f-bc74-19c1d9f4d6c7',
#        'identifier': [{'system': 'GDC',
#          'value': '91d7d870-2331-472f-bc74-19c1d9f4d6c7'}],
#        'data_category': 'Sequencing Reads',
#        'byte_size': 7602867805,
#        'type': None,
#        'file_format': None,
#        'checksum': 'ecce292cfbab62abf3e911a98579e5f3',
#        'id': '91d7d870-2331-472f-bc74-19c1d9f4d6c7',
#        'data_type': 'Aligned Reads'},
#       {'label': 'ea51af0a-e767-4db1-8a8d-1cf19df17c4c.wxs.MuTect2.aliquot.maf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:9c18aa38-5edd-40cf-8389-a03aea35a150',
#        'identifier': [{'system': 'GDC',
#          'value': '9c18aa38-5edd-40cf-8389-a03aea35a150'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 6167311,
#        'type': None,
#        'file_format': None,
#        'checksum': '765119382d413e7051cedb1ad122d436',
#        'id': '9c18aa38-5edd-40cf-8389-a03aea35a150',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': 'abdaac20-1a31-4785-ace5-7ef4cc07bc8e.wxs.VarScan2.somatic_annotation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1',
#        'identifier': [{'system': 'GDC',
#          'value': '9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 767641,
#        'type': None,
#        'file_format': None,
#        'checksum': '641b13968bf9401223d29e9f3350804c',
#        'id': '9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': 'a78c9b27-d695-4a91-90f8-cd08c29602b2.wxs.MuSE.aliquot.maf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:9f27b7a7-7e18-42c8-a5bd-62461a567955',
#        'identifier': [{'system': 'GDC',
#          'value': '9f27b7a7-7e18-42c8-a5bd-62461a567955'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 305442,
#        'type': None,
#        'file_format': None,
#        'checksum': 'ef18bf2c57161d8a48256f6f9fd3c441',
#        'id': '9f27b7a7-7e18-42c8-a5bd-62461a567955',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': 'a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.chimeric.gdc_realn.bam',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:a97b91db-1804-4f0a-8cdd-10e4cb30d458',
#        'identifier': [{'system': 'GDC',
#          'value': 'a97b91db-1804-4f0a-8cdd-10e4cb30d458'}],
#        'data_category': 'Sequencing Reads',
#        'byte_size': 20460524,
#        'type': None,
#        'file_format': None,
#        'checksum': '31b766f0f934513062f5213dc9740b94',
#        'id': 'a97b91db-1804-4f0a-8cdd-10e4cb30d458',
#        'data_type': 'Aligned Reads'},
#       {'label': '0e8a628a-d5a4-4ae2-bb81-73a1a9c1d4cd.wxs.MuSE.somatic_annotation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:b8ecf468-dd33-4f43-8093-544d92d676f6',
#        'identifier': [{'system': 'GDC',
#          'value': 'b8ecf468-dd33-4f43-8093-544d92d676f6'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 438051,
#        'type': None,
#        'file_format': None,
#        'checksum': '52a6cc7af0c366fd93240a49998289ff',
#        'id': 'b8ecf468-dd33-4f43-8093-544d92d676f6',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.somaticsniper.raw_somatic_mutation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:c411fd62-0198-4c47-ada8-0cffafb5a262',
#        'identifier': [{'system': 'GDC',
#          'value': 'c411fd62-0198-4c47-ada8-0cffafb5a262'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 5936384,
#        'type': None,
#        'file_format': None,
#        'checksum': '6d07c80d2683a58c9e656ee165570f35',
#        'id': 'c411fd62-0198-4c47-ada8-0cffafb5a262',
#        'data_type': 'Raw Simple Somatic Mutation'},
#       {'label': 'b85b56a6-89e2-424c-993d-764ae20bf072.wxs.SomaticSniper.aliquot.maf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:d7b978a6-a601-4025-8408-ee1fdb391689',
#        'identifier': [{'system': 'GDC',
#          'value': 'd7b978a6-a601-4025-8408-ee1fdb391689'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 4001912,
#        'type': None,
#        'file_format': None,
#        'checksum': 'ec3a6c924c6f10268a0b3f5de77c2e4d',
#        'id': 'd7b978a6-a601-4025-8408-ee1fdb391689',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': 'd4496cf9-bc61-400a-aa97-72331ee4fd2b.wxs.VarScan2.aliquot.maf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:dd6923a5-8fcc-4bc9-8912-14b20f387214',
#        'identifier': [{'system': 'GDC',
#          'value': 'dd6923a5-8fcc-4bc9-8912-14b20f387214'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 567540,
#        'type': None,
#        'file_format': None,
#        'checksum': 'da2b85a5ffd55a7884557784684ab45d',
#        'id': 'dd6923a5-8fcc-4bc9-8912-14b20f387214',
#        'data_type': 'Annotated Somatic Mutation'}],
#      'derived_from_specimen': 'Initial sample',
#      'associated_project': 'CPTAC-2',
#      'age_at_collection': None,
#      'anatomical_site': None,
#      'source_material_type': 'Primary Tumor',
#      'derived_from_subject': '09CO022',
#      'specimen_type': 'sample',
#      'id': '4591a53d-5668-4a70-b44b-e08a3d59267e',
#      'primary_disease_type': 'Adenomas and Adenocarcinomas',
#      'identifier': [{'system': 'GDC',
#        'value': '4591a53d-5668-4a70-b44b-e08a3d59267e'}]},
#     {'File': [],
#      'derived_from_specimen': '4591a53d-5668-4a70-b44b-e08a3d59267e',
#      'associated_project': 'CPTAC-2',
#      'age_at_collection': None,
#      'anatomical_site': None,
#      'source_material_type': 'Primary Tumor',
#      'derived_from_subject': '09CO022',
#      'specimen_type': 'portion',
#      'id': 'c53c4d60-2ddb-5da8-932e-00a86fa2347f',
#      'primary_disease_type': 'Adenomas and Adenocarcinomas',
#      'identifier': [{'system': 'GDC',
#        'value': 'c53c4d60-2ddb-5da8-932e-00a86fa2347f'}]},
#     {'File': [],
#      'derived_from_specimen': 'c53c4d60-2ddb-5da8-932e-00a86fa2347f',
#      'associated_project': 'CPTAC-2',
#      'age_at_collection': None,
#      'anatomical_site': None,
#      'source_material_type': 'Primary Tumor',
#      'derived_from_subject': '09CO022',
#      'specimen_type': 'analyte',
#      'id': '31075cfa-7aef-59f1-bf54-a1cddb5ee0fd',
#      'primary_disease_type': 'Adenomas and Adenocarcinomas',
#      'identifier': [{'system': 'GDC',
#        'value': '31075cfa-7aef-59f1-bf54-a1cddb5ee0fd'}]},
#     {'File': [],
#      'derived_from_specimen': '31075cfa-7aef-59f1-bf54-a1cddb5ee0fd',
#      'associated_project': 'CPTAC-2',
#      'age_at_collection': None,
#      'anatomical_site': None,
#      'source_material_type': 'Primary Tumor',
#      'derived_from_subject': '09CO022',
#      'specimen_type': 'aliquot',
#      'id': '0d8adcbf-13f0-48c3-83df-3fa205b79ae8',
#      'primary_disease_type': 'Adenomas and Adenocarcinomas',
#      'identifier': [{'system': 'GDC',
#        'value': '0d8adcbf-13f0-48c3-83df-3fa205b79ae8'}]},
#     {'File': [],
#      'derived_from_specimen': '4591a53d-5668-4a70-b44b-e08a3d59267e',
#      'associated_project': 'CPTAC-2',
#      'age_at_collection': None,
#      'anatomical_site': None,
#      'source_material_type': 'Primary Tumor',
#      'derived_from_subject': '09CO022',
#      'specimen_type': 'portion',
#      'id': 'd085ebd9-7605-54a0-abb9-10867f5fa1b1',
#      'primary_disease_type': 'Adenomas and Adenocarcinomas',
#      'identifier': [{'system': 'GDC',
#        'value': 'd085ebd9-7605-54a0-abb9-10867f5fa1b1'}]},
#     {'File': [],
#      'derived_from_specimen': 'd085ebd9-7605-54a0-abb9-10867f5fa1b1',
#      'associated_project': 'CPTAC-2',
#      'age_at_collection': None,
#      'anatomical_site': None,
#      'source_material_type': 'Primary Tumor',
#      'derived_from_subject': '09CO022',
#      'specimen_type': 'analyte',
#      'id': 'a31724b6-e550-552b-bd61-41341c534e28',
#      'primary_disease_type': 'Adenomas and Adenocarcinomas',
#      'identifier': [{'system': 'GDC',
#        'value': 'a31724b6-e550-552b-bd61-41341c534e28'}]},
#     {'File': [],
#      'derived_from_specimen': 'a31724b6-e550-552b-bd61-41341c534e28',
#      'associated_project': 'CPTAC-2',
#      'age_at_collection': None,
#      'anatomical_site': None,
#      'source_material_type': 'Primary Tumor',
#      'derived_from_subject': '09CO022',
#      'specimen_type': 'aliquot',
#      'id': '9250d96e-1cdc-4d68-8a56-f7b186a6fab5',
#      'primary_disease_type': 'Adenomas and Adenocarcinomas',
#      'identifier': [{'system': 'GDC',
#        'value': '9250d96e-1cdc-4d68-8a56-f7b186a6fab5'}]},
#     {'File': [{'label': 'fbc0c313-d356-4ad9-8257-57e90fb7f26b.wxs.Pindel.somatic_annotation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:00a9219e-109c-4013-89c8-3d01b39cd9bf',
#        'identifier': [{'system': 'GDC',
#          'value': '00a9219e-109c-4013-89c8-3d01b39cd9bf'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 248056,
#        'type': None,
#        'file_format': None,
#        'checksum': 'e09e988c4969cf68fac8168fa622df9f',
#        'id': '00a9219e-109c-4013-89c8-3d01b39cd9bf',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.mutect2.raw_somatic_mutation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:18b4dd00-f22a-4904-92f8-11d03fc21e44',
#        'identifier': [{'system': 'GDC',
#          'value': '18b4dd00-f22a-4904-92f8-11d03fc21e44'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 1611219,
#        'type': None,
#        'file_format': None,
#        'checksum': '5eab6ca0fbbb67a3204e55266161dc55',
#        'id': '18b4dd00-f22a-4904-92f8-11d03fc21e44',
#        'data_type': 'Raw Simple Somatic Mutation'},
#       {'label': '8c6af725-abc2-48af-a604-580e4b51fa30.wxs.MuTect2.somatic_annotation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:1fb29f83-87a5-416d-8af1-d94d749aeda9',
#        'identifier': [{'system': 'GDC',
#          'value': '1fb29f83-87a5-416d-8af1-d94d749aeda9'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 7547974,
#        'type': None,
#        'file_format': None,
#        'checksum': '2ab8ea64673f22be2fc3ae40ce3356eb',
#        'id': '1fb29f83-87a5-416d-8af1-d94d749aeda9',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': '17ff92b1-3226-430a-8599-bacdb8dd65b0.wxs.Pindel.aliquot.maf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:654ba668-6f5f-497b-acd4-c41bd8e18e9e',
#        'identifier': [{'system': 'GDC',
#          'value': '654ba668-6f5f-497b-acd4-c41bd8e18e9e'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 163494,
#        'type': None,
#        'file_format': None,
#        'checksum': 'fabcd676c20684a8df20be63e49756a4',
#        'id': '654ba668-6f5f-497b-acd4-c41bd8e18e9e',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': '2906082e-a906-4e04-b79b-f69541bb82bb.wxs.pindel.raw_somatic_mutation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:65d6fa7c-d474-4466-9b7d-a21b245237f7',
#        'identifier': [{'system': 'GDC',
#          'value': '65d6fa7c-d474-4466-9b7d-a21b245237f7'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 43887,
#        'type': None,
#        'file_format': None,
#        'checksum': 'cc174a5c968bd1dfc464c22fb1244f2b',
#        'id': '65d6fa7c-d474-4466-9b7d-a21b245237f7',
#        'data_type': 'Raw Simple Somatic Mutation'},
#       {'label': '70331103-de30-4d20-9dee-3d9bec0675d0.wxs.SomaticSniper.somatic_annotation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:6bb0f620-8925-4cd4-89c2-f0477d334ee9',
#        'identifier': [{'system': 'GDC',
#          'value': '6bb0f620-8925-4cd4-89c2-f0477d334ee9'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 5005951,
#        'type': None,
#        'file_format': None,
#        'checksum': 'f1582d896290ad6c93f4ee97195fb5a9',
#        'id': '6bb0f620-8925-4cd4-89c2-f0477d334ee9',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.varscan2.raw_somatic_mutation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:7247faf2-afb0-4a39-9a55-9d471de5c550',
#        'identifier': [{'system': 'GDC',
#          'value': '7247faf2-afb0-4a39-9a55-9d471de5c550'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 115646,
#        'type': None,
#        'file_format': None,
#        'checksum': '0dd012d2a55bedca6921fad581fbbd27',
#        'id': '7247faf2-afb0-4a39-9a55-9d471de5c550',
#        'data_type': 'Raw Simple Somatic Mutation'},
#       {'label': '96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_raw.maf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:77a179fc-a3bc-462e-8209-979b9a031e20',
#        'identifier': [{'system': 'GDC',
#          'value': '77a179fc-a3bc-462e-8209-979b9a031e20'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 342713,
#        'type': None,
#        'file_format': None,
#        'checksum': '35d6d356b65c552962845a5f963db28a',
#        'id': '77a179fc-a3bc-462e-8209-979b9a031e20',
#        'data_type': 'Aggregated Somatic Mutation'},
#       {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.muse.raw_somatic_mutation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:849452d3-3a1c-4f3d-a7c2-3e0b7580efec',
#        'identifier': [{'system': 'GDC',
#          'value': '849452d3-3a1c-4f3d-a7c2-3e0b7580efec'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 50325,
#        'type': None,
#        'file_format': None,
#        'checksum': '5dab4cb237c6bdf9f26938510d9f6442',
#        'id': '849452d3-3a1c-4f3d-a7c2-3e0b7580efec',
#        'data_type': 'Raw Simple Somatic Mutation'},
#       {'label': '96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_masked.maf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb',
#        'identifier': [{'system': 'GDC',
#          'value': '8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 53313,
#        'type': None,
#        'file_format': None,
#        'checksum': 'dc22add6654662c05c787407c20b4578',
#        'id': '8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb',
#        'data_type': 'Masked Somatic Mutation'},
#       {'label': 'ea51af0a-e767-4db1-8a8d-1cf19df17c4c.wxs.MuTect2.aliquot.maf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:9c18aa38-5edd-40cf-8389-a03aea35a150',
#        'identifier': [{'system': 'GDC',
#          'value': '9c18aa38-5edd-40cf-8389-a03aea35a150'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 6167311,
#        'type': None,
#        'file_format': None,
#        'checksum': '765119382d413e7051cedb1ad122d436',
#        'id': '9c18aa38-5edd-40cf-8389-a03aea35a150',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': 'abdaac20-1a31-4785-ace5-7ef4cc07bc8e.wxs.VarScan2.somatic_annotation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1',
#        'identifier': [{'system': 'GDC',
#          'value': '9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 767641,
#        'type': None,
#        'file_format': None,
#        'checksum': '641b13968bf9401223d29e9f3350804c',
#        'id': '9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': 'a78c9b27-d695-4a91-90f8-cd08c29602b2.wxs.MuSE.aliquot.maf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:9f27b7a7-7e18-42c8-a5bd-62461a567955',
#        'identifier': [{'system': 'GDC',
#          'value': '9f27b7a7-7e18-42c8-a5bd-62461a567955'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 305442,
#        'type': None,
#        'file_format': None,
#        'checksum': 'ef18bf2c57161d8a48256f6f9fd3c441',
#        'id': '9f27b7a7-7e18-42c8-a5bd-62461a567955',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': 'ce309009-9257-4c13-9241-83fc629c35a0_wxs_gdc_realn.bam',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:a35f18eb-3475-4433-a72f-4b8aa2cb6106',
#        'identifier': [{'system': 'GDC',
#          'value': 'a35f18eb-3475-4433-a72f-4b8aa2cb6106'}],
#        'data_category': 'Sequencing Reads',
#        'byte_size': 69157605164,
#        'type': None,
#        'file_format': None,
#        'checksum': '21f2140d9d3ef197422820a7e0bb8561',
#        'id': 'a35f18eb-3475-4433-a72f-4b8aa2cb6106',
#        'data_type': 'Aligned Reads'},
#       {'label': '0e8a628a-d5a4-4ae2-bb81-73a1a9c1d4cd.wxs.MuSE.somatic_annotation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:b8ecf468-dd33-4f43-8093-544d92d676f6',
#        'identifier': [{'system': 'GDC',
#          'value': 'b8ecf468-dd33-4f43-8093-544d92d676f6'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 438051,
#        'type': None,
#        'file_format': None,
#        'checksum': '52a6cc7af0c366fd93240a49998289ff',
#        'id': 'b8ecf468-dd33-4f43-8093-544d92d676f6',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.somaticsniper.raw_somatic_mutation.vcf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:c411fd62-0198-4c47-ada8-0cffafb5a262',
#        'identifier': [{'system': 'GDC',
#          'value': 'c411fd62-0198-4c47-ada8-0cffafb5a262'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 5936384,
#        'type': None,
#        'file_format': None,
#        'checksum': '6d07c80d2683a58c9e656ee165570f35',
#        'id': 'c411fd62-0198-4c47-ada8-0cffafb5a262',
#        'data_type': 'Raw Simple Somatic Mutation'},
#       {'label': 'b85b56a6-89e2-424c-993d-764ae20bf072.wxs.SomaticSniper.aliquot.maf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:d7b978a6-a601-4025-8408-ee1fdb391689',
#        'identifier': [{'system': 'GDC',
#          'value': 'd7b978a6-a601-4025-8408-ee1fdb391689'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 4001912,
#        'type': None,
#        'file_format': None,
#        'checksum': 'ec3a6c924c6f10268a0b3f5de77c2e4d',
#        'id': 'd7b978a6-a601-4025-8408-ee1fdb391689',
#        'data_type': 'Annotated Somatic Mutation'},
#       {'label': 'd4496cf9-bc61-400a-aa97-72331ee4fd2b.wxs.VarScan2.aliquot.maf.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:dd6923a5-8fcc-4bc9-8912-14b20f387214',
#        'identifier': [{'system': 'GDC',
#          'value': 'dd6923a5-8fcc-4bc9-8912-14b20f387214'}],
#        'data_category': 'Simple Nucleotide Variation',
#        'byte_size': 567540,
#        'type': None,
#        'file_format': None,
#        'checksum': 'da2b85a5ffd55a7884557784684ab45d',
#        'id': 'dd6923a5-8fcc-4bc9-8912-14b20f387214',
#        'data_type': 'Annotated Somatic Mutation'}],
#      'derived_from_specimen': 'Initial sample',
#      'associated_project': 'CPTAC-2',
#      'age_at_collection': None,
#      'anatomical_site': None,
#      'source_material_type': 'Blood Derived Normal',
#      'derived_from_subject': '09CO022',
#      'specimen_type': 'sample',
#      'id': 'b12c257d-7409-4858-9384-c430929a075a',
#      'primary_disease_type': 'Adenomas and Adenocarcinomas',
#      'identifier': [{'system': 'GDC',
#        'value': 'b12c257d-7409-4858-9384-c430929a075a'}]},
#     {'File': [],
#      'derived_from_specimen': 'b12c257d-7409-4858-9384-c430929a075a',
#      'associated_project': 'CPTAC-2',
#      'age_at_collection': None,
#      'anatomical_site': None,
#      'source_material_type': 'Blood Derived Normal',
#      'derived_from_subject': '09CO022',
#      'specimen_type': 'portion',
#      'id': '702d7ba0-9558-5b2d-af4d-cd797485b8c1',
#      'primary_disease_type': 'Adenomas and Adenocarcinomas',
#      'identifier': [{'system': 'GDC',
#        'value': '702d7ba0-9558-5b2d-af4d-cd797485b8c1'}]},
#     {'File': [],
#      'derived_from_specimen': '702d7ba0-9558-5b2d-af4d-cd797485b8c1',
#      'associated_project': 'CPTAC-2',
#      'age_at_collection': None,
#      'anatomical_site': None,
#      'source_material_type': 'Blood Derived Normal',
#      'derived_from_subject': '09CO022',
#      'specimen_type': 'analyte',
#      'id': 'f0003f0a-07ea-548e-b1f7-7e6d1b27d47a',
#      'primary_disease_type': 'Adenomas and Adenocarcinomas',
#      'identifier': [{'system': 'GDC',
#        'value': 'f0003f0a-07ea-548e-b1f7-7e6d1b27d47a'}]},
#     {'File': [],
#      'derived_from_specimen': 'f0003f0a-07ea-548e-b1f7-7e6d1b27d47a',
#      'associated_project': 'CPTAC-2',
#      'age_at_collection': None,
#      'anatomical_site': None,
#      'source_material_type': 'Blood Derived Normal',
#      'derived_from_subject': '09CO022',
#      'specimen_type': 'aliquot',
#      'id': 'ce309009-9257-4c13-9241-83fc629c35a0',
#      'primary_disease_type': 'Adenomas and Adenocarcinomas',
#      'identifier': [{'system': 'GDC',
#        'value': 'ce309009-9257-4c13-9241-83fc629c35a0'}]}],
#    'associated_project': 'CPTAC-2',
#    'id': 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d',
#    'primary_disease_type': 'Adenomas and Adenocarcinomas',
#    'identifier': [{'system': 'GDC',
#      'value': 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d'}],
#    'primary_disease_site': 'Colon'},
#   {'Diagnosis': [{'morphology': '8140/3',
#      'tumor_stage': 'Stage IIB',
#      'tumor_grade': 'Not Reported',
#      'Treatment': [],
#      'id': 'ff301535-70ca-11e8-bcf1-0a2705229b82',
#      'primary_diagnosis': 'Adenocarcinoma, NOS',
#      'age_at_diagnosis': None}],
#    'Specimen': [{'File': [{'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f03.raw.cap.psm',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:0235942c-7bd3-46c1-8a3d-87e42a0b1e86',
#        'identifier': [{'system': 'PDC',
#          'value': '0235942c-7bd3-46c1-8a3d-87e42a0b1e86'}],
#        'data_category': 'Peptide Spectral Matches',
#        'byte_size': 5195961,
#        'type': None,
#        'file_format': 'tsv',
#        'checksum': 'c1e585b85d70314ddfb9fe930faf6a0f',
#        'id': '0235942c-7bd3-46c1-8a3d-87e42a0b1e86',
#        'data_type': 'Text'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.mzML.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:0a63771a-14b2-4d6b-9c08-c7177c372789',
#        'identifier': [{'system': 'PDC',
#          'value': '0a63771a-14b2-4d6b-9c08-c7177c372789'}],
#        'data_category': 'Processed Mass Spectra',
#        'byte_size': 213302411,
#        'type': None,
#        'file_format': 'mzML',
#        'checksum': '8e16ac2e87bffdea86d75e03a8cf0ffa',
#        'id': '0a63771a-14b2-4d6b-9c08-c7177c372789',
#        'data_type': 'Open Standard'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.mzid.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:0daea74c-6886-415b-9395-cd4e0857acb4',
#        'identifier': [{'system': 'PDC',
#          'value': '0daea74c-6886-415b-9395-cd4e0857acb4'}],
#        'data_category': 'Peptide Spectral Matches',
#        'byte_size': 7044458,
#        'type': None,
#        'file_format': 'mzIdentML',
#        'checksum': 'fc0008314a37ba989ed29b1c7f9d67e1',
#        'id': '0daea74c-6886-415b-9395-cd4e0857acb4',
#        'data_type': 'Open Standard'},
#       {'label': '13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.mzid.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:0d846fdf-169e-4081-910d-a792fab3df43',
#        'identifier': [{'system': 'PDC',
#          'value': '0d846fdf-169e-4081-910d-a792fab3df43'}],
#        'data_category': 'Peptide Spectral Matches',
#        'byte_size': 4247403,
#        'type': None,
#        'file_format': 'mzIdentML',
#        'checksum': '5f8d183651df64850a85a64586aa2d9b',
#        'id': '0d846fdf-169e-4081-910d-a792fab3df43',
#        'data_type': 'Open Standard'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f04.mzid.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:1279b00d-cb50-4021-a595-08e7c3dd35c0',
#        'identifier': [{'system': 'PDC',
#          'value': '1279b00d-cb50-4021-a595-08e7c3dd35c0'}],
#        'data_category': 'Peptide Spectral Matches',
#        'byte_size': 7311308,
#        'type': None,
#        'file_format': 'mzIdentML',
#        'checksum': '48c15a24e109b3f783b8a23766f25a94',
#        'id': '1279b00d-cb50-4021-a595-08e7c3dd35c0',
#        'data_type': 'Open Standard'},
#       {'label': '13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.raw',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:1a1b004e-2ac6-42a7-b745-3e52be7fa22c',
#        'identifier': [{'system': 'PDC',
#          'value': '1a1b004e-2ac6-42a7-b745-3e52be7fa22c'}],
#        'data_category': 'Raw Mass Spectra',
#        'byte_size': 814691558,
#        'type': None,
#        'file_format': 'vendor-specific',
#        'checksum': '4a8c37b53a8dfd37df9f8a2457f08d8b',
#        'id': '1a1b004e-2ac6-42a7-b745-3e52be7fa22c',
#        'data_type': 'Proprietary'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.mzML.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:1cf6afc7-d8dd-492e-88b4-ce73f63f0525',
#        'identifier': [{'system': 'PDC',
#          'value': '1cf6afc7-d8dd-492e-88b4-ce73f63f0525'}],
#        'data_category': 'Processed Mass Spectra',
#        'byte_size': 228828721,
#        'type': None,
#        'file_format': 'mzML',
#        'checksum': '3f1e328de8a3cbc58ea38fb7e6b4be97',
#        'id': '1cf6afc7-d8dd-492e-88b4-ce73f63f0525',
#        'data_type': 'Open Standard'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.raw.cap.psm',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:21b0644c-4bc2-4a72-826a-eb0b507add08',
#        'identifier': [{'system': 'PDC',
#          'value': '21b0644c-4bc2-4a72-826a-eb0b507add08'}],
#        'data_category': 'Peptide Spectral Matches',
#        'byte_size': 5574069,
#        'type': None,
#        'file_format': 'tsv',
#        'checksum': '0fed23511a9cfd34d95dfa610e194b3d',
#        'id': '21b0644c-4bc2-4a72-826a-eb0b507add08',
#        'data_type': 'Text'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f07.mzid.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:250dbc86-4d5c-45aa-bab5-0fb75678574b',
#        'identifier': [{'system': 'PDC',
#          'value': '250dbc86-4d5c-45aa-bab5-0fb75678574b'}],
#        'data_category': 'Peptide Spectral Matches',
#        'byte_size': 6920705,
#        'type': None,
#        'file_format': 'mzIdentML',
#        'checksum': '59c5839127bf5e75de5099a6ef431a1b',
#        'id': '250dbc86-4d5c-45aa-bab5-0fb75678574b',
#        'data_type': 'Open Standard'},
#       {'label': '13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.raw.cap.psm',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:2834e1b0-1323-4ee5-b819-0e836aac244e',
#        'identifier': [{'system': 'PDC',
#          'value': '2834e1b0-1323-4ee5-b819-0e836aac244e'}],
#        'data_category': 'Peptide Spectral Matches',
#        'byte_size': 2529641,
#        'type': None,
#        'file_format': 'tsv',
#        'checksum': 'f5ce083f494f80aa6485cbfe65c3bf9d',
#        'id': '2834e1b0-1323-4ee5-b819-0e836aac244e',
#        'data_type': 'Text'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.raw',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:28cebeba-0af6-42f8-9d3d-9b2d6aadcd8a',
#        'identifier': [{'system': 'PDC',
#          'value': '28cebeba-0af6-42f8-9d3d-9b2d6aadcd8a'}],
#        'data_category': 'Raw Mass Spectra',
#        'byte_size': 1885185505,
#        'type': None,
#        'file_format': 'vendor-specific',
#        'checksum': '60a11fff4769d03b7d7a7586b5b05828',
#        'id': '28cebeba-0af6-42f8-9d3d-9b2d6aadcd8a',
#        'data_type': 'Proprietary'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.raw.cap.psm',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:2f42f669-8819-423f-9078-ec988cb71d11',
#        'identifier': [{'system': 'PDC',
#          'value': '2f42f669-8819-423f-9078-ec988cb71d11'}],
#        'data_category': 'Peptide Spectral Matches',
#        'byte_size': 5306074,
#        'type': None,
#        'file_format': 'tsv',
#        'checksum': '0c51b70a9ec74aabb52dc59120dcb18b',
#        'id': '2f42f669-8819-423f-9078-ec988cb71d11',
#        'data_type': 'Text'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.raw.cap.psm',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:31a66bc4-2b12-4310-919f-b8c0231e252d',
#        'identifier': [{'system': 'PDC',
#          'value': '31a66bc4-2b12-4310-919f-b8c0231e252d'}],
#        'data_category': 'Peptide Spectral Matches',
#        'byte_size': 5725135,
#        'type': None,
#        'file_format': 'tsv',
#        'checksum': 'cb5debd1ade07dfc256522f2332bb320',
#        'id': '31a66bc4-2b12-4310-919f-b8c0231e252d',
#        'data_type': 'Text'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.mzML.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:3ac4db66-7660-451f-833d-32ffa4f159d6',
#        'identifier': [{'system': 'PDC',
#          'value': '3ac4db66-7660-451f-833d-32ffa4f159d6'}],
#        'data_category': 'Processed Mass Spectra',
#        'byte_size': 199273832,
#        'type': None,
#        'file_format': 'mzML',
#        'checksum': 'e2e505e6dc18ec1eead1576d2289a09d',
#        'id': '3ac4db66-7660-451f-833d-32ffa4f159d6',
#        'data_type': 'Open Standard'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f08.mzML.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:3d1ffaff-47b5-4e63-9840-6490055fd38d',
#        'identifier': [{'system': 'PDC',
#          'value': '3d1ffaff-47b5-4e63-9840-6490055fd38d'}],
#        'data_category': 'Processed Mass Spectra',
#        'byte_size': 200810764,
#        'type': None,
#        'file_format': 'mzML',
#        'checksum': 'be9c1aa166ae610d36d3ae4b622d5112',
#        'id': '3d1ffaff-47b5-4e63-9840-6490055fd38d',
#        'data_type': 'Open Standard'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.raw',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:3d462e53-b907-4586-9b1f-041dde2b5dd5',
#        'identifier': [{'system': 'PDC',
#          'value': '3d462e53-b907-4586-9b1f-041dde2b5dd5'}],
#        'data_category': 'Raw Mass Spectra',
#        'byte_size': 1613377052,
#        'type': None,
#        'file_format': 'vendor-specific',
#        'checksum': 'f08c5881ec4ee03927ae8bf8676faee5',
#        'id': '3d462e53-b907-4586-9b1f-041dde2b5dd5',
#        'data_type': 'Proprietary'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f01.raw',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:40617525-424e-4bc0-8468-4e00ff9f0ccb',
#        'identifier': [{'system': 'PDC',
#          'value': '40617525-424e-4bc0-8468-4e00ff9f0ccb'}],
#        'data_category': 'Raw Mass Spectra',
#        'byte_size': 1638996500,
#        'type': None,
#        'file_format': 'vendor-specific',
#        'checksum': 'de695ce745d100a3c1512e6a7232956c',
#        'id': '40617525-424e-4bc0-8468-4e00ff9f0ccb',
#        'data_type': 'Proprietary'},
#       {'label': '13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.mzid.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:41057289-39ea-4f09-b24f-dfd1336fc1ed',
#        'identifier': [{'system': 'PDC',
#          'value': '41057289-39ea-4f09-b24f-dfd1336fc1ed'}],
#        'data_category': 'Peptide Spectral Matches',
#        'byte_size': 3715668,
#        'type': None,
#        'file_format': 'mzIdentML',
#        'checksum': 'c2ca24934a561a4d2f41e1a9e9fc474a',
#        'id': '41057289-39ea-4f09-b24f-dfd1336fc1ed',
#        'data_type': 'Open Standard'},
#       {'label': '13CPTAC_COprospective_P_PNNL_20170215_B4S1_f04.raw.cap.psm',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:42cfb6e3-3ebc-4a5e-bcd0-99c9fe7992b8',
#        'identifier': [{'system': 'PDC',
#          'value': '42cfb6e3-3ebc-4a5e-bcd0-99c9fe7992b8'}],
#        'data_category': 'Peptide Spectral Matches',
#        'byte_size': 2549143,
#        'type': None,
#        'file_format': 'tsv',
#        'checksum': 'b64210b35e7be647ed2450f872784e92',
#        'id': '42cfb6e3-3ebc-4a5e-bcd0-99c9fe7992b8',
#        'data_type': 'Text'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.mzid.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:47832160-26f2-4ad2-ae65-a781303b21d7',
#        'identifier': [{'system': 'PDC',
#          'value': '47832160-26f2-4ad2-ae65-a781303b21d7'}],
#        'data_category': 'Peptide Spectral Matches',
#        'byte_size': 7424654,
#        'type': None,
#        'file_format': 'mzIdentML',
#        'checksum': '61e93fdf0c6dc5e6b2db07971db2dac8',
#        'id': '47832160-26f2-4ad2-ae65-a781303b21d7',
#        'data_type': 'Open Standard'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.mzid.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:48d6afa8-9a0d-49b1-b080-f879108aefe9',
#        'identifier': [{'system': 'PDC',
#          'value': '48d6afa8-9a0d-49b1-b080-f879108aefe9'}],
#        'data_category': 'Peptide Spectral Matches',
#        'byte_size': 7140369,
#        'type': None,
#        'file_format': 'mzIdentML',
#        'checksum': '9ed307f94c00a23eacaf1901ad2f64fa',
#        'id': '48d6afa8-9a0d-49b1-b080-f879108aefe9',
#        'data_type': 'Open Standard'},
#       {'label': '13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.mzid.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:4ac75865-1dd4-4785-b8b0-ec0e133eab6c',
#        'identifier': [{'system': 'PDC',
#          'value': '4ac75865-1dd4-4785-b8b0-ec0e133eab6c'}],
#        'data_category': 'Peptide Spectral Matches',
#        'byte_size': 4067116,
#        'type': None,
#        'file_format': 'mzIdentML',
#        'checksum': 'ce117eb92b13ad29aef6fe713b22e8f5',
#        'id': '4ac75865-1dd4-4785-b8b0-ec0e133eab6c',
#        'data_type': 'Open Standard'},
#       {'label': '13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.mzML.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:4d60d292-cbbf-4610-8ef8-cd99fe3f900f',
#        'identifier': [{'system': 'PDC',
#          'value': '4d60d292-cbbf-4610-8ef8-cd99fe3f900f'}],
#        'data_category': 'Processed Mass Spectra',
#        'byte_size': 175999741,
#        'type': None,
#        'file_format': 'mzML',
#        'checksum': '2191752cf2fe702cdf8dbb8c5861029a',
#        'id': '4d60d292-cbbf-4610-8ef8-cd99fe3f900f',
#        'data_type': 'Open Standard'},
#       {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.mzid.gz',
#        'associated_project': ['CPTAC-2'],
#        'drs_uri': 'drs://dg.4DFC:51906b58-0772-436f-bcb8-fc2f36fcd5e2',
#        'identifier': [{'system': 'PDC',
#          'value': '51906b58-0772-436f-bcb8-fc2f36fcd5e2'}],
# ...
#      'checksum': 'dc5dfc6f27d894a8826f1a1ca4906cdf',
#      'id': 'b3f95f3e-50ce-40cf-b5e2-4b4c8ae61982',
#      'data_type': 'Open Standard'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.raw',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:b4be77b4-b2de-4b7a-b0ef-c13194f71569',
#      'identifier': [{'system': 'PDC',
#        'value': 'b4be77b4-b2de-4b7a-b0ef-c13194f71569'}],
#      'data_category': 'Raw Mass Spectra',
#      'byte_size': 1733606276,
#      'type': None,
#      'file_format': 'vendor-specific',
#      'checksum': '3fdecd345c95c60d6aff6d1790dcbbd7',
#      'id': 'b4be77b4-b2de-4b7a-b0ef-c13194f71569',
#      'data_type': 'Proprietary'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f11.raw',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:b576d133-59f8-40a3-8e02-8b6007547d34',
#      'identifier': [{'system': 'PDC',
#        'value': 'b576d133-59f8-40a3-8e02-8b6007547d34'}],
#      'data_category': 'Raw Mass Spectra',
#      'byte_size': 2045493648,
#      'type': None,
#      'file_format': 'vendor-specific',
#      'checksum': 'e3e298f2ddf04f61a866f06924a40086',
#      'id': 'b576d133-59f8-40a3-8e02-8b6007547d34',
#      'data_type': 'Proprietary'},
#     {'label': '87CPTAC_COprospective_W_VU_20160701_09CO022_f03.raw.cap.psm',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:b730fa81-1758-45c0-a6c5-2ab07e4c809d',
#      'identifier': [{'system': 'PDC',
#        'value': 'b730fa81-1758-45c0-a6c5-2ab07e4c809d'}],
#      'data_category': 'Peptide Spectral Matches',
#      'byte_size': 2368128,
#      'type': None,
#      'file_format': 'tsv',
#      'checksum': 'e603fec18a5c40748a5ca289954c4904',
#      'id': 'b730fa81-1758-45c0-a6c5-2ab07e4c809d',
#      'data_type': 'Text'},
#     {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f04.mzid.gz',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:b86bdaa4-4707-4b3b-88f4-809f6f985fdb',
#      'identifier': [{'system': 'PDC',
#        'value': 'b86bdaa4-4707-4b3b-88f4-809f6f985fdb'}],
#      'data_category': 'Peptide Spectral Matches',
#      'byte_size': 4588835,
#      'type': None,
#      'file_format': 'mzIdentML',
#      'checksum': '1146265fcc1376e7076a3bdcfa283ad4',
#      'id': 'b86bdaa4-4707-4b3b-88f4-809f6f985fdb',
#      'data_type': 'Open Standard'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f10.mzid.gz',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:b93abf59-3591-4921-9695-3cae8898818b',
#      'identifier': [{'system': 'PDC',
#        'value': 'b93abf59-3591-4921-9695-3cae8898818b'}],
#      'data_category': 'Peptide Spectral Matches',
#      'byte_size': 7904892,
#      'type': None,
#      'file_format': 'mzIdentML',
#      'checksum': '588dfd5be32fe26d062b045d5d2ae2dd',
#      'id': 'b93abf59-3591-4921-9695-3cae8898818b',
#      'data_type': 'Open Standard'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.raw',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:bc36613c-86ed-42f6-8717-2ba89c9bba7f',
#      'identifier': [{'system': 'PDC',
#        'value': 'bc36613c-86ed-42f6-8717-2ba89c9bba7f'}],
#      'data_category': 'Raw Mass Spectra',
#      'byte_size': 1672522583,
#      'type': None,
#      'file_format': 'vendor-specific',
#      'checksum': '9aeef99ecff5d9db6b95f68b84c4cf6b',
#      'id': 'bc36613c-86ed-42f6-8717-2ba89c9bba7f',
#      'data_type': 'Proprietary'},
#     {'label': '87CPTAC_COprospective_W_VU_20160701_09CO022_f05.mzML.gz',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:c286245c-2fbd-4743-9cd9-eb9c1bbb659a',
#      'identifier': [{'system': 'PDC',
#        'value': 'c286245c-2fbd-4743-9cd9-eb9c1bbb659a'}],
#      'data_category': 'Processed Mass Spectra',
#      'byte_size': 162569453,
#      'type': None,
#      'file_format': 'mzML',
#      'checksum': '3dd35f13250983ae5ebea887f7712463',
#      'id': 'c286245c-2fbd-4743-9cd9-eb9c1bbb659a',
#      'data_type': 'Open Standard'},
#     {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f06.mzML.gz',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:c309d2e0-0551-465a-a4e0-ca5e7a59d7f1',
#      'identifier': [{'system': 'PDC',
#        'value': 'c309d2e0-0551-465a-a4e0-ca5e7a59d7f1'}],
#      'data_category': 'Processed Mass Spectra',
#      'byte_size': 185219849,
#      'type': None,
#      'file_format': 'mzML',
#      'checksum': '796912f0c217f7c62951a8c6ebcba646',
#      'id': 'c309d2e0-0551-465a-a4e0-ca5e7a59d7f1',
#      'data_type': 'Open Standard'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.mzML.gz',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:c350e8c0-8fcc-4fe0-bc47-51b024fb757a',
#      'identifier': [{'system': 'PDC',
#        'value': 'c350e8c0-8fcc-4fe0-bc47-51b024fb757a'}],
#      'data_category': 'Processed Mass Spectra',
#      'byte_size': 217598995,
#      'type': None,
#      'file_format': 'mzML',
#      'checksum': '88dd488b6956cce153d1ef82e6c72793',
#      'id': 'c350e8c0-8fcc-4fe0-bc47-51b024fb757a',
#      'data_type': 'Open Standard'},
#     {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.mzid.gz',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:c932cbd0-306d-4159-ad30-0cd2ad018ffc',
#      'identifier': [{'system': 'PDC',
#        'value': 'c932cbd0-306d-4159-ad30-0cd2ad018ffc'}],
#      'data_category': 'Peptide Spectral Matches',
#      'byte_size': 4759004,
#      'type': None,
#      'file_format': 'mzIdentML',
#      'checksum': 'b5d73dbb30a07b6258c2ec7b6215b752',
#      'id': 'c932cbd0-306d-4159-ad30-0cd2ad018ffc',
#      'data_type': 'Open Standard'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f05.raw.cap.psm',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:cea9dd09-9672-4bf5-b093-0227db5b13f0',
#      'identifier': [{'system': 'PDC',
#        'value': 'cea9dd09-9672-4bf5-b093-0227db5b13f0'}],
#      'data_category': 'Peptide Spectral Matches',
#      'byte_size': 5853295,
#      'type': None,
#      'file_format': 'tsv',
#      'checksum': '660d8beeab85725b929595c74aee69f5',
#      'id': 'cea9dd09-9672-4bf5-b093-0227db5b13f0',
#      'data_type': 'Text'},
#     {'label': '87CPTAC_COprospective_W_VU_20160701_09CO022_f02.raw',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:d24a983f-5c0b-4df2-8135-06485b4a1529',
#      'identifier': [{'system': 'PDC',
#        'value': 'd24a983f-5c0b-4df2-8135-06485b4a1529'}],
#      'data_category': 'Raw Mass Spectra',
#      'byte_size': 863778432,
#      'type': None,
#      'file_format': 'vendor-specific',
#      'checksum': '9b44eaeb334e9218f8792273a1750919',
#      'id': 'd24a983f-5c0b-4df2-8135-06485b4a1529',
#      'data_type': 'Proprietary'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.raw.cap.psm',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:d252a407-fb5b-40c4-83e4-aa4865adb9e2',
#      'identifier': [{'system': 'PDC',
#        'value': 'd252a407-fb5b-40c4-83e4-aa4865adb9e2'}],
#      'data_category': 'Peptide Spectral Matches',
#      'byte_size': 5881324,
#      'type': None,
#      'file_format': 'tsv',
#      'checksum': 'c345249cb4d442bfa3a818bc39840f58',
#      'id': 'd252a407-fb5b-40c4-83e4-aa4865adb9e2',
#      'data_type': 'Text'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f06.raw',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:d8276edd-e179-4a3e-818c-1f071235dbbd',
#      'identifier': [{'system': 'PDC',
#        'value': 'd8276edd-e179-4a3e-818c-1f071235dbbd'}],
#      'data_category': 'Raw Mass Spectra',
#      'byte_size': 1809012149,
#      'type': None,
#      'file_format': 'vendor-specific',
#      'checksum': 'db63801481219c34d8b31d543f6f1377',
#      'id': 'd8276edd-e179-4a3e-818c-1f071235dbbd',
#      'data_type': 'Proprietary'},
#     {'label': '87CPTAC_COprospective_W_VU_20160701_09CO022_f06.mzid.gz',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:d9bece50-a8a4-4112-9fa6-680bd430ecdd',
#      'identifier': [{'system': 'PDC',
#        'value': 'd9bece50-a8a4-4112-9fa6-680bd430ecdd'}],
#      'data_category': 'Peptide Spectral Matches',
#      'byte_size': 4870038,
#      'type': None,
#      'file_format': 'mzIdentML',
#      'checksum': 'cdbb376bc89ae6dd3800df4b6db63f74',
#      'id': 'd9bece50-a8a4-4112-9fa6-680bd430ecdd',
#      'data_type': 'Open Standard'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.mzid.gz',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:df3f15b4-15ce-4957-8c30-912eedf71e18',
#      'identifier': [{'system': 'PDC',
#        'value': 'df3f15b4-15ce-4957-8c30-912eedf71e18'}],
#      'data_category': 'Peptide Spectral Matches',
#      'byte_size': 7709582,
#      'type': None,
#      'file_format': 'mzIdentML',
#      'checksum': '99267ba1f499eca071c363be1f35d22b',
#      'id': 'df3f15b4-15ce-4957-8c30-912eedf71e18',
#      'data_type': 'Open Standard'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f04.raw.cap.psm',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:e098e982-8a8f-449b-b36b-de20b63a8dc5',
#      'identifier': [{'system': 'PDC',
#        'value': 'e098e982-8a8f-449b-b36b-de20b63a8dc5'}],
#      'data_category': 'Peptide Spectral Matches',
#      'byte_size': 5719190,
#      'type': None,
#      'file_format': 'tsv',
#      'checksum': 'ddfa96324a1231e807c9a35477ece40d',
#      'id': 'e098e982-8a8f-449b-b36b-de20b63a8dc5',
#      'data_type': 'Text'},
#     {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f01.mzML.gz',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:e10a4629-75c4-45c9-9ce3-00d7b0f31232',
#      'identifier': [{'system': 'PDC',
#        'value': 'e10a4629-75c4-45c9-9ce3-00d7b0f31232'}],
#      'data_category': 'Processed Mass Spectra',
#      'byte_size': 177562667,
#      'type': None,
#      'file_format': 'mzML',
#      'checksum': 'ddf42adbfd8eeeb92c4acaba60222d5a',
#      'id': 'e10a4629-75c4-45c9-9ce3-00d7b0f31232',
#      'data_type': 'Open Standard'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f10.raw',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:e54f430b-8cdf-47d7-9c66-8688f32a256f',
#      'identifier': [{'system': 'PDC',
#        'value': 'e54f430b-8cdf-47d7-9c66-8688f32a256f'}],
#      'data_category': 'Raw Mass Spectra',
#      'byte_size': 1704603050,
#      'type': None,
#      'file_format': 'vendor-specific',
#      'checksum': '89b4b35b841c5c1202303c5218d94791',
#      'id': 'e54f430b-8cdf-47d7-9c66-8688f32a256f',
#      'data_type': 'Proprietary'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f07.mzid.gz',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:e678893f-fadc-4a92-842e-e89534886b9d',
#      'identifier': [{'system': 'PDC',
#        'value': 'e678893f-fadc-4a92-842e-e89534886b9d'}],
#      'data_category': 'Peptide Spectral Matches',
#      'byte_size': 7779691,
#      'type': None,
#      'file_format': 'mzIdentML',
#      'checksum': 'bf1889149a45b609e94b4c70e60326c0',
#      'id': 'e678893f-fadc-4a92-842e-e89534886b9d',
#      'data_type': 'Open Standard'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f06.mzid.gz',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:e68b9b17-100e-48c1-84d7-d1a5f9485c1e',
#      'identifier': [{'system': 'PDC',
#        'value': 'e68b9b17-100e-48c1-84d7-d1a5f9485c1e'}],
#      'data_category': 'Peptide Spectral Matches',
#      'byte_size': 7633586,
#      'type': None,
#      'file_format': 'mzIdentML',
#      'checksum': 'b0a122f5fcf894bc5eab79bfc1b9cd26',
#      'id': 'e68b9b17-100e-48c1-84d7-d1a5f9485c1e',
#      'data_type': 'Open Standard'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f08.mzML.gz',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:ec2b6628-0081-4609-9d84-8fe7e8fe5ee2',
#      'identifier': [{'system': 'PDC',
#        'value': 'ec2b6628-0081-4609-9d84-8fe7e8fe5ee2'}],
#      'data_category': 'Processed Mass Spectra',
#      'byte_size': 207488107,
#      'type': None,
#      'file_format': 'mzML',
#      'checksum': '1626736ac46b5d91480fe6160b24f2a8',
#      'id': 'ec2b6628-0081-4609-9d84-8fe7e8fe5ee2',
#      'data_type': 'Open Standard'},
#     {'label': '87CPTAC_COprospective_W_VU_20160701_09CO022_f02.mzML.gz',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:ef4a5cf5-ade0-41f9-95e6-b351531b2b52',
#      'identifier': [{'system': 'PDC',
#        'value': 'ef4a5cf5-ade0-41f9-95e6-b351531b2b52'}],
#      'data_category': 'Processed Mass Spectra',
#      'byte_size': 162518323,
#      'type': None,
#      'file_format': 'mzML',
#      'checksum': '16b6696d111d259eff591e7a7ea38ec7',
#      'id': 'ef4a5cf5-ade0-41f9-95e6-b351531b2b52',
#      'data_type': 'Open Standard'},
#     {'label': '16CPTAC_COprospective_W_PNNL_20170123_B4S4_f12.raw',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:eec97b50-58e7-41e9-9b53-e192632655c4',
#      'identifier': [{'system': 'PDC',
#        'value': 'eec97b50-58e7-41e9-9b53-e192632655c4'}],
#      'data_category': 'Raw Mass Spectra',
#      'byte_size': 1773260093,
#      'type': None,
#      'file_format': 'vendor-specific',
#      'checksum': '6422e8c855bacfdf80154503ce276fe1',
#      'id': 'eec97b50-58e7-41e9-9b53-e192632655c4',
#      'data_type': 'Proprietary'},
#     {'label': '87CPTAC_COprospective_W_VU_20160701_09CO022_f05.raw',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:f07375eb-d4a0-4df9-809c-77cb576ef4b5',
#      'identifier': [{'system': 'PDC',
#        'value': 'f07375eb-d4a0-4df9-809c-77cb576ef4b5'}],
#      'data_category': 'Raw Mass Spectra',
#      'byte_size': 923754997,
#      'type': None,
#      'file_format': 'vendor-specific',
#      'checksum': 'a6773785babdf0185b665d0067f76492',
#      'id': 'f07375eb-d4a0-4df9-809c-77cb576ef4b5',
#      'data_type': 'Proprietary'},
#     {'label': '87CPTAC_COprospective_W_VU_20160701_09CO022_f03.raw',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:f0d9fd49-298f-449b-9d29-b7253c5e2a7c',
#      'identifier': [{'system': 'PDC',
#        'value': 'f0d9fd49-298f-449b-9d29-b7253c5e2a7c'}],
#      'data_category': 'Raw Mass Spectra',
#      'byte_size': 936791109,
#      'type': None,
#      'file_format': 'vendor-specific',
#      'checksum': '67ea86f630b368d6d475bb8a9e2ba7f4',
#      'id': 'f0d9fd49-298f-449b-9d29-b7253c5e2a7c',
#      'data_type': 'Proprietary'},
#     {'label': '16CPTAC_COprospective_P_PNNL_20170215_B4S4_f03.raw.cap.psm',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:f3bb04cb-8cbd-45b6-8b2c-c3c42a56e9c2',
#      'identifier': [{'system': 'PDC',
#        'value': 'f3bb04cb-8cbd-45b6-8b2c-c3c42a56e9c2'}],
#      'data_category': 'Peptide Spectral Matches',
#      'byte_size': 2967257,
#      'type': None,
#      'file_format': 'tsv',
#      'checksum': 'ddb9975b0b00e6f10fe5bce22d0decd2',
#      'id': 'f3bb04cb-8cbd-45b6-8b2c-c3c42a56e9c2',
#      'data_type': 'Text'},
#     {'label': '87CPTAC_COprospective_W_VU_20160701_09CO022_f02.raw.cap.psm',
#      'associated_project': ['CPTAC-2'],
#      'drs_uri': 'drs://dg.4DFC:fbbfc3ab-0238-48e9-8dff-c669e88c54d4',
#      'identifier': [{'system': 'PDC',
#        'value': 'fbbfc3ab-0238-48e9-8dff-c669e88c54d4'}],
#      'data_category': 'Peptide Spectral Matches',
#      'byte_size': 2573922,
#      'type': None,
#      'file_format': 'tsv',
#      'checksum': 'eba1012863396408a3ced48380841b45',
#      'id': 'fbbfc3ab-0238-48e9-8dff-c669e88c54d4',
#      'data_type': 'Text'}],
#    'derived_from_specimen': 'Initial specimen',
#    'associated_project': 'CPTAC-2',
#    'age_at_collection': None,
#    'anatomical_site': 'Not Reported',
#    'source_material_type': 'Primary Tumor',
#    'derived_from_subject': None,
#    'specimen_type': 'sample',
#    'id': 'f6cce507-641b-11e8-bcf1-0a2705229b82',
#    'primary_disease_type': 'Colon Adenocarcinoma',
#    'identifier': [{'system': 'PDC',
#      'value': 'f6cce507-641b-11e8-bcf1-0a2705229b82'}]}],
#  'associated_project': 'CPTAC-2',
#  'primary_disease_type': 'Colon Adenocarcinoma',
#  'identifier': [{'system': 'PDC',
#    'value': '459e3b69-63d6-11e8-bcf1-0a2705229b82'}],
#  'primary_disease_site': 'Colon'}

# %%
columns()
# Out:
# SELECT field_path FROM `gdc-bq-sample.cda_mvp.INFORMATION_SCHEMA.COLUMN_FIELD_PATHS` WHERE table_name = 'v3'
# ['days_to_birth',
#  'race',
#  'sex',
#  'ethnicity',
#  'id',
#  'ResearchSubject',
#  'ResearchSubject.Diagnosis',
#  'ResearchSubject.Diagnosis.morphology',
#  'ResearchSubject.Diagnosis.tumor_stage',
#  'ResearchSubject.Diagnosis.tumor_grade',
#  'ResearchSubject.Diagnosis.Treatment',
#  'ResearchSubject.Diagnosis.Treatment.type',
#  'ResearchSubject.Diagnosis.Treatment.outcome',
#  'ResearchSubject.Diagnosis.id',
#  'ResearchSubject.Diagnosis.primary_diagnosis',
#  'ResearchSubject.Diagnosis.age_at_diagnosis',
#  'ResearchSubject.Specimen',
#  'ResearchSubject.Specimen.File',
#  'ResearchSubject.Specimen.File.label',
#  'ResearchSubject.Specimen.File.associated_project',
#  'ResearchSubject.Specimen.File.drs_uri',
#  'ResearchSubject.Specimen.File.identifier',
#  'ResearchSubject.Specimen.File.identifier.system',
#  'ResearchSubject.Specimen.File.identifier.value',
#  'ResearchSubject.Specimen.File.data_category',
#  'ResearchSubject.Specimen.File.byte_size',
#  'ResearchSubject.Specimen.File.type',
#  'ResearchSubject.Specimen.File.file_format',
#  'ResearchSubject.Specimen.File.checksum',
#  'ResearchSubject.Specimen.File.id',
#  'ResearchSubject.Specimen.File.data_type',
#  'ResearchSubject.Specimen.derived_from_specimen',
#  'ResearchSubject.Specimen.associated_project',
#  'ResearchSubject.Specimen.age_at_collection',
#  'ResearchSubject.Specimen.anatomical_site',
#  'ResearchSubject.Specimen.source_material_type',
#  'ResearchSubject.Specimen.derived_from_subject',
#  'ResearchSubject.Specimen.specimen_type',
#  'ResearchSubject.Specimen.id',
#  'ResearchSubject.Specimen.primary_disease_type',
#  'ResearchSubject.Specimen.identifier',
#  'ResearchSubject.Specimen.identifier.system',
#  'ResearchSubject.Specimen.identifier.value',
#  'ResearchSubject.associated_project',
#  'ResearchSubject.id',
#  'ResearchSubject.primary_disease_type',
#  'ResearchSubject.identifier',
#  'ResearchSubject.identifier.system',
#  'ResearchSubject.identifier.value',
#  'ResearchSubject.primary_disease_site']

# %% [markdown]
# The big advantage with CDA is that we can query the submitter ID directly (by using the Specimen.derived_from_subject option) to get a list of all the cases associated with a particular subject.

# %%
query_by_derived = Q(f'ResearchSubject.Specimen.derived_from_subject = "{submitter_id}"')
results = query_by_derived.run(limit=100)
print(results)

result_list = []
for result in results:
    result_list.append(result)

# Write this to a file.
with open(f'cda_derived_from_{submitter_id}.json', 'w') as f:
    json.dump(result_list, f, indent=4, sort_keys=True)

result_list
# Out:
# Query: SELECT * FROM gdc-bq-sample.cda_mvp.v3, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen WHERE (_Specimen.derived_from_subject = '09CO022')
# Offset: 0
# Limit: 100
# Count: 11
# More pages: No
# [{'days_to_birth': None,
#   'race': 'black or african american',
#   'sex': 'female',
#   'ethnicity': 'not hispanic or latino',
#   'id': '4591a53d-5668-4a70-b44b-e08a3d59267e',
#   'ResearchSubject': [{'Diagnosis': [{'morphology': '8140/3',
#       'tumor_stage': 'Stage IIB',
#       'tumor_grade': 'Not Reported',
#       'Treatment': [],
#       'id': '7b8d36ba-ab84-48ad-ac2c-11ac40d3d0eb',
#       'primary_diagnosis': 'Adenocarcinoma, NOS',
#       'age_at_diagnosis': None}],
#     'Specimen': [{'File': [{'label': 'fbc0c313-d356-4ad9-8257-57e90fb7f26b.wxs.Pindel.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:00a9219e-109c-4013-89c8-3d01b39cd9bf',
#         'identifier': [{'system': 'GDC',
#           'value': '00a9219e-109c-4013-89c8-3d01b39cd9bf'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 248056,
#         'type': None,
#         'file_format': None,
#         'checksum': 'e09e988c4969cf68fac8168fa622df9f',
#         'id': '00a9219e-109c-4013-89c8-3d01b39cd9bf',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.mutect2.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:18b4dd00-f22a-4904-92f8-11d03fc21e44',
#         'identifier': [{'system': 'GDC',
#           'value': '18b4dd00-f22a-4904-92f8-11d03fc21e44'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 1611219,
#         'type': None,
#         'file_format': None,
#         'checksum': '5eab6ca0fbbb67a3204e55266161dc55',
#         'id': '18b4dd00-f22a-4904-92f8-11d03fc21e44',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '8c6af725-abc2-48af-a604-580e4b51fa30.wxs.MuTect2.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:1fb29f83-87a5-416d-8af1-d94d749aeda9',
#         'identifier': [{'system': 'GDC',
#           'value': '1fb29f83-87a5-416d-8af1-d94d749aeda9'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 7547974,
#         'type': None,
#         'file_format': None,
#         'checksum': '2ab8ea64673f22be2fc3ae40ce3356eb',
#         'id': '1fb29f83-87a5-416d-8af1-d94d749aeda9',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.star_splice_junctions.tsv.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:251c0ac2-9ba0-43ca-acc1-01e9638b1250',
#         'identifier': [{'system': 'GDC',
#           'value': '251c0ac2-9ba0-43ca-acc1-01e9638b1250'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 2472314,
#         'type': None,
#         'file_format': None,
#         'checksum': 'f81e25701c17eab29bdee4223c82cc56',
#         'id': '251c0ac2-9ba0-43ca-acc1-01e9638b1250',
#         'data_type': 'Splice Junction Quantification'},
#        {'label': 'a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.genomic.gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:38a714a2-ea50-487f-b184-fc3e2fbb8635',
#         'identifier': [{'system': 'GDC',
#           'value': '38a714a2-ea50-487f-b184-fc3e2fbb8635'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 4414014860,
#         'type': None,
#         'file_format': None,
#         'checksum': '46f5800fb243249938ddf09fc95ed416',
#         'id': '38a714a2-ea50-487f-b184-fc3e2fbb8635',
#         'data_type': 'Aligned Reads'},
#        {'label': '6cca2f97-024b-4d5f-a753-bf148725ec8c.htseq_counts.txt.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:502ada14-06bf-48ae-9f57-66646a9c8fa0',
#         'identifier': [{'system': 'GDC',
#           'value': '502ada14-06bf-48ae-9f57-66646a9c8fa0'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 238654,
#         'type': None,
#         'file_format': None,
#         'checksum': 'a15b1b8c641407a9c8fa3756fc86d7c6',
#         'id': '502ada14-06bf-48ae-9f57-66646a9c8fa0',
#         'data_type': 'Gene Expression Quantification'},
#        {'label': 'dfecdd3f-a8eb-4e69-8713-85170b11fe2a.mirnaseq.mirnas.quantification.txt',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:527f7662-b314-44ba-998b-99d1dfc7ae33',
#         'identifier': [{'system': 'GDC',
#           'value': '527f7662-b314-44ba-998b-99d1dfc7ae33'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 49839,
#         'type': None,
#         'file_format': None,
#         'checksum': '3540412c79caa600aef56f928fed04aa',
#         'id': '527f7662-b314-44ba-998b-99d1dfc7ae33',
#         'data_type': 'miRNA Expression Quantification'},
#        {'label': '0d8adcbf-13f0-48c3-83df-3fa205b79ae8_mirnaseq_gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:5dd36db9-d94c-412a-8cc6-7cc2f43b890c',
#         'identifier': [{'system': 'GDC',
#           'value': '5dd36db9-d94c-412a-8cc6-7cc2f43b890c'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 265126753,
#         'type': None,
#         'file_format': None,
#         'checksum': '14982035c8909b3747d03a23924c5af0',
#         'id': '5dd36db9-d94c-412a-8cc6-7cc2f43b890c',
#         'data_type': 'Aligned Reads'},
#        {'label': 'a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.star_gene_counts.tsv.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:5e0db211-7fa4-477d-b642-ec5082d99e88',
#         'identifier': [{'system': 'GDC',
#           'value': '5e0db211-7fa4-477d-b642-ec5082d99e88'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 369648,
#         'type': None,
#         'file_format': None,
#         'checksum': '38e816e53699daac1474a27681ee315c',
#         'id': '5e0db211-7fa4-477d-b642-ec5082d99e88',
#         'data_type': 'Gene Expression Quantification'},
#        {'label': '17ff92b1-3226-430a-8599-bacdb8dd65b0.wxs.Pindel.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:654ba668-6f5f-497b-acd4-c41bd8e18e9e',
#         'identifier': [{'system': 'GDC',
#           'value': '654ba668-6f5f-497b-acd4-c41bd8e18e9e'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 163494,
#         'type': None,
#         'file_format': None,
#         'checksum': 'fabcd676c20684a8df20be63e49756a4',
#         'id': '654ba668-6f5f-497b-acd4-c41bd8e18e9e',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '2906082e-a906-4e04-b79b-f69541bb82bb.wxs.pindel.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:65d6fa7c-d474-4466-9b7d-a21b245237f7',
#         'identifier': [{'system': 'GDC',
#           'value': '65d6fa7c-d474-4466-9b7d-a21b245237f7'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 43887,
#         'type': None,
#         'file_format': None,
#         'checksum': 'cc174a5c968bd1dfc464c22fb1244f2b',
#         'id': '65d6fa7c-d474-4466-9b7d-a21b245237f7',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '70331103-de30-4d20-9dee-3d9bec0675d0.wxs.SomaticSniper.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:6bb0f620-8925-4cd4-89c2-f0477d334ee9',
#         'identifier': [{'system': 'GDC',
#           'value': '6bb0f620-8925-4cd4-89c2-f0477d334ee9'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 5005951,
#         'type': None,
#         'file_format': None,
#         'checksum': 'f1582d896290ad6c93f4ee97195fb5a9',
#         'id': '6bb0f620-8925-4cd4-89c2-f0477d334ee9',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'dfecdd3f-a8eb-4e69-8713-85170b11fe2a.mirnaseq.isoforms.quantification.txt',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:6e56cf8c-acb9-4a34-a3d8-ec0060a19193',
#         'identifier': [{'system': 'GDC',
#           'value': '6e56cf8c-acb9-4a34-a3d8-ec0060a19193'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 425670,
#         'type': None,
#         'file_format': None,
#         'checksum': '3d57646194512126325c59177b8e537b',
#         'id': '6e56cf8c-acb9-4a34-a3d8-ec0060a19193',
#         'data_type': 'Isoform Expression Quantification'},
#        {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.varscan2.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:7247faf2-afb0-4a39-9a55-9d471de5c550',
#         'identifier': [{'system': 'GDC',
#           'value': '7247faf2-afb0-4a39-9a55-9d471de5c550'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 115646,
#         'type': None,
#         'file_format': None,
#         'checksum': '0dd012d2a55bedca6921fad581fbbd27',
#         'id': '7247faf2-afb0-4a39-9a55-9d471de5c550',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '9250d96e-1cdc-4d68-8a56-f7b186a6fab5_wxs_gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:73e507f1-8e2f-400d-acd6-ee9a9ad338e9',
#         'identifier': [{'system': 'GDC',
#           'value': '73e507f1-8e2f-400d-acd6-ee9a9ad338e9'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 59654562246,
#         'type': None,
#         'file_format': None,
#         'checksum': '6e2a2dbfef2574f49c261d1e567316b3',
#         'id': '73e507f1-8e2f-400d-acd6-ee9a9ad338e9',
#         'data_type': 'Aligned Reads'},
#        {'label': '96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_raw.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:77a179fc-a3bc-462e-8209-979b9a031e20',
#         'identifier': [{'system': 'GDC',
#           'value': '77a179fc-a3bc-462e-8209-979b9a031e20'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 342713,
#         'type': None,
#         'file_format': None,
#         'checksum': '35d6d356b65c552962845a5f963db28a',
#         'id': '77a179fc-a3bc-462e-8209-979b9a031e20',
#         'data_type': 'Aggregated Somatic Mutation'},
#        {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.muse.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:849452d3-3a1c-4f3d-a7c2-3e0b7580efec',
#         'identifier': [{'system': 'GDC',
#           'value': '849452d3-3a1c-4f3d-a7c2-3e0b7580efec'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 50325,
#         'type': None,
#         'file_format': None,
#         'checksum': '5dab4cb237c6bdf9f26938510d9f6442',
#         'id': '849452d3-3a1c-4f3d-a7c2-3e0b7580efec',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '6cca2f97-024b-4d5f-a753-bf148725ec8c.FPKM-UQ.txt.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:8bea647e-66d8-42af-ab06-7bd0629179c7',
#         'identifier': [{'system': 'GDC',
#           'value': '8bea647e-66d8-42af-ab06-7bd0629179c7'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 371625,
#         'type': None,
#         'file_format': None,
#         'checksum': '7a0a86367f6f1129851e2d9152813c8c',
#         'id': '8bea647e-66d8-42af-ab06-7bd0629179c7',
#         'data_type': 'Gene Expression Quantification'},
#        {'label': '96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_masked.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb',
#         'identifier': [{'system': 'GDC',
#           'value': '8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 53313,
#         'type': None,
#         'file_format': None,
#         'checksum': 'dc22add6654662c05c787407c20b4578',
#         'id': '8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb',
#         'data_type': 'Masked Somatic Mutation'},
#        {'label': '6cca2f97-024b-4d5f-a753-bf148725ec8c.FPKM.txt.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:8f4884a5-9726-4abc-8e3b-db4f1b603dfa',
#         'identifier': [{'system': 'GDC',
#           'value': '8f4884a5-9726-4abc-8e3b-db4f1b603dfa'}],
#         'data_category': 'Transcriptome Profiling',
#         'byte_size': 295185,
#         'type': None,
#         'file_format': None,
#         'checksum': 'a641a766218e0b4be0ffe05aa3229ac2',
#         'id': '8f4884a5-9726-4abc-8e3b-db4f1b603dfa',
#         'data_type': 'Gene Expression Quantification'},
#        {'label': 'a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.transcriptome.gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:91d7d870-2331-472f-bc74-19c1d9f4d6c7',
#         'identifier': [{'system': 'GDC',
#           'value': '91d7d870-2331-472f-bc74-19c1d9f4d6c7'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 7602867805,
#         'type': None,
#         'file_format': None,
#         'checksum': 'ecce292cfbab62abf3e911a98579e5f3',
#         'id': '91d7d870-2331-472f-bc74-19c1d9f4d6c7',
#         'data_type': 'Aligned Reads'},
#        {'label': 'ea51af0a-e767-4db1-8a8d-1cf19df17c4c.wxs.MuTect2.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:9c18aa38-5edd-40cf-8389-a03aea35a150',
#         'identifier': [{'system': 'GDC',
#           'value': '9c18aa38-5edd-40cf-8389-a03aea35a150'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 6167311,
#         'type': None,
#         'file_format': None,
#         'checksum': '765119382d413e7051cedb1ad122d436',
#         'id': '9c18aa38-5edd-40cf-8389-a03aea35a150',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'abdaac20-1a31-4785-ace5-7ef4cc07bc8e.wxs.VarScan2.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1',
#         'identifier': [{'system': 'GDC',
#           'value': '9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 767641,
#         'type': None,
#         'file_format': None,
#         'checksum': '641b13968bf9401223d29e9f3350804c',
#         'id': '9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'a78c9b27-d695-4a91-90f8-cd08c29602b2.wxs.MuSE.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:9f27b7a7-7e18-42c8-a5bd-62461a567955',
#         'identifier': [{'system': 'GDC',
#           'value': '9f27b7a7-7e18-42c8-a5bd-62461a567955'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 305442,
#         'type': None,
#         'file_format': None,
#         'checksum': 'ef18bf2c57161d8a48256f6f9fd3c441',
#         'id': '9f27b7a7-7e18-42c8-a5bd-62461a567955',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'a01fea54-6450-40d8-9948-0ba9e228d592.rna_seq.chimeric.gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:a97b91db-1804-4f0a-8cdd-10e4cb30d458',
#         'identifier': [{'system': 'GDC',
#           'value': 'a97b91db-1804-4f0a-8cdd-10e4cb30d458'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 20460524,
#         'type': None,
#         'file_format': None,
#         'checksum': '31b766f0f934513062f5213dc9740b94',
#         'id': 'a97b91db-1804-4f0a-8cdd-10e4cb30d458',
#         'data_type': 'Aligned Reads'},
#        {'label': '0e8a628a-d5a4-4ae2-bb81-73a1a9c1d4cd.wxs.MuSE.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b8ecf468-dd33-4f43-8093-544d92d676f6',
#         'identifier': [{'system': 'GDC',
#           'value': 'b8ecf468-dd33-4f43-8093-544d92d676f6'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 438051,
#         'type': None,
#         'file_format': None,
#         'checksum': '52a6cc7af0c366fd93240a49998289ff',
#         'id': 'b8ecf468-dd33-4f43-8093-544d92d676f6',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.somaticsniper.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:c411fd62-0198-4c47-ada8-0cffafb5a262',
#         'identifier': [{'system': 'GDC',
#           'value': 'c411fd62-0198-4c47-ada8-0cffafb5a262'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 5936384,
#         'type': None,
#         'file_format': None,
#         'checksum': '6d07c80d2683a58c9e656ee165570f35',
#         'id': 'c411fd62-0198-4c47-ada8-0cffafb5a262',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': 'b85b56a6-89e2-424c-993d-764ae20bf072.wxs.SomaticSniper.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:d7b978a6-a601-4025-8408-ee1fdb391689',
#         'identifier': [{'system': 'GDC',
#           'value': 'd7b978a6-a601-4025-8408-ee1fdb391689'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 4001912,
#         'type': None,
#         'file_format': None,
#         'checksum': 'ec3a6c924c6f10268a0b3f5de77c2e4d',
#         'id': 'd7b978a6-a601-4025-8408-ee1fdb391689',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'd4496cf9-bc61-400a-aa97-72331ee4fd2b.wxs.VarScan2.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:dd6923a5-8fcc-4bc9-8912-14b20f387214',
#         'identifier': [{'system': 'GDC',
#           'value': 'dd6923a5-8fcc-4bc9-8912-14b20f387214'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 567540,
#         'type': None,
#         'file_format': None,
#         'checksum': 'da2b85a5ffd55a7884557784684ab45d',
#         'id': 'dd6923a5-8fcc-4bc9-8912-14b20f387214',
#         'data_type': 'Annotated Somatic Mutation'}],
#       'derived_from_specimen': 'Initial sample',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '09CO022',
#       'specimen_type': 'sample',
#       'id': '4591a53d-5668-4a70-b44b-e08a3d59267e',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '4591a53d-5668-4a70-b44b-e08a3d59267e'}]},
#      {'File': [],
#       'derived_from_specimen': '4591a53d-5668-4a70-b44b-e08a3d59267e',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '09CO022',
#       'specimen_type': 'portion',
#       'id': 'c53c4d60-2ddb-5da8-932e-00a86fa2347f',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'c53c4d60-2ddb-5da8-932e-00a86fa2347f'}]},
#      {'File': [],
#       'derived_from_specimen': 'c53c4d60-2ddb-5da8-932e-00a86fa2347f',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '09CO022',
#       'specimen_type': 'analyte',
#       'id': '31075cfa-7aef-59f1-bf54-a1cddb5ee0fd',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '31075cfa-7aef-59f1-bf54-a1cddb5ee0fd'}]},
#      {'File': [],
#       'derived_from_specimen': '31075cfa-7aef-59f1-bf54-a1cddb5ee0fd',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '09CO022',
#       'specimen_type': 'aliquot',
#       'id': '0d8adcbf-13f0-48c3-83df-3fa205b79ae8',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '0d8adcbf-13f0-48c3-83df-3fa205b79ae8'}]},
#      {'File': [],
#       'derived_from_specimen': '4591a53d-5668-4a70-b44b-e08a3d59267e',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '09CO022',
#       'specimen_type': 'portion',
#       'id': 'd085ebd9-7605-54a0-abb9-10867f5fa1b1',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'd085ebd9-7605-54a0-abb9-10867f5fa1b1'}]},
#      {'File': [],
#       'derived_from_specimen': 'd085ebd9-7605-54a0-abb9-10867f5fa1b1',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '09CO022',
#       'specimen_type': 'analyte',
#       'id': 'a31724b6-e550-552b-bd61-41341c534e28',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'a31724b6-e550-552b-bd61-41341c534e28'}]},
#      {'File': [],
#       'derived_from_specimen': 'a31724b6-e550-552b-bd61-41341c534e28',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Primary Tumor',
#       'derived_from_subject': '09CO022',
#       'specimen_type': 'aliquot',
#       'id': '9250d96e-1cdc-4d68-8a56-f7b186a6fab5',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '9250d96e-1cdc-4d68-8a56-f7b186a6fab5'}]},
#      {'File': [{'label': 'fbc0c313-d356-4ad9-8257-57e90fb7f26b.wxs.Pindel.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:00a9219e-109c-4013-89c8-3d01b39cd9bf',
#         'identifier': [{'system': 'GDC',
#           'value': '00a9219e-109c-4013-89c8-3d01b39cd9bf'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 248056,
#         'type': None,
#         'file_format': None,
#         'checksum': 'e09e988c4969cf68fac8168fa622df9f',
#         'id': '00a9219e-109c-4013-89c8-3d01b39cd9bf',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.mutect2.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:18b4dd00-f22a-4904-92f8-11d03fc21e44',
#         'identifier': [{'system': 'GDC',
#           'value': '18b4dd00-f22a-4904-92f8-11d03fc21e44'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 1611219,
#         'type': None,
#         'file_format': None,
#         'checksum': '5eab6ca0fbbb67a3204e55266161dc55',
#         'id': '18b4dd00-f22a-4904-92f8-11d03fc21e44',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '8c6af725-abc2-48af-a604-580e4b51fa30.wxs.MuTect2.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:1fb29f83-87a5-416d-8af1-d94d749aeda9',
#         'identifier': [{'system': 'GDC',
#           'value': '1fb29f83-87a5-416d-8af1-d94d749aeda9'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 7547974,
#         'type': None,
#         'file_format': None,
#         'checksum': '2ab8ea64673f22be2fc3ae40ce3356eb',
#         'id': '1fb29f83-87a5-416d-8af1-d94d749aeda9',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '17ff92b1-3226-430a-8599-bacdb8dd65b0.wxs.Pindel.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:654ba668-6f5f-497b-acd4-c41bd8e18e9e',
#         'identifier': [{'system': 'GDC',
#           'value': '654ba668-6f5f-497b-acd4-c41bd8e18e9e'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 163494,
#         'type': None,
#         'file_format': None,
#         'checksum': 'fabcd676c20684a8df20be63e49756a4',
#         'id': '654ba668-6f5f-497b-acd4-c41bd8e18e9e',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '2906082e-a906-4e04-b79b-f69541bb82bb.wxs.pindel.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:65d6fa7c-d474-4466-9b7d-a21b245237f7',
#         'identifier': [{'system': 'GDC',
#           'value': '65d6fa7c-d474-4466-9b7d-a21b245237f7'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 43887,
#         'type': None,
#         'file_format': None,
#         'checksum': 'cc174a5c968bd1dfc464c22fb1244f2b',
#         'id': '65d6fa7c-d474-4466-9b7d-a21b245237f7',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '70331103-de30-4d20-9dee-3d9bec0675d0.wxs.SomaticSniper.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:6bb0f620-8925-4cd4-89c2-f0477d334ee9',
#         'identifier': [{'system': 'GDC',
#           'value': '6bb0f620-8925-4cd4-89c2-f0477d334ee9'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 5005951,
#         'type': None,
#         'file_format': None,
#         'checksum': 'f1582d896290ad6c93f4ee97195fb5a9',
#         'id': '6bb0f620-8925-4cd4-89c2-f0477d334ee9',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.varscan2.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:7247faf2-afb0-4a39-9a55-9d471de5c550',
#         'identifier': [{'system': 'GDC',
#           'value': '7247faf2-afb0-4a39-9a55-9d471de5c550'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 115646,
#         'type': None,
#         'file_format': None,
#         'checksum': '0dd012d2a55bedca6921fad581fbbd27',
#         'id': '7247faf2-afb0-4a39-9a55-9d471de5c550',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_raw.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:77a179fc-a3bc-462e-8209-979b9a031e20',
#         'identifier': [{'system': 'GDC',
#           'value': '77a179fc-a3bc-462e-8209-979b9a031e20'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 342713,
#         'type': None,
#         'file_format': None,
#         'checksum': '35d6d356b65c552962845a5f963db28a',
#         'id': '77a179fc-a3bc-462e-8209-979b9a031e20',
#         'data_type': 'Aggregated Somatic Mutation'},
#        {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.muse.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:849452d3-3a1c-4f3d-a7c2-3e0b7580efec',
#         'identifier': [{'system': 'GDC',
#           'value': '849452d3-3a1c-4f3d-a7c2-3e0b7580efec'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 50325,
#         'type': None,
#         'file_format': None,
#         'checksum': '5dab4cb237c6bdf9f26938510d9f6442',
#         'id': '849452d3-3a1c-4f3d-a7c2-3e0b7580efec',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': '96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_masked.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb',
#         'identifier': [{'system': 'GDC',
#           'value': '8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 53313,
#         'type': None,
#         'file_format': None,
#         'checksum': 'dc22add6654662c05c787407c20b4578',
#         'id': '8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb',
#         'data_type': 'Masked Somatic Mutation'},
#        {'label': 'ea51af0a-e767-4db1-8a8d-1cf19df17c4c.wxs.MuTect2.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:9c18aa38-5edd-40cf-8389-a03aea35a150',
#         'identifier': [{'system': 'GDC',
#           'value': '9c18aa38-5edd-40cf-8389-a03aea35a150'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 6167311,
#         'type': None,
#         'file_format': None,
#         'checksum': '765119382d413e7051cedb1ad122d436',
#         'id': '9c18aa38-5edd-40cf-8389-a03aea35a150',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'abdaac20-1a31-4785-ace5-7ef4cc07bc8e.wxs.VarScan2.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1',
#         'identifier': [{'system': 'GDC',
#           'value': '9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 767641,
#         'type': None,
#         'file_format': None,
#         'checksum': '641b13968bf9401223d29e9f3350804c',
#         'id': '9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'a78c9b27-d695-4a91-90f8-cd08c29602b2.wxs.MuSE.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:9f27b7a7-7e18-42c8-a5bd-62461a567955',
#         'identifier': [{'system': 'GDC',
#           'value': '9f27b7a7-7e18-42c8-a5bd-62461a567955'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 305442,
#         'type': None,
#         'file_format': None,
#         'checksum': 'ef18bf2c57161d8a48256f6f9fd3c441',
#         'id': '9f27b7a7-7e18-42c8-a5bd-62461a567955',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'ce309009-9257-4c13-9241-83fc629c35a0_wxs_gdc_realn.bam',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:a35f18eb-3475-4433-a72f-4b8aa2cb6106',
#         'identifier': [{'system': 'GDC',
#           'value': 'a35f18eb-3475-4433-a72f-4b8aa2cb6106'}],
#         'data_category': 'Sequencing Reads',
#         'byte_size': 69157605164,
#         'type': None,
#         'file_format': None,
#         'checksum': '21f2140d9d3ef197422820a7e0bb8561',
#         'id': 'a35f18eb-3475-4433-a72f-4b8aa2cb6106',
#         'data_type': 'Aligned Reads'},
#        {'label': '0e8a628a-d5a4-4ae2-bb81-73a1a9c1d4cd.wxs.MuSE.somatic_annotation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:b8ecf468-dd33-4f43-8093-544d92d676f6',
#         'identifier': [{'system': 'GDC',
#           'value': 'b8ecf468-dd33-4f43-8093-544d92d676f6'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 438051,
#         'type': None,
#         'file_format': None,
#         'checksum': '52a6cc7af0c366fd93240a49998289ff',
#         'id': 'b8ecf468-dd33-4f43-8093-544d92d676f6',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.somaticsniper.raw_somatic_mutation.vcf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:c411fd62-0198-4c47-ada8-0cffafb5a262',
#         'identifier': [{'system': 'GDC',
#           'value': 'c411fd62-0198-4c47-ada8-0cffafb5a262'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 5936384,
#         'type': None,
#         'file_format': None,
#         'checksum': '6d07c80d2683a58c9e656ee165570f35',
#         'id': 'c411fd62-0198-4c47-ada8-0cffafb5a262',
#         'data_type': 'Raw Simple Somatic Mutation'},
#        {'label': 'b85b56a6-89e2-424c-993d-764ae20bf072.wxs.SomaticSniper.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:d7b978a6-a601-4025-8408-ee1fdb391689',
#         'identifier': [{'system': 'GDC',
#           'value': 'd7b978a6-a601-4025-8408-ee1fdb391689'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 4001912,
#         'type': None,
#         'file_format': None,
#         'checksum': 'ec3a6c924c6f10268a0b3f5de77c2e4d',
#         'id': 'd7b978a6-a601-4025-8408-ee1fdb391689',
#         'data_type': 'Annotated Somatic Mutation'},
#        {'label': 'd4496cf9-bc61-400a-aa97-72331ee4fd2b.wxs.VarScan2.aliquot.maf.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:dd6923a5-8fcc-4bc9-8912-14b20f387214',
#         'identifier': [{'system': 'GDC',
#           'value': 'dd6923a5-8fcc-4bc9-8912-14b20f387214'}],
#         'data_category': 'Simple Nucleotide Variation',
#         'byte_size': 567540,
#         'type': None,
#         'file_format': None,
#         'checksum': 'da2b85a5ffd55a7884557784684ab45d',
#         'id': 'dd6923a5-8fcc-4bc9-8912-14b20f387214',
#         'data_type': 'Annotated Somatic Mutation'}],
#       'derived_from_specimen': 'Initial sample',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Blood Derived Normal',
#       'derived_from_subject': '09CO022',
#       'specimen_type': 'sample',
#       'id': 'b12c257d-7409-4858-9384-c430929a075a',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'b12c257d-7409-4858-9384-c430929a075a'}]},
#      {'File': [],
#       'derived_from_specimen': 'b12c257d-7409-4858-9384-c430929a075a',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Blood Derived Normal',
#       'derived_from_subject': '09CO022',
#       'specimen_type': 'portion',
#       'id': '702d7ba0-9558-5b2d-af4d-cd797485b8c1',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': '702d7ba0-9558-5b2d-af4d-cd797485b8c1'}]},
#      {'File': [],
#       'derived_from_specimen': '702d7ba0-9558-5b2d-af4d-cd797485b8c1',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Blood Derived Normal',
#       'derived_from_subject': '09CO022',
#       'specimen_type': 'analyte',
#       'id': 'f0003f0a-07ea-548e-b1f7-7e6d1b27d47a',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'f0003f0a-07ea-548e-b1f7-7e6d1b27d47a'}]},
#      {'File': [],
#       'derived_from_specimen': 'f0003f0a-07ea-548e-b1f7-7e6d1b27d47a',
#       'associated_project': 'CPTAC-2',
#       'age_at_collection': None,
#       'anatomical_site': None,
#       'source_material_type': 'Blood Derived Normal',
#       'derived_from_subject': '09CO022',
#       'specimen_type': 'aliquot',
#       'id': 'ce309009-9257-4c13-9241-83fc629c35a0',
#       'primary_disease_type': 'Adenomas and Adenocarcinomas',
#       'identifier': [{'system': 'GDC',
#         'value': 'ce309009-9257-4c13-9241-83fc629c35a0'}]}],
#     'associated_project': 'CPTAC-2',
#     'id': 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d',
#     'primary_disease_type': 'Adenomas and Adenocarcinomas',
#     'identifier': [{'system': 'GDC',
#       'value': 'c5421e34-e5c7-4ba5-aed9-146a5575fd8d'}],
#     'primary_disease_site': 'Colon'},
#    {'Diagnosis': [{'morphology': '8140/3',
#       'tumor_stage': 'Stage IIB',
#       'tumor_grade': 'Not Reported',
#       'Treatment': [],
#       'id': 'ff301535-70ca-11e8-bcf1-0a2705229b82',
#       'primary_diagnosis': 'Adenocarcinoma, NOS',
#       'age_at_diagnosis': None}],
#     'Specimen': [{'File': [{'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f03.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:0235942c-7bd3-46c1-8a3d-87e42a0b1e86',
#         'identifier': [{'system': 'PDC',
#           'value': '0235942c-7bd3-46c1-8a3d-87e42a0b1e86'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 5195961,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': 'c1e585b85d70314ddfb9fe930faf6a0f',
#         'id': '0235942c-7bd3-46c1-8a3d-87e42a0b1e86',
#         'data_type': 'Text'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:0a63771a-14b2-4d6b-9c08-c7177c372789',
#         'identifier': [{'system': 'PDC',
#           'value': '0a63771a-14b2-4d6b-9c08-c7177c372789'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 213302411,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '8e16ac2e87bffdea86d75e03a8cf0ffa',
#         'id': '0a63771a-14b2-4d6b-9c08-c7177c372789',
#         'data_type': 'Open Standard'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:0daea74c-6886-415b-9395-cd4e0857acb4',
#         'identifier': [{'system': 'PDC',
#           'value': '0daea74c-6886-415b-9395-cd4e0857acb4'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 7044458,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': 'fc0008314a37ba989ed29b1c7f9d67e1',
#         'id': '0daea74c-6886-415b-9395-cd4e0857acb4',
#         'data_type': 'Open Standard'},
#        {'label': '13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:0d846fdf-169e-4081-910d-a792fab3df43',
#         'identifier': [{'system': 'PDC',
#           'value': '0d846fdf-169e-4081-910d-a792fab3df43'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 4247403,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '5f8d183651df64850a85a64586aa2d9b',
#         'id': '0d846fdf-169e-4081-910d-a792fab3df43',
#         'data_type': 'Open Standard'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f04.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:1279b00d-cb50-4021-a595-08e7c3dd35c0',
#         'identifier': [{'system': 'PDC',
#           'value': '1279b00d-cb50-4021-a595-08e7c3dd35c0'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 7311308,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '48c15a24e109b3f783b8a23766f25a94',
#         'id': '1279b00d-cb50-4021-a595-08e7c3dd35c0',
#         'data_type': 'Open Standard'},
#        {'label': '13CPTAC_COprospective_P_PNNL_20170215_B4S1_f06.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:1a1b004e-2ac6-42a7-b745-3e52be7fa22c',
#         'identifier': [{'system': 'PDC',
#           'value': '1a1b004e-2ac6-42a7-b745-3e52be7fa22c'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 814691558,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '4a8c37b53a8dfd37df9f8a2457f08d8b',
#         'id': '1a1b004e-2ac6-42a7-b745-3e52be7fa22c',
#         'data_type': 'Proprietary'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:1cf6afc7-d8dd-492e-88b4-ce73f63f0525',
#         'identifier': [{'system': 'PDC',
#           'value': '1cf6afc7-d8dd-492e-88b4-ce73f63f0525'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 228828721,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': '3f1e328de8a3cbc58ea38fb7e6b4be97',
#         'id': '1cf6afc7-d8dd-492e-88b4-ce73f63f0525',
#         'data_type': 'Open Standard'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f06.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:21b0644c-4bc2-4a72-826a-eb0b507add08',
#         'identifier': [{'system': 'PDC',
#           'value': '21b0644c-4bc2-4a72-826a-eb0b507add08'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 5574069,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': '0fed23511a9cfd34d95dfa610e194b3d',
#         'id': '21b0644c-4bc2-4a72-826a-eb0b507add08',
#         'data_type': 'Text'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f07.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:250dbc86-4d5c-45aa-bab5-0fb75678574b',
#         'identifier': [{'system': 'PDC',
#           'value': '250dbc86-4d5c-45aa-bab5-0fb75678574b'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 6920705,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '59c5839127bf5e75de5099a6ef431a1b',
#         'id': '250dbc86-4d5c-45aa-bab5-0fb75678574b',
#         'data_type': 'Open Standard'},
#        {'label': '13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:2834e1b0-1323-4ee5-b819-0e836aac244e',
#         'identifier': [{'system': 'PDC',
#           'value': '2834e1b0-1323-4ee5-b819-0e836aac244e'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 2529641,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': 'f5ce083f494f80aa6485cbfe65c3bf9d',
#         'id': '2834e1b0-1323-4ee5-b819-0e836aac244e',
#         'data_type': 'Text'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f12.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:28cebeba-0af6-42f8-9d3d-9b2d6aadcd8a',
#         'identifier': [{'system': 'PDC',
#           'value': '28cebeba-0af6-42f8-9d3d-9b2d6aadcd8a'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1885185505,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': '60a11fff4769d03b7d7a7586b5b05828',
#         'id': '28cebeba-0af6-42f8-9d3d-9b2d6aadcd8a',
#         'data_type': 'Proprietary'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f02.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:2f42f669-8819-423f-9078-ec988cb71d11',
#         'identifier': [{'system': 'PDC',
#           'value': '2f42f669-8819-423f-9078-ec988cb71d11'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 5306074,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': '0c51b70a9ec74aabb52dc59120dcb18b',
#         'id': '2f42f669-8819-423f-9078-ec988cb71d11',
#         'data_type': 'Text'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:31a66bc4-2b12-4310-919f-b8c0231e252d',
#         'identifier': [{'system': 'PDC',
#           'value': '31a66bc4-2b12-4310-919f-b8c0231e252d'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 5725135,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': 'cb5debd1ade07dfc256522f2332bb320',
#         'id': '31a66bc4-2b12-4310-919f-b8c0231e252d',
#         'data_type': 'Text'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:3ac4db66-7660-451f-833d-32ffa4f159d6',
#         'identifier': [{'system': 'PDC',
#           'value': '3ac4db66-7660-451f-833d-32ffa4f159d6'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 199273832,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': 'e2e505e6dc18ec1eead1576d2289a09d',
#         'id': '3ac4db66-7660-451f-833d-32ffa4f159d6',
#         'data_type': 'Open Standard'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f08.mzML.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:3d1ffaff-47b5-4e63-9840-6490055fd38d',
#         'identifier': [{'system': 'PDC',
#           'value': '3d1ffaff-47b5-4e63-9840-6490055fd38d'}],
#         'data_category': 'Processed Mass Spectra',
#         'byte_size': 200810764,
#         'type': None,
#         'file_format': 'mzML',
#         'checksum': 'be9c1aa166ae610d36d3ae4b622d5112',
#         'id': '3d1ffaff-47b5-4e63-9840-6490055fd38d',
#         'data_type': 'Open Standard'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:3d462e53-b907-4586-9b1f-041dde2b5dd5',
#         'identifier': [{'system': 'PDC',
#           'value': '3d462e53-b907-4586-9b1f-041dde2b5dd5'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1613377052,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': 'f08c5881ec4ee03927ae8bf8676faee5',
#         'id': '3d462e53-b907-4586-9b1f-041dde2b5dd5',
#         'data_type': 'Proprietary'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f01.raw',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:40617525-424e-4bc0-8468-4e00ff9f0ccb',
#         'identifier': [{'system': 'PDC',
#           'value': '40617525-424e-4bc0-8468-4e00ff9f0ccb'}],
#         'data_category': 'Raw Mass Spectra',
#         'byte_size': 1638996500,
#         'type': None,
#         'file_format': 'vendor-specific',
#         'checksum': 'de695ce745d100a3c1512e6a7232956c',
#         'id': '40617525-424e-4bc0-8468-4e00ff9f0ccb',
#         'data_type': 'Proprietary'},
#        {'label': '13CPTAC_COprospective_P_PNNL_20170215_B4S1_f02.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:41057289-39ea-4f09-b24f-dfd1336fc1ed',
#         'identifier': [{'system': 'PDC',
#           'value': '41057289-39ea-4f09-b24f-dfd1336fc1ed'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 3715668,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': 'c2ca24934a561a4d2f41e1a9e9fc474a',
#         'id': '41057289-39ea-4f09-b24f-dfd1336fc1ed',
#         'data_type': 'Open Standard'},
#        {'label': '13CPTAC_COprospective_P_PNNL_20170215_B4S1_f04.raw.cap.psm',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:42cfb6e3-3ebc-4a5e-bcd0-99c9fe7992b8',
#         'identifier': [{'system': 'PDC',
#           'value': '42cfb6e3-3ebc-4a5e-bcd0-99c9fe7992b8'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 2549143,
#         'type': None,
#         'file_format': 'tsv',
#         'checksum': 'b64210b35e7be647ed2450f872784e92',
#         'id': '42cfb6e3-3ebc-4a5e-bcd0-99c9fe7992b8',
#         'data_type': 'Text'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f09.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:47832160-26f2-4ad2-ae65-a781303b21d7',
#         'identifier': [{'system': 'PDC',
#           'value': '47832160-26f2-4ad2-ae65-a781303b21d7'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 7424654,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '61e93fdf0c6dc5e6b2db07971db2dac8',
#         'id': '47832160-26f2-4ad2-ae65-a781303b21d7',
#         'data_type': 'Open Standard'},
#        {'label': '13CPTAC_COprospective_W_PNNL_20170123_B4S1_f10.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:48d6afa8-9a0d-49b1-b080-f879108aefe9',
#         'identifier': [{'system': 'PDC',
#           'value': '48d6afa8-9a0d-49b1-b080-f879108aefe9'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 7140369,
#         'type': None,
#         'file_format': 'mzIdentML',
#         'checksum': '9ed307f94c00a23eacaf1901ad2f64fa',
#         'id': '48d6afa8-9a0d-49b1-b080-f879108aefe9',
#         'data_type': 'Open Standard'},
#        {'label': '13CPTAC_COprospective_P_PNNL_20170215_B4S1_f05.mzid.gz',
#         'associated_project': ['CPTAC-2'],
#         'drs_uri': 'drs://dg.4DFC:4ac75865-1dd4-4785-b8b0-ec0e133eab6c',
#         'identifier': [{'system': 'PDC',
#           'value': '4ac75865-1dd4-4785-b8b0-ec0e133eab6c'}],
#         'data_category': 'Peptide Spectral Matches',
#         'byte_size': 4067116,
#         'type': None,
#         'file_format': 'mzIdentML',
# ...
#    {'File': [],
#     'derived_from_specimen': '4591a53d-5668-4a70-b44b-e08a3d59267e',
#     'associated_project': 'CPTAC-2',
#     'age_at_collection': None,
#     'anatomical_site': None,
#     'source_material_type': 'Primary Tumor',
#     'derived_from_subject': '09CO022',
#     'specimen_type': 'portion',
#     'id': 'c53c4d60-2ddb-5da8-932e-00a86fa2347f',
#     'primary_disease_type': 'Adenomas and Adenocarcinomas',
#     'identifier': [{'system': 'GDC',
#       'value': 'c53c4d60-2ddb-5da8-932e-00a86fa2347f'}]},
#    {'File': [],
#     'derived_from_specimen': 'c53c4d60-2ddb-5da8-932e-00a86fa2347f',
#     'associated_project': 'CPTAC-2',
#     'age_at_collection': None,
#     'anatomical_site': None,
#     'source_material_type': 'Primary Tumor',
#     'derived_from_subject': '09CO022',
#     'specimen_type': 'analyte',
#     'id': '31075cfa-7aef-59f1-bf54-a1cddb5ee0fd',
#     'primary_disease_type': 'Adenomas and Adenocarcinomas',
#     'identifier': [{'system': 'GDC',
#       'value': '31075cfa-7aef-59f1-bf54-a1cddb5ee0fd'}]},
#    {'File': [],
#     'derived_from_specimen': '31075cfa-7aef-59f1-bf54-a1cddb5ee0fd',
#     'associated_project': 'CPTAC-2',
#     'age_at_collection': None,
#     'anatomical_site': None,
#     'source_material_type': 'Primary Tumor',
#     'derived_from_subject': '09CO022',
#     'specimen_type': 'aliquot',
#     'id': '0d8adcbf-13f0-48c3-83df-3fa205b79ae8',
#     'primary_disease_type': 'Adenomas and Adenocarcinomas',
#     'identifier': [{'system': 'GDC',
#       'value': '0d8adcbf-13f0-48c3-83df-3fa205b79ae8'}]},
#    {'File': [],
#     'derived_from_specimen': '4591a53d-5668-4a70-b44b-e08a3d59267e',
#     'associated_project': 'CPTAC-2',
#     'age_at_collection': None,
#     'anatomical_site': None,
#     'source_material_type': 'Primary Tumor',
#     'derived_from_subject': '09CO022',
#     'specimen_type': 'portion',
#     'id': 'd085ebd9-7605-54a0-abb9-10867f5fa1b1',
#     'primary_disease_type': 'Adenomas and Adenocarcinomas',
#     'identifier': [{'system': 'GDC',
#       'value': 'd085ebd9-7605-54a0-abb9-10867f5fa1b1'}]},
#    {'File': [],
#     'derived_from_specimen': 'd085ebd9-7605-54a0-abb9-10867f5fa1b1',
#     'associated_project': 'CPTAC-2',
#     'age_at_collection': None,
#     'anatomical_site': None,
#     'source_material_type': 'Primary Tumor',
#     'derived_from_subject': '09CO022',
#     'specimen_type': 'analyte',
#     'id': 'a31724b6-e550-552b-bd61-41341c534e28',
#     'primary_disease_type': 'Adenomas and Adenocarcinomas',
#     'identifier': [{'system': 'GDC',
#       'value': 'a31724b6-e550-552b-bd61-41341c534e28'}]},
#    {'File': [],
#     'derived_from_specimen': 'a31724b6-e550-552b-bd61-41341c534e28',
#     'associated_project': 'CPTAC-2',
#     'age_at_collection': None,
#     'anatomical_site': None,
#     'source_material_type': 'Primary Tumor',
#     'derived_from_subject': '09CO022',
#     'specimen_type': 'aliquot',
#     'id': '9250d96e-1cdc-4d68-8a56-f7b186a6fab5',
#     'primary_disease_type': 'Adenomas and Adenocarcinomas',
#     'identifier': [{'system': 'GDC',
#       'value': '9250d96e-1cdc-4d68-8a56-f7b186a6fab5'}]},
#    {'File': [{'label': 'fbc0c313-d356-4ad9-8257-57e90fb7f26b.wxs.Pindel.somatic_annotation.vcf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:00a9219e-109c-4013-89c8-3d01b39cd9bf',
#       'identifier': [{'system': 'GDC',
#         'value': '00a9219e-109c-4013-89c8-3d01b39cd9bf'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 248056,
#       'type': None,
#       'file_format': None,
#       'checksum': 'e09e988c4969cf68fac8168fa622df9f',
#       'id': '00a9219e-109c-4013-89c8-3d01b39cd9bf',
#       'data_type': 'Annotated Somatic Mutation'},
#      {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.mutect2.raw_somatic_mutation.vcf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:18b4dd00-f22a-4904-92f8-11d03fc21e44',
#       'identifier': [{'system': 'GDC',
#         'value': '18b4dd00-f22a-4904-92f8-11d03fc21e44'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 1611219,
#       'type': None,
#       'file_format': None,
#       'checksum': '5eab6ca0fbbb67a3204e55266161dc55',
#       'id': '18b4dd00-f22a-4904-92f8-11d03fc21e44',
#       'data_type': 'Raw Simple Somatic Mutation'},
#      {'label': '8c6af725-abc2-48af-a604-580e4b51fa30.wxs.MuTect2.somatic_annotation.vcf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:1fb29f83-87a5-416d-8af1-d94d749aeda9',
#       'identifier': [{'system': 'GDC',
#         'value': '1fb29f83-87a5-416d-8af1-d94d749aeda9'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 7547974,
#       'type': None,
#       'file_format': None,
#       'checksum': '2ab8ea64673f22be2fc3ae40ce3356eb',
#       'id': '1fb29f83-87a5-416d-8af1-d94d749aeda9',
#       'data_type': 'Annotated Somatic Mutation'},
#      {'label': '17ff92b1-3226-430a-8599-bacdb8dd65b0.wxs.Pindel.aliquot.maf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:654ba668-6f5f-497b-acd4-c41bd8e18e9e',
#       'identifier': [{'system': 'GDC',
#         'value': '654ba668-6f5f-497b-acd4-c41bd8e18e9e'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 163494,
#       'type': None,
#       'file_format': None,
#       'checksum': 'fabcd676c20684a8df20be63e49756a4',
#       'id': '654ba668-6f5f-497b-acd4-c41bd8e18e9e',
#       'data_type': 'Annotated Somatic Mutation'},
#      {'label': '2906082e-a906-4e04-b79b-f69541bb82bb.wxs.pindel.raw_somatic_mutation.vcf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:65d6fa7c-d474-4466-9b7d-a21b245237f7',
#       'identifier': [{'system': 'GDC',
#         'value': '65d6fa7c-d474-4466-9b7d-a21b245237f7'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 43887,
#       'type': None,
#       'file_format': None,
#       'checksum': 'cc174a5c968bd1dfc464c22fb1244f2b',
#       'id': '65d6fa7c-d474-4466-9b7d-a21b245237f7',
#       'data_type': 'Raw Simple Somatic Mutation'},
#      {'label': '70331103-de30-4d20-9dee-3d9bec0675d0.wxs.SomaticSniper.somatic_annotation.vcf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:6bb0f620-8925-4cd4-89c2-f0477d334ee9',
#       'identifier': [{'system': 'GDC',
#         'value': '6bb0f620-8925-4cd4-89c2-f0477d334ee9'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 5005951,
#       'type': None,
#       'file_format': None,
#       'checksum': 'f1582d896290ad6c93f4ee97195fb5a9',
#       'id': '6bb0f620-8925-4cd4-89c2-f0477d334ee9',
#       'data_type': 'Annotated Somatic Mutation'},
#      {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.varscan2.raw_somatic_mutation.vcf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:7247faf2-afb0-4a39-9a55-9d471de5c550',
#       'identifier': [{'system': 'GDC',
#         'value': '7247faf2-afb0-4a39-9a55-9d471de5c550'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 115646,
#       'type': None,
#       'file_format': None,
#       'checksum': '0dd012d2a55bedca6921fad581fbbd27',
#       'id': '7247faf2-afb0-4a39-9a55-9d471de5c550',
#       'data_type': 'Raw Simple Somatic Mutation'},
#      {'label': '96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_raw.maf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:77a179fc-a3bc-462e-8209-979b9a031e20',
#       'identifier': [{'system': 'GDC',
#         'value': '77a179fc-a3bc-462e-8209-979b9a031e20'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 342713,
#       'type': None,
#       'file_format': None,
#       'checksum': '35d6d356b65c552962845a5f963db28a',
#       'id': '77a179fc-a3bc-462e-8209-979b9a031e20',
#       'data_type': 'Aggregated Somatic Mutation'},
#      {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.muse.raw_somatic_mutation.vcf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:849452d3-3a1c-4f3d-a7c2-3e0b7580efec',
#       'identifier': [{'system': 'GDC',
#         'value': '849452d3-3a1c-4f3d-a7c2-3e0b7580efec'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 50325,
#       'type': None,
#       'file_format': None,
#       'checksum': '5dab4cb237c6bdf9f26938510d9f6442',
#       'id': '849452d3-3a1c-4f3d-a7c2-3e0b7580efec',
#       'data_type': 'Raw Simple Somatic Mutation'},
#      {'label': '96cedbfc-64f9-4110-9e84-c5fde32208ef.wxs.aliquot_ensemble_masked.maf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb',
#       'identifier': [{'system': 'GDC',
#         'value': '8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 53313,
#       'type': None,
#       'file_format': None,
#       'checksum': 'dc22add6654662c05c787407c20b4578',
#       'id': '8ebb6c3a-67a0-4fc1-b834-3d6ecd9526cb',
#       'data_type': 'Masked Somatic Mutation'},
#      {'label': 'ea51af0a-e767-4db1-8a8d-1cf19df17c4c.wxs.MuTect2.aliquot.maf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:9c18aa38-5edd-40cf-8389-a03aea35a150',
#       'identifier': [{'system': 'GDC',
#         'value': '9c18aa38-5edd-40cf-8389-a03aea35a150'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 6167311,
#       'type': None,
#       'file_format': None,
#       'checksum': '765119382d413e7051cedb1ad122d436',
#       'id': '9c18aa38-5edd-40cf-8389-a03aea35a150',
#       'data_type': 'Annotated Somatic Mutation'},
#      {'label': 'abdaac20-1a31-4785-ace5-7ef4cc07bc8e.wxs.VarScan2.somatic_annotation.vcf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1',
#       'identifier': [{'system': 'GDC',
#         'value': '9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 767641,
#       'type': None,
#       'file_format': None,
#       'checksum': '641b13968bf9401223d29e9f3350804c',
#       'id': '9e47cc99-31e0-4028-97bb-f4cdb9ebf5a1',
#       'data_type': 'Annotated Somatic Mutation'},
#      {'label': 'a78c9b27-d695-4a91-90f8-cd08c29602b2.wxs.MuSE.aliquot.maf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:9f27b7a7-7e18-42c8-a5bd-62461a567955',
#       'identifier': [{'system': 'GDC',
#         'value': '9f27b7a7-7e18-42c8-a5bd-62461a567955'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 305442,
#       'type': None,
#       'file_format': None,
#       'checksum': 'ef18bf2c57161d8a48256f6f9fd3c441',
#       'id': '9f27b7a7-7e18-42c8-a5bd-62461a567955',
#       'data_type': 'Annotated Somatic Mutation'},
#      {'label': 'ce309009-9257-4c13-9241-83fc629c35a0_wxs_gdc_realn.bam',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:a35f18eb-3475-4433-a72f-4b8aa2cb6106',
#       'identifier': [{'system': 'GDC',
#         'value': 'a35f18eb-3475-4433-a72f-4b8aa2cb6106'}],
#       'data_category': 'Sequencing Reads',
#       'byte_size': 69157605164,
#       'type': None,
#       'file_format': None,
#       'checksum': '21f2140d9d3ef197422820a7e0bb8561',
#       'id': 'a35f18eb-3475-4433-a72f-4b8aa2cb6106',
#       'data_type': 'Aligned Reads'},
#      {'label': '0e8a628a-d5a4-4ae2-bb81-73a1a9c1d4cd.wxs.MuSE.somatic_annotation.vcf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:b8ecf468-dd33-4f43-8093-544d92d676f6',
#       'identifier': [{'system': 'GDC',
#         'value': 'b8ecf468-dd33-4f43-8093-544d92d676f6'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 438051,
#       'type': None,
#       'file_format': None,
#       'checksum': '52a6cc7af0c366fd93240a49998289ff',
#       'id': 'b8ecf468-dd33-4f43-8093-544d92d676f6',
#       'data_type': 'Annotated Somatic Mutation'},
#      {'label': '05a070b0-8448-462f-b31d-83b4a98f6bbd.wxs.somaticsniper.raw_somatic_mutation.vcf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:c411fd62-0198-4c47-ada8-0cffafb5a262',
#       'identifier': [{'system': 'GDC',
#         'value': 'c411fd62-0198-4c47-ada8-0cffafb5a262'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 5936384,
#       'type': None,
#       'file_format': None,
#       'checksum': '6d07c80d2683a58c9e656ee165570f35',
#       'id': 'c411fd62-0198-4c47-ada8-0cffafb5a262',
#       'data_type': 'Raw Simple Somatic Mutation'},
#      {'label': 'b85b56a6-89e2-424c-993d-764ae20bf072.wxs.SomaticSniper.aliquot.maf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:d7b978a6-a601-4025-8408-ee1fdb391689',
#       'identifier': [{'system': 'GDC',
#         'value': 'd7b978a6-a601-4025-8408-ee1fdb391689'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 4001912,
#       'type': None,
#       'file_format': None,
#       'checksum': 'ec3a6c924c6f10268a0b3f5de77c2e4d',
#       'id': 'd7b978a6-a601-4025-8408-ee1fdb391689',
#       'data_type': 'Annotated Somatic Mutation'},
#      {'label': 'd4496cf9-bc61-400a-aa97-72331ee4fd2b.wxs.VarScan2.aliquot.maf.gz',
#       'associated_project': ['CPTAC-2'],
#       'drs_uri': 'drs://dg.4DFC:dd6923a5-8fcc-4bc9-8912-14b20f387214',
#       'identifier': [{'system': 'GDC',
#         'value': 'dd6923a5-8fcc-4bc9-8912-14b20f387214'}],
#       'data_category': 'Simple Nucleotide Variation',
#       'byte_size': 567540,
#       'type': None,
#       'file_format': None,
#       'checksum': 'da2b85a5ffd55a7884557784684ab45d',
#       'id': 'dd6923a5-8fcc-4bc9-8912-14b20f387214',
#       'data_type': 'Annotated Somatic Mutation'}],
#     'derived_from_specimen': 'Initial sample',
#     'associated_project': 'CPTAC-2',
#     'age_at_collection': None,
#     'anatomical_site': None,
#     'source_material_type': 'Blood Derived Normal',
#     'derived_from_subject': '09CO022',
#     'specimen_type': 'sample',
#     'id': 'b12c257d-7409-4858-9384-c430929a075a',
#     'primary_disease_type': 'Adenomas and Adenocarcinomas',
#     'identifier': [{'system': 'GDC',
#       'value': 'b12c257d-7409-4858-9384-c430929a075a'}]},
#    {'File': [],
#     'derived_from_specimen': 'b12c257d-7409-4858-9384-c430929a075a',
#     'associated_project': 'CPTAC-2',
#     'age_at_collection': None,
#     'anatomical_site': None,
#     'source_material_type': 'Blood Derived Normal',
#     'derived_from_subject': '09CO022',
#     'specimen_type': 'portion',
#     'id': '702d7ba0-9558-5b2d-af4d-cd797485b8c1',
#     'primary_disease_type': 'Adenomas and Adenocarcinomas',
#     'identifier': [{'system': 'GDC',
#       'value': '702d7ba0-9558-5b2d-af4d-cd797485b8c1'}]},
#    {'File': [],
#     'derived_from_specimen': '702d7ba0-9558-5b2d-af4d-cd797485b8c1',
#     'associated_project': 'CPTAC-2',
#     'age_at_collection': None,
#     'anatomical_site': None,
#     'source_material_type': 'Blood Derived Normal',
#     'derived_from_subject': '09CO022',
#     'specimen_type': 'analyte',
#     'id': 'f0003f0a-07ea-548e-b1f7-7e6d1b27d47a',
#     'primary_disease_type': 'Adenomas and Adenocarcinomas',
#     'identifier': [{'system': 'GDC',
#       'value': 'f0003f0a-07ea-548e-b1f7-7e6d1b27d47a'}]},
#    {'File': [],
#     'derived_from_specimen': 'f0003f0a-07ea-548e-b1f7-7e6d1b27d47a',
#     'associated_project': 'CPTAC-2',
#     'age_at_collection': None,
#     'anatomical_site': None,
#     'source_material_type': 'Blood Derived Normal',
#     'derived_from_subject': '09CO022',
#     'specimen_type': 'aliquot',
#     'id': 'ce309009-9257-4c13-9241-83fc629c35a0',
#     'primary_disease_type': 'Adenomas and Adenocarcinomas',
#     'identifier': [{'system': 'GDC',
#       'value': 'ce309009-9257-4c13-9241-83fc629c35a0'}]}],
#   'associated_project': 'CPTAC-2',
#   'primary_disease_type': 'Adenomas and Adenocarcinomas',
#   'identifier': [{'system': 'GDC',
#     'value': 'ce309009-9257-4c13-9241-83fc629c35a0'}],
#   'primary_disease_site': 'Colon',
#   'File': [],
#   'derived_from_specimen': 'f0003f0a-07ea-548e-b1f7-7e6d1b27d47a',
#   'age_at_collection': None,
#   'anatomical_site': None,
#   'source_material_type': 'Blood Derived Normal',
#   'derived_from_subject': '09CO022',
#   'specimen_type': 'aliquot'}]
